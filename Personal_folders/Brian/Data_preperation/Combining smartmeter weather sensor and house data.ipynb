# %% [markdown]
# # Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import dask.dataframe as dd

from tqdm import tqdm

mpl.style.use('default')
#%matplotlib notebook
# %matplotlib inline

# %% [markdown]
# # Load data

# %%
"""
Lead the hour dataframe containing all dwellings with smartmeter & weather data.
"""
a = pd.read_csv('//datc//opschaler//combined_gas_smart_weather_dfs//processed/all_dwellings_combined_hour.csv', delimiter='\t', parse_dates=['datetime'])
a = a.set_index(['datetime'])

# %%
b = pd.read_csv('//datc//opschaler//honeywell_sensors_per_dwelling_combined//honeywell_all_dwellings_combined.csv', delimiter='\t', parse_dates=['datetime'])
b.head()
# Out:
#              datetime  Co2Value  Humidity  HumidityBathRoom  Presence  \
# 0 2017-01-04 00:00:00   1127.00     50.50            206.00     60.75
# 1 2017-01-04 00:05:00   1151.50     50.50            206.25     60.50
# 2 2017-01-04 00:10:00   1146.75     50.50            206.00     60.50
# 3 2017-01-04 00:15:00   1129.25     50.00            206.25     60.50
# 4 2017-01-04 00:20:00   1096.50     50.25            206.25     60.50
#
#    RoomTemp  VentilationLevel     dwelling
# 0   21.1450               NaN  P01S01W6595
# 1   21.1800               NaN  P01S01W6595
# 2   21.1625               NaN  P01S01W6595
# 3   21.1600               NaN  P01S01W6595
# 4   21.1275               NaN  P01S01W6595

# %%
# Out:
#   Living room Kitchen Bedroom 1 Bedroom 2
# 0      1dc018  1dc00e    1dc012    1dc010
# 1      1dc029  1dc011    1dc019    1dc01b
# 2      1dc02c  1dc015    1dc01f    1dc024
# 3      1dc036  1dc01c    1dc026    1dc025
# 4      1dc03c  1dc021    1dc031    1dc027

# %%
b
# Out:
#                    datetime  Co2Value  Humidity  HumidityBathRoom  Presence  \
# 0       2017-01-04 00:00:00   1127.00     50.50            206.00     60.75
# 1       2017-01-04 00:05:00   1151.50     50.50            206.25     60.50
# 2       2017-01-04 00:10:00   1146.75     50.50            206.00     60.50
# 3       2017-01-04 00:15:00   1129.25     50.00            206.25     60.50
# 4       2017-01-04 00:20:00   1096.50     50.25            206.25     60.50
# 5       2017-01-04 00:25:00   1091.00     50.25            206.00     60.50
# 6       2017-01-04 00:30:00   1079.50     50.00            206.00     60.50
# 7       2017-01-04 00:35:00   1077.00     50.00            206.00     60.50
# 8       2017-01-04 00:40:00   1072.25     49.75            206.00     60.50
# 9       2017-01-04 00:45:00   1057.75     49.50            206.00     60.50
# 10      2017-01-04 00:50:00   1075.00     49.75            206.00     60.50
# ...
