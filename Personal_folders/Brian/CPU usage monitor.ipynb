# %% [markdown]
# # CPU Usage monitor
# This notebooks shows the CPU usage.
# TODO: Make axis not transparent

# %%
import psutil
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

from IPython import display

#mpl.style.use('default')

# %matplotlib inline

sns.set()

# %%
# %matplotlib inline
import time
import pylab as pl
from IPython import display
values = []

for i in range(1000):
    values.append(psutil.cpu_percent(interval=1, percpu=False))
    pl.plot(values)
    display.clear_output(wait=True)
    display.display(pl.gcf())
    #time.sleep(0.05)
