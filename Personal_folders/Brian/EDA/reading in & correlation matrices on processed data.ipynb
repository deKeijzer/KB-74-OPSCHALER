# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import numpy as np
# %matplotlib inline
mpl.style.use('default')

# %%
dir = '//datc//opschaler//combined_gas_smart_weather_dfs//processed//'
dwelling_id = 'P01S01W5855_10s'
s = pd.read_csv(dir+dwelling_id+'.csv', delimiter='\t', parse_dates=['datetime'])
s = s.set_index(['datetime'])
s.head()
# Out:
#                           eMeter  eMeterReturn    eMeterLow  eMeterLowReturn  \
# datetime
# 2017-03-07 07:34:20  2457.402100           0.0  2370.063965              0.0
# 2017-03-07 07:34:30  2457.404053           0.0  2370.063965              0.0
# 2017-03-07 07:34:40  2457.406006           0.0  2370.063965              0.0
# 2017-03-07 07:34:50  2457.406982           0.0  2370.063965              0.0
# 2017-03-07 07:35:00  2457.408936           0.0  2370.063965              0.0
#
#                      ePower  ePowerReturn     gasMeter  gasPower     DD   DR  \
# datetime
# 2017-03-07 07:34:20   551.0           0.0  2073.334961       0.0  286.5  0.0
# 2017-03-07 07:34:30   550.0           0.0  2073.334961       0.0  286.5  0.0
# 2017-03-07 07:34:40   554.0           0.0  2073.334961       0.0  286.5  0.0
# 2017-03-07 07:34:50   547.0           0.0  2073.334961       0.0  286.5  0.0
# 2017-03-07 07:35:00   549.0           0.0  2073.334961       0.0  286.5  0.0
#
# ...

# %%
dir = '//datc//opschaler//combined_gas_smart_weather_dfs//processed//'
dwelling_id = 'P01S01W5855_hour'
h = pd.read_csv(dir+dwelling_id+'.csv', delimiter='\t', parse_dates=['datetime'])
h = h.set_index(['datetime'])
h.head()
# Out:
#                           eMeter  eMeterReturn    eMeterLow  eMeterLowReturn  \
# datetime
# 2017-03-07 07:00:00  2457.478027           0.0  2370.063965              0.0
# 2017-03-07 08:00:00  2457.860840           0.0  2370.063965              0.0
# 2017-03-07 09:00:00  2458.163818           0.0  2370.063965              0.0
# 2017-03-07 10:00:00  2458.550049           0.0  2370.063965              0.0
# 2017-03-07 11:00:00  2459.329834           0.0  2370.063965              0.0
#
#                          ePower  ePowerReturn     gasMeter  gasPower  \
# datetime
# 2017-03-07 07:00:00  382.396667           0.0  2073.334961  0.598145
# 2017-03-07 08:00:00  477.858368           0.0  2073.933105  0.598145
# 2017-03-07 09:00:00  232.491669           0.0  2074.427002  0.493896
# 2017-03-07 10:00:00  880.230530           0.0  2074.990967  0.563965
# 2017-03-07 11:00:00  251.952728           0.0  2075.397949  0.406982
#
# ...

# %%
h.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1996 entries, 2017-03-07 07:00:00 to 2017-05-29 10:00:00
# Data columns (total 23 columns):
# eMeter             1996 non-null float64
# eMeterReturn       1996 non-null float64
# eMeterLow          1996 non-null float64
# eMeterLowReturn    1996 non-null float64
# ePower             1932 non-null float64
# ePowerReturn       1932 non-null float64
# gasMeter           1996 non-null float64
# gasPower           1929 non-null float64
# DD                 1996 non-null float64
# DR                 1996 non-null float64
# FF                 1996 non-null float64
# FX                 1996 non-null float64
# N                  1996 non-null float64
# P                  1996 non-null float64
# Q                  1996 non-null float64
# RG                 1996 non-null float64
# SQ                 1996 non-null float64
# T                  1996 non-null float64
# T10                1996 non-null float64
# ...

# %%
s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 717995 entries, 2017-03-07 07:34:20 to 2017-05-29 10:00:00
# Data columns (total 23 columns):
# eMeter             717995 non-null float64
# eMeterReturn       717995 non-null float64
# eMeterLow          717995 non-null float64
# eMeterLowReturn    717995 non-null float64
# ePower             686029 non-null float64
# ePowerReturn       686029 non-null float64
# gasMeter           717995 non-null float64
# gasPower           694952 non-null float64
# DD                 717995 non-null float64
# DR                 717995 non-null float64
# FF                 717995 non-null float64
# FX                 717995 non-null float64
# N                  717995 non-null float64
# P                  717995 non-null float64
# Q                  717995 non-null float64
# RG                 717995 non-null float64
# SQ                 717995 non-null float64
# T                  717995 non-null float64
# ...

# %%
h.isnull().sum()
# Out:
# eMeter              0
# eMeterReturn        0
# eMeterLow           0
# eMeterLowReturn     0
# ePower             64
# ePowerReturn       64
# gasMeter            0
# gasPower           67
# DD                  0
# DR                  0
# FF                  0
# FX                  0
# N                   0
# P                   0
# Q                   0
# RG                  0
# SQ                  0
# T                   0
# T10                 0
# TD                  0
# U                   0
# VV                  0
# WW                  0
# dtype: int64

# %%
s.isnull().sum()
# Out:
# eMeter                 0
# eMeterReturn           0
# eMeterLow              0
# eMeterLowReturn        0
# ePower             31966
# ePowerReturn       31966
# gasMeter               0
# gasPower           23043
# DD                     0
# DR                     0
# FF                     0
# FX                     0
# N                      0
# P                      0
# Q                      0
# RG                     0
# SQ                     0
# T                      0
# T10                    0
# TD                     0
# U                      0
# VV                     0
# WW                     0
# dtype: int64

# %%
plt.suptitle('House ID: P01S01W0378')

plt.subplot(2,2,1)
plt.plot(s.index, s['Q'], '-', color='r', linewidth=1)
plt.xlabel('Date [-]')
plt.ylabel('Global Radiation [J/m$^2$]')
plt.xticks(rotation=45)
plt.grid()
plt.tight_layout()

plt.subplot(2,2,2)
plt.plot(s.index, s['T'], '-', color='r', linewidth=1)
plt.xlabel('Date [-]')
plt.ylabel('Temperature [°C]')
plt.xticks(rotation=45)
plt.grid()
plt.tight_layout()

plt.subplot(2,2,3)
plt.plot(s.index, s['ePower'], '-', color='r', linewidth=0.1)
plt.xlabel('Date [-]')
plt.ylabel('ePower [kWh]')
plt.xticks(rotation=45)
plt.grid()
plt.tight_layout()

plt.subplot(2,2,4)
plt.plot(s.index, s['gasPower'], '-', color='r', linewidth=0.4)
plt.xlabel('Date [-]')
plt.ylabel('gasPower [m$^3$]')
plt.xticks(rotation=45)
plt.grid()
plt.tight_layout()

# %%
plt.suptitle('House ID: P01S01W0378 1 hour sample rate')

plt.subplot(2,2,1)
plt.plot(h.index, h['Q'], '-', color='r', linewidth=1)
plt.xlabel('Date [-]')
plt.ylabel('Global Radiation [J/m$^2$]')
plt.xticks(rotation=45)
plt.grid()
plt.tight_layout()

plt.subplot(2,2,2)
plt.plot(h.index, h['T'], '-', color='r', linewidth=1)
plt.xlabel('Date [-]')
plt.ylabel('Temperature [°C]')
plt.xticks(rotation=45)
plt.grid()
plt.tight_layout()

plt.subplot(2,2,3)
plt.plot(h.index, h['ePower'], '-', color='r', linewidth=0.1)
plt.xlabel('Date [-]')
plt.ylabel('ePower [kWh]')
plt.xticks(rotation=45)
plt.grid()
plt.tight_layout()

plt.subplot(2,2,4)
plt.plot(h.index, h['gasPower'], '-', color='r', linewidth=0.4)
plt.xlabel('Date [-]')
plt.ylabel('gasPower [m$^3$]')
plt.xticks(rotation=45)
plt.grid()
plt.tight_layout()

# %%
sns.heatmap(h.corr(), square=False, cmap='RdYlGn')

# %%
"""
Pearson correlation coefficient matrix. 
The Pearson correlation coefficient is a measure of the linear correlation between two variables.
"""

corr = s.corr()
mask = np.zeros_like(s.corr())
mask[np.triu_indices_from(mask)] = True


fig, ax = plt.subplots(figsize=(25,25))

sns.heatmap(corr, mask=mask, square=False, cmap='RdYlGn', annot=True, ax=ax,
            cbar_kws={'label':'Pearson correlation coefficient [-]'})

plt.title('Correlation Matrix')
plt.xticks(rotation=90)
plt.yticks(rotation=0)
# Out:
# (array([  0.5,   1.5,   2.5,   3.5,   4.5,   5.5,   6.5,   7.5,   8.5,
#           9.5,  10.5,  11.5,  12.5,  13.5,  14.5,  15.5,  16.5,  17.5,
#          18.5,  19.5,  20.5,  21.5,  22.5]),
#  <a list of 23 Text yticklabel objects>)

# %%
def create_corr_matrix(df, dwelling_id, annot):
    """
    Pearson correlation coefficient matrix. 
    The Pearson correlation coefficient is a measure of the linear correlation between two variables.
    """
    plt.clf()
    
    corr = s.corr()
    mask = np.zeros_like(s.corr())
    mask[np.triu_indices_from(mask)] = True

    if annot:
        fig, ax = plt.subplots(figsize=(25,25))
    else:
        fig, ax = plt.subplots()

    fig = sns.heatmap(corr, mask=mask, square=False, cmap='RdYlGn', annot=annot, ax=ax, 
                cbar_kws={'label':'Pearson correlation coefficient [-]'})

    fig.set_title('Correlation matrix of dwelling ID: '+dwelling_id)
    fig.tick_params(axis='x', rotation=90)
    fig.tick_params(axis='y', rotation=0)

    fig = fig.get_figure()
    fig.tight_layout()
    fig.show()
    
    print('Saving heatmap')
    fig.savefig('//datc//opschaler//EDA//Pearson_corr//' + dwelling_id + '.png', dpi=300)
    return fig

# %%
fig = create_corr_matrix(s, 'False 10s', False)
# Out:
# /opt/jupyterhub/anaconda/lib/python3.6/site-packages/matplotlib/figure.py:459: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
# Saving heatmap

# %%
print('t')
# Out:
# t
