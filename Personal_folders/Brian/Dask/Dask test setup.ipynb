# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
mpl.style.use('default')
import glob
import dask
import dask.dataframe as dd
from tqdm import tqdm
from dask.distributed import Client, LocalCluster, progress, fire_and_forget
from dask import delayed

# %matplotlib inline

# %% [markdown]
# # Setting up LocalCluster & run it
# Might not be needed, but experienced that `processes=False, n_workers=1` are the best options to have.

# %%
#cluster = LocalCluster(processes=False, n_workers=8)
cluster = LocalCluster(processes=False, n_workers=1)
#cpu_worker = cluster.workers[0]
#cpu_worker.name = 'cpu'
#cpu_worker.set_resources(CPU=90)

client=Client(cluster, processes=True)
#client=Client()
client

# %%
#cluster

# %% [markdown]
# # Defining functions

# %%
def read_weather_data():
    """
    Reads in the weather Pandas DataFrame.
    :return: Pandas DataFrame
    """
    # Check if UTC to gmt+1 conversion is being handled correctly
    weather = pd.read_csv('F://datc//opschaler//weather_data//knmi_10_min_raw_data//output//df_combined_uncleaned.csv',
                          delimiter='\t', comment='#',
                          parse_dates=['datetime'])
    weather = weather.set_index(['datetime'])
    weather = reduce_memory(weather)
    return weather


def smartmeter_data():
    """
    Reads in the file paths and dwelling id's of the smartmeter data.
    :return: file_paths, dwelling_ids, both as lists.
    """
    path = 'F://datc//opschaler//smartmeter_data//'
    file_paths = np.array(glob.glob(path + "*.csv"))

    print('Detected %s smartmeter_data files.' % len(file_paths))
    dwelling_ids = np.array(list((map(lambda x: x[-15:-4], file_paths))))

    return file_paths, dwelling_ids


def reduce_memory(df):
    """
    Reduces memory footprint of the input dataframe.
    Changes float64 columns to float32 dtype.
    """
    columns = df.columns
    memory_before = df.memory_usage(deep=False).sum() / 2**30 # convert bytes to GB

    for column in columns:
        if df[column].dtype == 'float64':
            df[column] = df[column].astype('float32')
        
    memory_after = df.memory_usage(deep=False).sum() / 2**30 # convert bytes to GB
    #print('Memory usage reduced from %.3f GB to %.3f GB' % (memory_before, memory_after))
    
    return df

@delayed(nout=2)
def clean_prepare_smart_gas(file_path, dwelling_id):
    """
    Input is a dwelling_id.csv file.
    Output are cleaned & prepared dataframes (smart, gas).

    :param file_path: path to 'dwelling_id.csv' file
    :return: Smart and gas Pandas DataFrames
    """
    df = pd.read_csv(file_path, delimiter=';', header=0)
    df = df.rename(index=str, columns={'Timestamp': 'datetime', 'gasTimestamp': 'datetime'})
    
    # Split up the dataframe
    smart = df.iloc[:, :7] # electricity part
    gas = df.iloc[:, 7:] # gas part
    
    del df
    
    try:
        smart['datetime'] = pd.to_datetime(smart['datetime'])
        gas['datetime'] = pd.to_datetime(gas['datetime'])
    except:
        print('datetime column contains non-datetime values')
        smart = clean_datetime(smart)
        gas = clean_datetime(gas)
        smart['datetime'] = pd.to_datetime(smart['datetime'])
        gas['datetime'] = pd.to_datetime(gas['datetime'])

    smart = smart.set_index(['datetime'])
    gas = gas.set_index(['datetime'])

    smart = dask.delayed(reduce_memory)(smart) # Dask delay the 'reduce_memory' function with 'smart' as input variable for 'reduce_memory'
    gas = dask.delayed(reduce_memory)(gas)

    return smart, gas


@delayed
def clean_datetime(df):
    """
    TODO: Speed up the function
    Input should be a df with a column called 'datetime'.
    This function checks wether a row in the df.datetime column can be parsed to a Pandas datetime object,
    by trying pd.to_datetime() on it.
    If it fails it will replace that row with np.nan().
    Finally this function will return the df with the NaN rows dropped.
    It only drops the row if the datetime column contains a NaN.

    :param df: Pandas DataFrame containing a datetime column called 'datetime'.
    :return: Pandas DataFrame
    """
    for i in range(len(df)):
        try:
            pd.to_datetime(df.datetime[i])
        except ValueError:
            print('-----')
            print('ValueError at index = %s' % i)
            print(df.datetime[i])
            df.datetime = df.datetime.replace(df.datetime[i], np.nan)
    df = df.dropna(subset=['datetime'])
    return df


@delayed(nout=2)
def resample_dfs_to_default_sample_rate(smart, gas):
    """
    Resample smart, gas, weather to their original sample rate.
    This will make missing timestamp appear, with NaN as their values.
    """
    smart = smart.resample('10s').mean()
    gas = gas.resample('H').mean()

    return smart, gas


@delayed
def create_hour_df(smart, gas, weather, dwelling_id):
    # compute frames
    smart = smart.compute()
    gas = gas.compute()
    
    # Calculate gasPower
    gas['gasPower'] = gas['gasMeter'].diff()
    
    # Resample smart df to one hour
    # Define what to do for which columns
    to_sum = ['eMeterReturn', 'eMeterLow', 'eMeterLowReturn', 'ePower', 'ePowerReturn'] # resampler.sum() these columns
    to_last = ['eMeter'] # resample.last(), take last known value from the columns (look in documentation for more info)
    
    # Resample smart to one hour (df is still in 10s resolution, but all data besides the hour points are NaN)
    smart[to_sum] = smart[to_sum].resample('H').sum() # sum values
    smart[to_last] = smart[to_last].resample('H').last() # see pandas documentation
    
    # Get rid off NaNs , resample complete df including its index to 1 hour
    smart = smart.resample('H').mean() # resample to 1H by mean (this wont change the values calculated by .sum() and .last())
    

    weather = weather.resample('H').mean()  # Down sample weather df to one hour
    
    # Combine gas, smart, weather
    df_hour = pd.merge(smart, gas, left_index=True, right_index=True)
    df_hour = pd.merge(df_hour, weather, left_index=True, right_index=True)
    df_hour['dwelling'] = dwelling_id # Add a dwelling id column
    
    return df_hour


@delayed
def create_10s_df(smart, gas, weather, dwelling_id):
    # compute frames
    smart = smart.compute()
    gas = gas.compute()
    
    
    gas = gas.resample('10s').ffill()  # Up sample gas to 10s by forward filling the values

    # Currently this code makes it so there is one gasPower value per hour, we could ffill this also?
    gas['gasPower'] = gas['gasMeter'].diff() # Calculate gasPower

    weather = weather.resample('10s').ffill()  # forward fill because the raw data is the 10 minute mean
    
    # Combine gas, smart, weather
    df_10s = pd.merge(smart, gas, left_index=True, right_index=True)
    df_10s = pd.merge(df_10s, weather, left_index=True, right_index=True)
    df_10s['dwelling'] = dwelling_id
    
    return df_10s


@delayed
def plot_nans(df, dwelling_id, resample_to):
    """
    Create a heatmap of the NaNs in the input DataFrame.
    :param df: Pandas DataFrame
    :param df: String to resample to, for example '1T' or 'H'
    :param dwelling_id: String
    :return: Seaborn heatmap as a Figure
    """
    plt.clf()
    df = df.isnull()
    # Downsample to make all data visible
    df = df.resample(resample_to).sum()  # Downsample to make small NaNs visible
    df = df.apply(lambda x: x > 0, 1)  # Replace values >0 with 1

    # Reindex datetimes
    # https://stackoverflow.com/questions/41046630/set-time-formatting-on-a-datetime-index-when-plotting-pandas-series
    try:
        df.index = df.index.to_period('D')
    except:
        print('plot_nans could not set df.index.to_period')

    # Plot heatmap
    n = int(len(df)*0.1)  # Choose amount of yticklabels to show

    try:
        fig = sns.heatmap(df, cmap='Reds', square=False, vmin=0, cbar=False, yticklabels=n*2, cbar_kws={})
    except TypeError:
        print('plot_nans ValueError')
        fig = sns.heatmap(df, cmap='Reds', square=False, vmin=0, cbar=False, cbar_kws={})

    # Set cbar ticks manually
    #cbar = fig.collections[0].colorbar
    #cbar.set_ticks([0, 1])
    #cbar.set_ticklabels(['Not NaN', 'NaN'])

    # Correct layout
    fig.invert_yaxis()
    fig.tick_params(axis='x', rotation=90)
    fig.tick_params(axis='y', rotation=0)
    fig.set(xlabel='Column [-]', ylabel='Index [-]')
    plt.title('Dwelling ID: '+dwelling_id)

    fig = fig.get_figure()
    #fig.tight_layout()
    #fig.show()
    #print('Saving heatmap')
    #fig.savefig('F://datc//opschaler//nan_information//figures//' + dwelling_id + '.png', dpi=1200)
    #savefig crashes dask
    
    return fig


@delayed
def df_nan_checker(df, threshold_percentage):
    """
    TODO: Parellalize, as in one column per core/worker?
    Checks each column in the input dataframe for NaNs.
    Outputs the amount of NaNs behind each other, including the start and stop index, per column as a sublist.
    For example when the dataframe has three columns.
    Output is in the form of:
    [[column_one_info], [column_two_info], [column_three_info]]
    With the column_..._info being in the form of:
    [start_index, stop_index, amount_of_NaNs]

    :param df: Pandas DataFrame
    :param threshold_percentage: Filter output based on NaN streaks being larger than x % of the total length of the dataframe.
    :return: Pandas DataFrame
    """
    columns = df.columns
    df = df.isnull()
    output = []
    length = len(columns)
    
    
    @delayed
    def check_rows(df, column_name):
        column_info = []
        temp = []
        x = False

        for j, value in enumerate(df[column_name]):
            if x == False and value == True:
                temp.append(df.index[j])
                x = True
            elif x == True and value == True:
                temp.append(df.index[j])
            elif x == True and value == False:
                column_info.append(temp)
                temp = []
                x = False

        lengths = []

        for array in column_info:
            lengths.append([array[0], array[-1], len(array)])

        return lengths

    
    for i in range(length):
        lengths = check_rows(df, columns[i])
        output.append(lengths)
    
    @delayed
    def list_to_df(output):
        # Convert df_info to a readable dataframe instead of list

        """
        Row per column from the 'output' list
        Columns: start-index, stop-index, NaN streak
        """

        df_info = pd.DataFrame(columns=['Column name', 'Start index', 'Stop index', 'Amount of NaNs'])
        length = len(output)
        column_names = []
        starts = []
        stops = []
        amounts = []

        for column in range(length):
            #print('At iteration %s of %s' % (column, length))
            for i in range(len(output[column])):
                column_names.append(df.columns[column])
                starts.append(output[column][i][0])
                stops.append(output[column][i][1])
                amounts.append(output[column][i][2])

        print('Appending NaN info to df')
        # Convert list to pd series
        column_names = pd.Series(column_names)
        starts = pd.Series(starts)
        stops = pd.Series(stops)
        amounts = pd.Series(amounts)
        # Append pd series to a column
        df_info['Column name'] = column_names.values
        df_info['Start index'] = starts.values
        df_info['Stop index'] = stops.values
        df_info['Amount of NaNs'] = amounts.values

        percentage = (df_info['Amount of NaNs'] / len(df)) * 100
        df_info.drop(df_info[percentage < threshold_percentage].index, inplace=True)
        return df_info

    df_info = list_to_df(output)
    
    return df_info


def save_df_unprocessed(df, dwelling_id):
    """
    Save unprocessed dataframe.
    :param df: Pandas DataFrame
    :param dwelling_id: String
    :return: None
    """
    dir = 'F://datc//opschaler//combined_gas_smart_weather_dfs//unprocessed//'
    df.to_csv(dir + dwelling_id + '.csv', sep='\t', index=True)
    print('Saved unprocessed df: %s' % dwelling_id)
    return


@delayed
def drop_nan_streaks_above_threshold(df, df_nan_table, thresholds):
    """
    Drops NaN streaks from the df when they are larger then the threshold value.
    This function also inputs df_nan_table because it already has been made in the smart_gas_nan_checker.
    :param df: Pandas DataDrame to process NaNs off
    :param df_nan_table: NaN info Pandas DataFrame of the input df
    :param thresholds: Dictionary {'column_name':column_threshold}, column_threshold has to be an integer.
    :return: Pandas DataFrame
    """
    df_nan_table = df_nan_table.compute()

    # Check for NaN streaks > threshold and drop them from the df
    length = len(df_nan_table['Amount of NaNs'])
    print('df_nan_table length: %s' % length)

    indices_to_drop = []
    for i, amount in enumerate(df_nan_table['Amount of NaNs']):
        selected_column = df_nan_table['Column name'][i]
        try:
            if amount > thresholds[selected_column]:
                start_index = (df_nan_table['Start index'][i])
                stop_index = (df_nan_table['Stop index'][i])
                indices = df[start_index:stop_index].index
                print('Enumeration %s of %s | From \t %s \t to \t %s | column %s | NaN streak length: %s'
                      % (i, length, start_index, stop_index, selected_column, (len(indices))))
                try:
                    indices_to_drop += indices
                except:
                    print('Could not add indices to indices_to_drop list')
            else:
                #print('amount < threshold')
                pass
        except:
            #print('No threshold detected for %s' % selected_column)
            pass

    print('Dropping NaN streaks > threshold')
    l1 = len(df)
    df = df.drop(indices_to_drop)
    l2 = len(df)
    print('Removed %s rows' % (l1-l2))
    return df


def save_df_processed(df, dwelling_id):
    """
    Save interpolated dataframe.
    :param df: Pandas DataFrame
    :param dwelling_id: String
    :return: None
    """
    dir = 'F://datc//opschaler//combined_gas_smart_weather_dfs//processed//'
    df.to_csv(dir + dwelling_id + '.csv', sep='\t', index=True)
    print('Saved processed df: %s' % dwelling_id)
    return

# %% [markdown]
# # Main loop

# %%
# %%time

client.restart()

weather = read_weather_data()
weather_rs = weather.resample('10min').mean()


file_paths, dwelling_ids = smartmeter_data()

#file_paths = file_paths[:5]

dfs_hour = []
dfs_10s = []
dfs_nan_table_10s = []
dfs_nan_table_hour = []

dfs_10s_partly_processed = []
dfs_hour_partly_processed = []

smarts = []
gass = []
weather_result = []


for i, path in enumerate(file_paths):
    dwelling_id = dwelling_ids[i]
    
    smart, gas = clean_prepare_smart_gas(path, dwelling_id)
    
    # client.persist: Start computing these variables and keep them in memory
    smart = smart.persist()
    gas = gas.persist()

    smart, gas = resample_dfs_to_default_sample_rate(smart, gas)
    
    smart = smart.persist()
    gas = gas.persist()
    
    df_hour = create_hour_df(smart, gas, weather_rs, dwelling_id)
    df_10s = create_10s_df(smart, gas, weather_rs, dwelling_id)
    
    df_hour = df_hour.persist()
    df_10s = df_10s.persist()
    
    #Slow, plus low cpu usage...
    #fig = plot_nans(df_10s, dwelling_id+' 10s sample rate', '1T')
    
    df_nan_table_10s = df_nan_checker(df_10s, 0)
    df_nan_table_hour = df_nan_checker(df_hour, 0)
    
    df_nan_table_10s = df_nan_table_10s.persist()
    df_nan_table_hour = df_nan_table_hour.persist()
    
    thresholds_10s = {'eMeter': 6, 'ePower': 6, 'gasMeter': 72, 'T': 36, 'Q': 18}
    df_10s_partly_processed = drop_nan_streaks_above_threshold(df_10s, df_nan_table_10s, thresholds_10s)
    df_10s_partly_processed = df_10s_partly_processed.persist()
    
    thresholds_hour = {'eMeter': 2, 'ePower': 2, 'gasMeter': 2, 'T': 1, 'Q': 1}
    df_hour_partly_processed = drop_nan_streaks_above_threshold(df_hour, df_nan_table_hour, thresholds_hour)
    df_hour_partly_processed = df_hour_partly_processed.persist()
    
    # Append results
    smarts.append(smart)
    gass.append(gas)
    dfs_hour.append(df_hour)
    dfs_10s.append(df_10s)
    dfs_nan_table_10s.append(df_nan_table_10s)
    dfs_nan_table_hour.append(df_nan_table_hour)
    
    dfs_10s_partly_processed.append(df_10s_partly_processed)
    dfs_hour_partly_processed.append(df_hour_partly_processed)
# Out:
# Detected 56 smartmeter_data files.
# Wall time: 18 s
# c:\program files\python36\lib\site-packages\pandas\core\base.py:126: FutureWarning:
# .resample() is now a deferred operation
# You called memory_usage(...) on this deferred object which materialized it into a dataframe
# by implicitly taking the mean.  Use .resample(...).mean() instead
#   if hasattr(self, 'memory_usage'):
# c:\program files\python36\lib\site-packages\pandas\core\base.py:127: FutureWarning:
# .resample() is now a deferred operation
# You called memory_usage(...) on this deferred object which materialized it into a dataframe
# by implicitly taking the mean.  Use .resample(...).mean() instead
#   mem = self.memory_usage(deep=True)
# Appending NaN info to df
# Appending NaN info to df
# Appending NaN info to dfAppending NaN info to dfAppending NaN info to dfAppending NaN info to df
#
#
#
# df_nan_table length: 61
# Enumeration 1 of 61 | From 	 2017-07-14 14:00:00 	 to 	 2017-07-18 03:00:00 | column eMeter | NaN streak length: 86
# Enumeration 9 of 61 | From 	 2017-07-14 14:00:00 	 to 	 2017-07-18 03:00:00 | column ePower | NaN streak length: 86
# Enumeration 15 of 61 | From 	 2017-07-14 14:00:00 	 to 	 2017-07-18 03:00:00 | column gasMeter | NaN streak length: 86
# Enumeration 52 of 61 | From 	 2017-07-08 17:00:00 	 to 	 2017-07-08 21:00:00 | column Q | NaN streak length: 5
# Enumeration 55 of 61 | From 	 2017-07-08 17:00:00 	 to 	 2017-07-08 21:00:00 | column T | NaN streak length: 5
# Dropping NaN streaks > threshold
# Removed 91 rows
# df_nan_table length: 44
# Enumeration 3 of 44 | From 	 2017-04-04 18:00:00 	 to 	 2017-04-07 07:00:00 | column eMeter | NaN streak length: 62
# Enumeration 19 of 44 | From 	 2017-04-04 18:00:00 	 to 	 2017-04-07 07:00:00 | column ePower | NaN streak length: 62
# Enumeration 28 of 44 | From 	 2017-04-04 18:00:00 	 to 	 2017-04-07 07:00:00 | column gasMeter | NaN streak length: 62
# Dropping NaN streaks > threshold
# Removed 62 rows
# Appending NaN info to df
# df_nan_table length: 36Appending NaN info to dfdf_nan_table length: 48
#
# df_nan_table length: 38df_nan_table length: 48
# Enumeration 1 of 36 | From 	 2017-07-14 14:00:00 	 to 	 2017-07-18 03:00:00 | column eMeter | NaN streak length: 86
#
#
# Enumeration 1 of 48 | From 	 2017-07-14 14:00:00 	 to 	 2017-07-18 03:00:00 | column eMeter | NaN streak length: 86Appending NaN info to dfEnumeration 9 of 36 | From 	 2017-07-14 14:00:00 	 to 	 2017-07-18 03:00:00 | column ePower | NaN streak length: 86
# Enumeration 3 of 38 | From 	 2017-04-04 18:00:00 	 to 	 2017-04-07 07:00:00 | column eMeter | NaN streak length: 62
# Enumeration 1 of 48 | From 	 2017-07-14 14:00:00 	 to 	 2017-07-18 03:00:00 | column eMeter | NaN streak length: 86Enumeration 2 of 48 | From 	 2017-08-01 11:00:00 	 to 	 2017-09-05 15:00:00 | column eMeter | NaN streak length: 845
#
#
#
# Enumeration 13 of 36 | From 	 2017-07-14 14:00:00 	 to 	 2017-07-18 03:00:00 | column gasMeter | NaN streak length: 86Enumeration 23 of 38 | From 	 2017-04-04 18:00:00 	 to 	 2017-04-07 07:00:00 | column ePower | NaN streak length: 62Enumeration 2 of 48 | From 	 2017-08-09 03:00:00 	 to 	 2017-09-05 15:00:00 | column eMeter | NaN streak length: 661Enumeration 13 of 48 | From 	 2017-07-14 14:00:00 	 to 	 2017-07-18 03:00:00 | column ePower | NaN streak length: 86
#
#
#
# Enumeration 27 of 36 | From 	 2017-07-08 17:00:00 	 to 	 2017-07-08 21:00:00 | column Q | NaN streak length: 5Enumeration 32 of 38 | From 	 2017-04-04 18:00:00 	 to 	 2017-04-07 07:00:00 | column gasMeter | NaN streak length: 62Enumeration 13 of 48 | From 	 2017-07-14 14:00:00 	 to 	 2017-07-18 03:00:00 | column ePower | NaN streak length: 86Enumeration 14 of 48 | From 	 2017-08-01 11:00:00 	 to 	 2017-09-05 15:00:00 | column ePower | NaN streak length: 845
#
#
#
# Enumeration 30 of 36 | From 	 2017-07-08 17:00:00 	 to 	 2017-07-08 21:00:00 | column T | NaN streak length: 5Dropping NaN streaks > thresholdEnumeration 14 of 48 | From 	 2017-08-09 03:00:00 	 to 	 2017-09-05 15:00:00 | column ePower | NaN streak length: 661Enumeration 18 of 48 | From 	 2017-07-14 14:00:00 	 to 	 2017-07-18 03:00:00 | column gasMeter | NaN streak length: 86
#
#
#
# Dropping NaN streaks > thresholdEnumeration 18 of 48 | From 	 2017-07-14 14:00:00 	 to 	 2017-07-18 03:00:00 | column gasMeter | NaN streak length: 86Removed 62 rows
# Enumeration 19 of 48 | From 	 2017-08-01 11:00:00 	 to 	 2017-09-05 15:00:00 | column gasMeter | NaN streak length: 845
#
#
# Removed 91 rowsEnumeration 20 of 48 | From 	 2017-08-09 03:00:00 	 to 	 2017-09-05 15:00:00 | column gasMeter | NaN streak length: 661Enumeration 39 of 48 | From 	 2017-07-08 17:00:00 	 to 	 2017-07-08 21:00:00 | column Q | NaN streak length: 5
#
#
# Enumeration 39 of 48 | From 	 2017-07-08 17:00:00 	 to 	 2017-07-08 21:00:00 | column Q | NaN streak length: 5
# Enumeration 42 of 48 | From 	 2017-07-08 17:00:00 	 to 	 2017-07-08 21:00:00 | column T | NaN streak length: 5Enumeration 42 of 48 | From 	 2017-07-08 17:00:00 	 to 	 2017-07-08 21:00:00 | column T | NaN streak length: 5
#
# Dropping NaN streaks > thresholddf_nan_table length: 11432df_nan_table length: 53370Dropping NaN streaks > threshold
#
#
#
# Enumeration 0 of 11432 | From 	 2017-03-16 08:36:20 	 to 	 2017-03-16 08:59:50 | column eMeter | NaN streak length: 142Removed 752 rowsRemoved 936 rows
# Enumeration 1604 of 53370 | From 	 2017-07-14 13:54:10 	 to 	 2017-07-18 04:34:20 | column eMeter | NaN streak length: 31202
#
# Enumeration 1 of 11432 | From 	 2017-03-16 09:00:10 	 to 	 2017-03-16 09:59:50 | column eMeter | NaN streak length: 359
#
# Enumeration 2 of 11432 | From 	 2017-03-16 10:00:10 	 to 	 2017-03-16 10:59:50 | column eMeter | NaN streak length: 359Enumeration 3514 of 53370 | From 	 2017-08-13 00:16:50 	 to 	 2017-08-13 01:17:40 | column eMeter | NaN streak length: 366
#
# Enumeration 3 of 11432 | From 	 2017-03-16 11:00:10 	 to 	 2017-03-16 11:59:50 | column eMeter | NaN streak length: 359Enumeration 3905 of 53370 | From 	 2017-08-18 00:44:30 	 to 	 2017-08-18 01:45:10 | column eMeter | NaN streak length: 365
# df_nan_table length: 58291
#
# Enumeration 3912 of 53370 | From 	 2017-08-18 02:53:50 	 to 	 2017-08-18 03:14:30 | column eMeter | NaN streak length: 125Enumeration 4 of 11432 | From 	 2017-03-16 12:00:10 	 to 	 2017-03-16 12:59:50 | column eMeter | NaN streak length: 359
#
# Enumeration 925 of 58291 | From 	 2017-07-10 05:44:00 	 to 	 2017-07-10 06:44:50 | column eMeter | NaN streak length: 366Enumeration 5 of 11432 | From 	 2017-03-16 13:00:10 	 to 	 2017-03-16 13:59:50 | column eMeter | NaN streak length: 359
#
# Enumeration 1165 of 58291 | From 	 2017-07-12 19:33:40 	 to 	 2017-07-12 20:34:30 | column eMeter | NaN streak length: 366Enumeration 6 of 11432 | From 	 2017-03-16 14:00:10 	 to 	 2017-03-16 14:59:50 | column eMeter | NaN streak length: 359
#
# Enumeration 1334 of 58291 | From 	 2017-07-14 13:54:10 	 to 	 2017-07-18 04:34:10 | column eMeter | NaN streak length: 31201
# Enumeration 7 of 11432 | From 	 2017-03-16 15:00:10 	 to 	 2017-03-16 15:59:50 | column eMeter | NaN streak length: 359
# Enumeration 2562 of 58291 | From 	 2017-08-01 10:30:00 	 to 	 2017-09-05 16:58:30 | column eMeter | NaN streak length: 304732Enumeration 8 of 11432 | From 	 2017-03-16 16:00:10 	 to 	 2017-03-16 16:59:50 | column eMeter | NaN streak length: 359Enumeration 33610 of 53370 | From 	 2017-07-14 13:54:10 	 to 	 2017-07-18 04:34:20 | column ePower | NaN streak length: 31202
#
#
# Enumeration 9 of 11432 | From 	 2017-03-16 17:00:10 	 to 	 2017-03-16 17:59:50 | column eMeter | NaN streak length: 359Enumeration 35520 of 53370 | From 	 2017-08-13 00:16:50 	 to 	 2017-08-13 01:17:40 | column ePower | NaN streak length: 366
#
# Enumeration 10 of 11432 | From 	 2017-03-16 18:00:10 	 to 	 2017-03-16 18:59:50 | column eMeter | NaN streak length: 359Enumeration 35911 of 53370 | From 	 2017-08-18 00:44:30 	 to 	 2017-08-18 01:45:10 | column ePower | NaN streak length: 365
#
# Enumeration 11 of 11432 | From 	 2017-03-16 19:00:10 	 to 	 2017-03-16 19:59:50 | column eMeter | NaN streak length: 359Enumeration 35918 of 53370 | From 	 2017-08-18 02:53:50 	 to 	 2017-08-18 03:14:30 | column ePower | NaN streak length: 125
# Enumeration 2895 of 58291 | From 	 2017-09-09 14:45:40 	 to 	 2017-09-09 15:46:20 | column eMeter | NaN streak length: 365
# Enumeration 12 of 11432 | From 	 2017-03-16 20:00:10 	 to 	 2017-03-16 20:59:50 | column eMeter | NaN streak length: 359
#
# Enumeration 2896 of 58291 | From 	 2017-09-09 16:54:50 	 to 	 2017-09-09 16:59:40 | column eMeter | NaN streak length: 30Enumeration 13 of 11432 | From 	 2017-03-16 21:00:10 	 to 	 2017-03-16 21:59:50 | column eMeter | NaN streak length: 359
#
# Enumeration 14 of 11432 | From 	 2017-03-16 22:00:10 	 to 	 2017-03-16 22:59:50 | column eMeter | NaN streak length: 359
# Enumeration 15 of 11432 | From 	 2017-03-16 23:00:10 	 to 	 2017-03-16 23:59:50 | column eMeter | NaN streak length: 359
# Enumeration 51282 of 53370 | From 	 2017-07-05 17:00:00 	 to 	 2017-07-05 17:59:50 | column gasMeter | NaN streak length: 360Enumeration 16 of 11432 | From 	 2017-03-17 00:00:10 	 to 	 2017-03-17 00:59:50 | column eMeter | NaN streak length: 359
# Enumeration 51283 of 53370 | From 	 2017-07-08 05:00:00 	 to 	 2017-07-08 05:59:50 | column gasMeter | NaN streak length: 360
# Enumeration 17 of 11432 | From 	 2017-03-17 01:00:10 	 to 	 2017-03-17 01:59:50 | column eMeter | NaN streak length: 359
#
# Enumeration 51284 of 53370 | From 	 2017-07-08 07:00:00 	 to 	 2017-07-08 07:59:50 | column gasMeter | NaN streak length: 360Enumeration 38277 of 58291 | From 	 2017-07-10 05:44:00 	 to 	 2017-07-10 06:44:50 | column ePower | NaN streak length: 366
# Enumeration 18 of 11432 | From 	 2017-03-17 02:00:10 	 to 	 2017-03-17 02:59:50 | column eMeter | NaN streak length: 359
# Enumeration 51285 of 53370 | From 	 2017-07-14 14:00:00 	 to 	 2017-07-18 03:59:50 | column gasMeter | NaN streak length: 30960
#
# Enumeration 38517 of 58291 | From 	 2017-07-12 19:33:40 	 to 	 2017-07-12 20:34:30 | column ePower | NaN streak length: 366Enumeration 19 of 11432 | From 	 2017-03-17 03:00:10 	 to 	 2017-03-17 03:59:50 | column eMeter | NaN streak length: 359
#
# Enumeration 51286 of 53370 | From 	 2017-07-20 12:00:00 	 to 	 2017-07-20 12:59:50 | column gasMeter | NaN streak length: 360Enumeration 20 of 11432 | From 	 2017-03-17 04:00:10 	 to 	 2017-03-17 04:59:50 | column eMeter | NaN streak length: 359
# Enumeration 38686 of 58291 | From 	 2017-07-14 13:54:10 	 to 	 2017-07-18 04:34:10 | column ePower | NaN streak length: 31201
#
# Enumeration 51287 of 53370 | From 	 2017-08-14 17:00:00 	 to 	 2017-08-14 17:59:50 | column gasMeter | NaN streak length: 360Enumeration 21 of 11432 | From 	 2017-03-17 05:00:10 	 to 	 2017-03-17 05:59:50 | column eMeter | NaN streak length: 359
#
# Enumeration 51288 of 53370 | From 	 2017-08-20 09:00:00 	 to 	 2017-08-20 09:59:50 | column gasMeter | NaN streak length: 360Enumeration 39914 of 58291 | From 	 2017-08-01 10:30:00 	 to 	 2017-09-05 16:58:30 | column ePower | NaN streak length: 304732Enumeration 22 of 11432 | From 	 2017-03-17 06:00:10 	 to 	 2017-03-17 06:59:50 | column eMeter | NaN streak length: 359
#
#
# Enumeration 51289 of 53370 | From 	 2017-08-20 14:00:00 	 to 	 2017-08-20 14:59:50 | column gasMeter | NaN streak length: 360Enumeration 23 of 11432 | From 	 2017-03-17 07:00:10 	 to 	 2017-03-17 07:59:50 | column eMeter | NaN streak length: 359
#
# Enumeration 51290 of 53370 | From 	 2017-08-23 04:00:00 	 to 	 2017-08-23 04:59:50 | column gasMeter | NaN streak length: 360Enumeration 24 of 11432 | From 	 2017-03-17 08:00:10 	 to 	 2017-03-17 08:59:50 | column eMeter | NaN streak length: 359
# Enumeration 40247 of 58291 | From 	 2017-09-09 14:45:40 	 to 	 2017-09-09 15:46:20 | column ePower | NaN streak length: 365
# Enumeration 51291 of 53370 | From 	 2017-08-27 02:00:00 	 to 	 2017-08-27 03:59:50 | column gasMeter | NaN streak length: 720
#
# Enumeration 25 of 11432 | From 	 2017-03-17 09:00:10 	 to 	 2017-03-17 09:59:50 | column eMeter | NaN streak length: 359Enumeration 40248 of 58291 | From 	 2017-09-09 16:54:50 	 to 	 2017-09-09 16:59:40 | column ePower | NaN streak length: 30Enumeration 51292 of 53370 | From 	 2017-08-27 07:00:00 	 to 	 2017-08-27 07:59:50 | column gasMeter | NaN streak length: 360
#
# Enumeration 51293 of 53370 | From 	 2017-08-29 02:00:00 	 to 	 2017-08-29 02:59:50 | column gasMeter | NaN streak length: 360Enumeration 26 of 11432 | From 	 2017-03-17 10:00:10 	 to 	 2017-03-17 10:59:50 | column eMeter | NaN streak length: 359
#
#
# Enumeration 51294 of 53370 | From 	 2017-10-14 18:00:00 	 to 	 2017-10-14 18:59:50 | column gasMeter | NaN streak length: 360Enumeration 27 of 11432 | From 	 2017-03-17 11:00:10 	 to 	 2017-03-17 11:59:50 | column eMeter | NaN streak length: 359
#
# Enumeration 51295 of 53370 | From 	 2017-10-19 09:00:00 	 to 	 2017-10-19 09:59:50 | column gasMeter | NaN streak length: 360Enumeration 28 of 11432 | From 	 2017-03-17 12:00:10 	 to 	 2017-03-17 12:59:50 | column eMeter | NaN streak length: 359
#
# Enumeration 29 of 11432 | From 	 2017-03-17 13:00:10 	 to 	 2017-03-17 13:59:50 | column eMeter | NaN streak length: 359Enumeration 51296 of 53370 | From 	 2017-10-21 16:00:00 	 to 	 2017-10-21 16:59:50 | column gasMeter | NaN streak length: 360
#
# Enumeration 56028 of 58291 | From 	 2017-07-14 14:00:00 	 to 	 2017-07-18 03:59:50 | column gasMeter | NaN streak length: 30960Enumeration 30 of 11432 | From 	 2017-03-17 14:00:10 	 to 	 2017-03-17 14:59:50 | column eMeter | NaN streak length: 359
# Enumeration 52138 of 53370 | From 	 2017-06-23 02:00:00 	 to 	 2017-06-23 02:09:50 | column Q | NaN streak length: 60
#
# Enumeration 56029 of 58291 | From 	 2017-08-01 11:00:00 	 to 	 2017-09-05 15:59:50 | column gasMeter | NaN streak length: 304200
# Enumeration 31 of 11432 | From 	 2017-03-17 15:00:10 	 to 	 2017-03-17 15:59:50 | column eMeter | NaN streak length: 359Enumeration 52139 of 53370 | From 	 2017-06-24 02:00:00 	 to 	 2017-06-24 02:09:50 | column Q | NaN streak length: 60
#
# Enumeration 52140 of 53370 | From 	 2017-06-25 02:00:00 	 to 	 2017-06-25 02:09:50 | column Q | NaN streak length: 60Enumeration 32 of 11432 | From 	 2017-03-17 16:00:10 	 to 	 2017-03-17 16:59:50 | column eMeter | NaN streak length: 359
#
# Enumeration 33 of 11432 | From 	 2017-03-17 17:00:10 	 to 	 2017-03-17 17:59:50 | column eMeter | NaN streak length: 359Enumeration 52141 of 53370 | From 	 2017-06-26 02:00:00 	 to 	 2017-06-26 02:09:50 | column Q | NaN streak length: 60
#
# Enumeration 56030 of 58291 | From 	 2017-09-19 10:00:00 	 to 	 2017-09-19 10:59:50 | column gasMeter | NaN streak length: 360Enumeration 34 of 11432 | From 	 2017-03-17 18:00:10 	 to 	 2017-03-17 18:59:50 | column eMeter | NaN streak length: 359Enumeration 52142 of 53370 | From 	 2017-06-27 02:00:00 	 to 	 2017-06-27 02:09:50 | column Q | NaN streak length: 60
#
#
# Enumeration 35 of 11432 | From 	 2017-03-17 19:00:10 	 to 	 2017-03-17 19:59:50 | column eMeter | NaN streak length: 359Enumeration 56031 of 58291 | From 	 2017-10-08 21:00:00 	 to 	 2017-10-08 21:59:50 | column gasMeter | NaN streak length: 360Enumeration 52143 of 53370 | From 	 2017-06-28 02:00:00 	 to 	 2017-06-28 02:09:50 | column Q | NaN streak length: 60
#
#
# Enumeration 36 of 11432 | From 	 2017-03-17 20:00:10 	 to 	 2017-03-17 20:59:50 | column eMeter | NaN streak length: 359Enumeration 56032 of 58291 | From 	 2017-10-17 04:00:00 	 to 	 2017-10-17 05:59:50 | column gasMeter | NaN streak length: 720Enumeration 52144 of 53370 | From 	 2017-06-29 02:00:00 	 to 	 2017-06-29 02:09:50 | column Q | NaN streak length: 60
#
#
# Enumeration 37 of 11432 | From 	 2017-03-17 21:00:10 	 to 	 2017-03-17 21:59:50 | column eMeter | NaN streak length: 359Enumeration 52145 of 53370 | From 	 2017-06-30 02:00:00 	 to 	 2017-06-30 02:09:50 | column Q | NaN streak length: 60Enumeration 56942 of 58291 | From 	 2017-06-30 02:00:00 	 to 	 2017-06-30 02:09:50 | column Q | NaN streak length: 60
#
# Enumeration 38 of 11432 | From 	 2017-03-17 22:00:10 	 to 	 2017-03-17 22:59:50 | column eMeter | NaN streak length: 359
# Enumeration 52146 of 53370 | From 	 2017-07-01 02:00:00 	 to 	 2017-07-01 02:09:50 | column Q | NaN streak length: 60Enumeration 56943 of 58291 | From 	 2017-07-01 02:00:00 	 to 	 2017-07-01 02:09:50 | column Q | NaN streak length: 60
#
#
# Enumeration 39 of 11432 | From 	 2017-03-17 23:00:10 	 to 	 2017-03-17 23:59:50 | column eMeter | NaN streak length: 359Enumeration 52147 of 53370 | From 	 2017-07-02 02:00:00 	 to 	 2017-07-02 02:09:50 | column Q | NaN streak length: 60
#
# Enumeration 56944 of 58291 | From 	 2017-07-02 02:00:00 	 to 	 2017-07-02 02:09:50 | column Q | NaN streak length: 60
# Enumeration 40 of 11432 | From 	 2017-03-18 00:00:10 	 to 	 2017-03-18 00:59:50 | column eMeter | NaN streak length: 359Enumeration 52148 of 53370 | From 	 2017-07-03 02:00:00 	 to 	 2017-07-03 02:09:50 | column Q | NaN streak length: 60
#
# Enumeration 56945 of 58291 | From 	 2017-07-03 02:00:00 	 to 	 2017-07-03 02:09:50 | column Q | NaN streak length: 60
# Enumeration 52149 of 53370 | From 	 2017-07-04 02:00:00 	 to 	 2017-07-04 02:09:50 | column Q | NaN streak length: 60Enumeration 41 of 11432 | From 	 2017-03-18 01:00:10 	 to 	 2017-03-18 01:59:50 | column eMeter | NaN streak length: 359Enumeration 56946 of 58291 | From 	 2017-07-04 02:00:00 	 to 	 2017-07-04 02:09:50 | column Q | NaN streak length: 60
#
#
# Enumeration 52150 of 53370 | From 	 2017-07-05 02:00:00 	 to 	 2017-07-05 02:09:50 | column Q | NaN streak length: 60Enumeration 42 of 11432 | From 	 2017-03-18 02:00:10 	 to 	 2017-03-18 02:59:50 | column eMeter | NaN streak length: 359
#
# Enumeration 56947 of 58291 | From 	 2017-07-05 02:00:00 	 to 	 2017-07-05 02:09:50 | column Q | NaN streak length: 60Enumeration 43 of 11432 | From 	 2017-03-18 03:00:10 	 to 	 2017-03-18 03:59:50 | column eMeter | NaN streak length: 359
# Enumeration 52151 of 53370 | From 	 2017-07-06 02:00:00 	 to 	 2017-07-06 02:09:50 | column Q | NaN streak length: 60
#
# Enumeration 56948 of 58291 | From 	 2017-07-06 02:00:00 	 to 	 2017-07-06 02:09:50 | column Q | NaN streak length: 60
# Enumeration 44 of 11432 | From 	 2017-03-18 04:00:10 	 to 	 2017-03-18 04:59:50 | column eMeter | NaN streak length: 359Enumeration 52152 of 53370 | From 	 2017-07-07 02:00:00 	 to 	 2017-07-07 02:09:50 | column Q | NaN streak length: 60
# Enumeration 56949 of 58291 | From 	 2017-07-07 02:00:00 	 to 	 2017-07-07 02:09:50 | column Q | NaN streak length: 60
# Enumeration 45 of 11432 | From 	 2017-03-18 05:00:10 	 to 	 2017-03-18 05:59:50 | column eMeter | NaN streak length: 359
# Enumeration 52153 of 53370 | From 	 2017-07-08 02:00:00 	 to 	 2017-07-08 02:09:50 | column Q | NaN streak length: 60
#
# Enumeration 46 of 11432 | From 	 2017-03-18 06:00:10 	 to 	 2017-03-18 06:59:50 | column eMeter | NaN streak length: 359Enumeration 56950 of 58291 | From 	 2017-07-08 02:00:00 	 to 	 2017-07-08 02:09:50 | column Q | NaN streak length: 60
#
# Enumeration 52154 of 53370 | From 	 2017-07-08 16:30:00 	 to 	 2017-07-08 22:19:50 | column Q | NaN streak length: 2100Enumeration 47 of 11432 | From 	 2017-03-18 07:00:10 	 to 	 2017-03-18 07:59:50 | column eMeter | NaN streak length: 359
# Enumeration 56951 of 58291 | From 	 2017-07-08 16:30:00 	 to 	 2017-07-08 22:19:50 | column Q | NaN streak length: 2100
#
# Enumeration 52155 of 53370 | From 	 2017-07-09 00:10:00 	 to 	 2017-07-09 00:49:50 | column Q | NaN streak length: 240Enumeration 56952 of 58291 | From 	 2017-07-09 00:10:00 	 to 	 2017-07-09 00:49:50 | column Q | NaN streak length: 240
# Enumeration 48 of 11432 | From 	 2017-03-18 08:00:10 	 to 	 2017-03-18 08:59:50 | column eMeter | NaN streak length: 359
#
# Enumeration 52156 of 53370 | From 	 2017-07-09 02:00:00 	 to 	 2017-07-09 02:09:50 | column Q | NaN streak length: 60Enumeration 56953 of 58291 | From 	 2017-07-09 02:00:00 	 to 	 2017-07-09 02:09:50 | column Q | NaN streak length: 60Enumeration 49 of 11432 | From 	 2017-03-18 09:00:10 	 to 	 2017-03-18 09:59:50 | column eMeter | NaN streak length: 359
#
#
# Enumeration 52157 of 53370 | From 	 2017-07-10 02:00:00 	 to 	 2017-07-10 02:09:50 | column Q | NaN streak length: 60Enumeration 56954 of 58291 | From 	 2017-07-10 02:00:00 	 to 	 2017-07-10 02:09:50 | column Q | NaN streak length: 60Enumeration 50 of 11432 | From 	 2017-03-18 10:00:10 	 to 	 2017-03-18 10:59:50 | column eMeter | NaN streak length: 359
#
#
# Enumeration 52158 of 53370 | From 	 2017-07-11 02:00:00 	 to 	 2017-07-11 02:09:50 | column Q | NaN streak length: 60Enumeration 56955 of 58291 | From 	 2017-07-11 02:00:00 	 to 	 2017-07-11 02:09:50 | column Q | NaN streak length: 60Enumeration 51 of 11432 | From 	 2017-03-18 11:00:10 	 to 	 2017-03-18 11:59:50 | column eMeter | NaN streak length: 359
#
#
# Enumeration 52 of 11432 | From 	 2017-03-18 12:00:10 	 to 	 2017-03-18 12:59:50 | column eMeter | NaN streak length: 359Enumeration 52159 of 53370 | From 	 2017-07-12 02:00:00 	 to 	 2017-07-12 02:09:50 | column Q | NaN streak length: 60Enumeration 56956 of 58291 | From 	 2017-07-12 02:00:00 	 to 	 2017-07-12 02:09:50 | column Q | NaN streak length: 60
#
#
# Enumeration 52160 of 53370 | From 	 2017-07-13 02:00:00 	 to 	 2017-07-13 02:09:50 | column Q | NaN streak length: 60Enumeration 53 of 11432 | From 	 2017-03-18 13:00:10 	 to 	 2017-03-18 13:59:50 | column eMeter | NaN streak length: 359
# Enumeration 56957 of 58291 | From 	 2017-07-13 02:00:00 	 to 	 2017-07-13 02:09:50 | column Q | NaN streak length: 60
#
# Enumeration 52161 of 53370 | From 	 2017-07-13 20:10:00 	 to 	 2017-07-13 20:19:50 | column Q | NaN streak length: 60Enumeration 54 of 11432 | From 	 2017-03-18 14:00:10 	 to 	 2017-03-18 14:59:50 | column eMeter | NaN streak length: 359
# Enumeration 56958 of 58291 | From 	 2017-07-13 20:10:00 	 to 	 2017-07-13 20:19:50 | column Q | NaN streak length: 60
# Enumeration 52162 of 53370 | From 	 2017-07-14 02:00:00 	 to 	 2017-07-14 02:09:50 | column Q | NaN streak length: 60
# Enumeration 55 of 11432 | From 	 2017-03-18 15:00:10 	 to 	 2017-03-18 15:59:50 | column eMeter | NaN streak length: 359Enumeration 56959 of 58291 | From 	 2017-07-14 02:00:00 	 to 	 2017-07-14 02:09:50 | column Q | NaN streak length: 60
#
#
# Enumeration 56 of 11432 | From 	 2017-03-18 16:00:10 	 to 	 2017-03-18 16:59:50 | column eMeter | NaN streak length: 359Enumeration 52163 of 53370 | From 	 2017-07-15 02:00:00 	 to 	 2017-07-15 02:09:50 | column Q | NaN streak length: 60Enumeration 56960 of 58291 | From 	 2017-07-15 02:00:00 	 to 	 2017-07-15 02:09:50 | column Q | NaN streak length: 60
#
#
# Enumeration 57 of 11432 | From 	 2017-03-18 17:00:10 	 to 	 2017-03-18 17:59:50 | column eMeter | NaN streak length: 359Enumeration 52164 of 53370 | From 	 2017-07-16 02:00:00 	 to 	 2017-07-16 02:09:50 | column Q | NaN streak length: 60Enumeration 56961 of 58291 | From 	 2017-07-16 02:00:00 	 to 	 2017-07-16 02:09:50 | column Q | NaN streak length: 60
#
#
# Enumeration 58 of 11432 | From 	 2017-03-18 18:00:10 	 to 	 2017-03-18 18:59:50 | column eMeter | NaN streak length: 359Enumeration 52165 of 53370 | From 	 2017-07-17 02:00:00 	 to 	 2017-07-17 02:09:50 | column Q | NaN streak length: 60Enumeration 56962 of 58291 | From 	 2017-07-17 02:00:00 	 to 	 2017-07-17 02:09:50 | column Q | NaN streak length: 60
#
#
# Enumeration 59 of 11432 | From 	 2017-03-18 19:00:10 	 to 	 2017-03-18 19:59:50 | column eMeter | NaN streak length: 359Enumeration 52166 of 53370 | From 	 2017-07-18 02:00:00 	 to 	 2017-07-18 02:09:50 | column Q | NaN streak length: 60Enumeration 56963 of 58291 | From 	 2017-07-18 02:00:00 	 to 	 2017-07-18 02:09:50 | column Q | NaN streak length: 60
#
#
# Enumeration 60 of 11432 | From 	 2017-03-18 20:00:10 	 to 	 2017-03-18 20:59:50 | column eMeter | NaN streak length: 359Enumeration 52167 of 53370 | From 	 2017-07-19 02:00:00 	 to 	 2017-07-19 02:09:50 | column Q | NaN streak length: 60Enumeration 56964 of 58291 | From 	 2017-07-19 02:00:00 	 to 	 2017-07-19 02:09:50 | column Q | NaN streak length: 60
#
#
# Enumeration 61 of 11432 | From 	 2017-03-18 21:00:10 	 to 	 2017-03-18 21:59:50 | column eMeter | NaN streak length: 359
# Enumeration 52168 of 53370 | From 	 2017-07-20 02:00:00 	 to 	 2017-07-20 02:09:50 | column Q | NaN streak length: 60Enumeration 56965 of 58291 | From 	 2017-07-20 02:00:00 	 to 	 2017-07-20 02:09:50 | column Q | NaN streak length: 60
# Enumeration 62 of 11432 | From 	 2017-03-18 22:00:10 	 to 	 2017-03-18 22:59:50 | column eMeter | NaN streak length: 359
#
# Enumeration 56966 of 58291 | From 	 2017-07-21 02:00:00 	 to 	 2017-07-21 02:09:50 | column Q | NaN streak length: 60
# Enumeration 52169 of 53370 | From 	 2017-07-21 02:00:00 	 to 	 2017-07-21 02:09:50 | column Q | NaN streak length: 60Enumeration 63 of 11432 | From 	 2017-03-18 23:00:10 	 to 	 2017-03-18 23:59:50 | column eMeter | NaN streak length: 359Enumeration 56967 of 58291 | From 	 2017-07-22 02:00:00 	 to 	 2017-07-22 02:09:50 | column Q | NaN streak length: 60
#
#
# Enumeration 64 of 11432 | From 	 2017-03-19 00:00:10 	 to 	 2017-03-19 00:59:50 | column eMeter | NaN streak length: 359Enumeration 52170 of 53370 | From 	 2017-07-22 02:00:00 	 to 	 2017-07-22 02:09:50 | column Q | NaN streak length: 60Enumeration 56968 of 58291 | From 	 2017-07-23 02:00:00 	 to 	 2017-07-23 02:09:50 | column Q | NaN streak length: 60
#
#
# Enumeration 65 of 11432 | From 	 2017-03-19 01:00:10 	 to 	 2017-03-19 01:59:50 | column eMeter | NaN streak length: 359Enumeration 52171 of 53370 | From 	 2017-07-23 02:00:00 	 to 	 2017-07-23 02:09:50 | column Q | NaN streak length: 60Enumeration 56969 of 58291 | From 	 2017-07-24 02:00:00 	 to 	 2017-07-24 02:09:50 | column Q | NaN streak length: 60
#
#
# Enumeration 52172 of 53370 | From 	 2017-07-24 02:00:00 	 to 	 2017-07-24 02:09:50 | column Q | NaN streak length: 60Enumeration 66 of 11432 | From 	 2017-03-19 02:00:10 	 to 	 2017-03-19 02:59:50 | column eMeter | NaN streak length: 359Enumeration 56970 of 58291 | From 	 2017-07-25 02:00:00 	 to 	 2017-07-25 02:09:50 | column Q | NaN streak length: 60
#
#
# Enumeration 52173 of 53370 | From 	 2017-07-25 02:00:00 	 to 	 2017-07-25 02:09:50 | column Q | NaN streak length: 60Enumeration 56971 of 58291 | From 	 2017-07-26 02:00:00 	 to 	 2017-07-26 02:09:50 | column Q | NaN streak length: 60Enumeration 67 of 11432 | From 	 2017-03-19 03:00:10 	 to 	 2017-03-19 03:59:50 | column eMeter | NaN streak length: 359
#
#
# Enumeration 56972 of 58291 | From 	 2017-07-27 02:00:00 	 to 	 2017-07-27 02:09:50 | column Q | NaN streak length: 60Enumeration 52174 of 53370 | From 	 2017-07-26 02:00:00 	 to 	 2017-07-26 02:09:50 | column Q | NaN streak length: 60Enumeration 68 of 11432 | From 	 2017-03-19 04:00:10 	 to 	 2017-03-19 04:59:50 | column eMeter | NaN streak length: 359
#
#
# Enumeration 56973 of 58291 | From 	 2017-07-28 02:00:00 	 to 	 2017-07-28 02:09:50 | column Q | NaN streak length: 60Enumeration 69 of 11432 | From 	 2017-03-19 05:00:10 	 to 	 2017-03-19 05:59:50 | column eMeter | NaN streak length: 359Enumeration 52175 of 53370 | From 	 2017-07-27 02:00:00 	 to 	 2017-07-27 02:09:50 | column Q | NaN streak length: 60
#
#
# Enumeration 56974 of 58291 | From 	 2017-07-29 02:00:00 	 to 	 2017-07-29 02:09:50 | column Q | NaN streak length: 60Enumeration 70 of 11432 | From 	 2017-03-19 06:00:10 	 to 	 2017-03-19 06:59:50 | column eMeter | NaN streak length: 359Enumeration 52176 of 53370 | From 	 2017-07-28 02:00:00 	 to 	 2017-07-28 02:09:50 | column Q | NaN streak length: 60
#
#
# Enumeration 56975 of 58291 | From 	 2017-07-30 02:00:00 	 to 	 2017-07-30 02:09:50 | column Q | NaN streak length: 60Enumeration 52177 of 53370 | From 	 2017-07-29 02:00:00 	 to 	 2017-07-29 02:09:50 | column Q | NaN streak length: 60Enumeration 71 of 11432 | From 	 2017-03-19 07:00:10 	 to 	 2017-03-19 07:59:50 | column eMeter | NaN streak length: 359
#
#
# Enumeration 56976 of 58291 | From 	 2017-07-31 02:00:00 	 to 	 2017-07-31 02:09:50 | column Q | NaN streak length: 60Enumeration 52178 of 53370 | From 	 2017-07-30 02:00:00 	 to 	 2017-07-30 02:09:50 | column Q | NaN streak length: 60
# Enumeration 72 of 11432 | From 	 2017-03-19 08:00:10 	 to 	 2017-03-19 08:59:50 | column eMeter | NaN streak length: 359
#
# Enumeration 56977 of 58291 | From 	 2017-08-01 02:00:00 	 to 	 2017-08-01 02:09:50 | column Q | NaN streak length: 60Enumeration 52179 of 53370 | From 	 2017-07-31 02:00:00 	 to 	 2017-07-31 02:09:50 | column Q | NaN streak length: 60
# Enumeration 73 of 11432 | From 	 2017-03-19 09:00:10 	 to 	 2017-03-19 09:59:50 | column eMeter | NaN streak length: 359
#
# Enumeration 56978 of 58291 | From 	 2017-08-02 02:00:00 	 to 	 2017-08-02 02:09:50 | column Q | NaN streak length: 60Enumeration 52180 of 53370 | From 	 2017-08-01 02:00:00 	 to 	 2017-08-01 02:09:50 | column Q | NaN streak length: 60Enumeration 74 of 11432 | From 	 2017-03-19 10:00:10 	 to 	 2017-03-19 10:59:50 | column eMeter | NaN streak length: 359
#
#
# Enumeration 56979 of 58291 | From 	 2017-08-03 02:00:00 	 to 	 2017-08-03 02:09:50 | column Q | NaN streak length: 60Enumeration 52181 of 53370 | From 	 2017-08-02 02:00:00 	 to 	 2017-08-02 02:09:50 | column Q | NaN streak length: 60
#
# Enumeration 75 of 11432 | From 	 2017-03-19 11:00:10 	 to 	 2017-03-19 11:59:50 | column eMeter | NaN streak length: 359Enumeration 56980 of 58291 | From 	 2017-08-04 02:00:00 	 to 	 2017-08-04 02:09:50 | column Q | NaN streak length: 60
# Enumeration 52182 of 53370 | From 	 2017-08-03 02:00:00 	 to 	 2017-08-03 02:09:50 | column Q | NaN streak length: 60
#
# Enumeration 76 of 11432 | From 	 2017-03-19 12:00:10 	 to 	 2017-03-19 12:59:50 | column eMeter | NaN streak length: 359Enumeration 56981 of 58291 | From 	 2017-08-05 02:00:00 	 to 	 2017-08-05 02:09:50 | column Q | NaN streak length: 60
#
# Enumeration 52183 of 53370 | From 	 2017-08-04 02:00:00 	 to 	 2017-08-04 02:09:50 | column Q | NaN streak length: 60
# Enumeration 56982 of 58291 | From 	 2017-08-06 02:00:00 	 to 	 2017-08-06 02:09:50 | column Q | NaN streak length: 60Enumeration 77 of 11432 | From 	 2017-03-19 13:00:10 	 to 	 2017-03-19 13:59:50 | column eMeter | NaN streak length: 359
#
# Enumeration 52184 of 53370 | From 	 2017-08-05 02:00:00 	 to 	 2017-08-05 02:09:50 | column Q | NaN streak length: 60Enumeration 56983 of 58291 | From 	 2017-08-07 02:00:00 	 to 	 2017-08-07 02:09:50 | column Q | NaN streak length: 60Enumeration 78 of 11432 | From 	 2017-03-19 14:00:10 	 to 	 2017-03-19 14:59:50 | column eMeter | NaN streak length: 359
#
#
# Enumeration 52185 of 53370 | From 	 2017-08-06 02:00:00 	 to 	 2017-08-06 02:09:50 | column Q | NaN streak length: 60Enumeration 56984 of 58291 | From 	 2017-08-08 02:00:00 	 to 	 2017-08-08 02:09:50 | column Q | NaN streak length: 60Enumeration 79 of 11432 | From 	 2017-03-19 15:00:10 	 to 	 2017-03-19 15:59:50 | column eMeter | NaN streak length: 359
#
#
# Enumeration 56985 of 58291 | From 	 2017-08-09 02:00:00 	 to 	 2017-08-09 02:09:50 | column Q | NaN streak length: 60Enumeration 52186 of 53370 | From 	 2017-08-07 02:00:00 	 to 	 2017-08-07 02:09:50 | column Q | NaN streak length: 60Enumeration 80 of 11432 | From 	 2017-03-19 16:00:10 	 to 	 2017-03-19 16:59:50 | column eMeter | NaN streak length: 359
#
# Enumeration 56986 of 58291 | From 	 2017-08-10 02:00:00 	 to 	 2017-08-10 02:09:50 | column Q | NaN streak length: 60Enumeration 52187 of 53370 | From 	 2017-08-08 02:00:00 	 to 	 2017-08-08 02:09:50 | column Q | NaN streak length: 60
#
# Enumeration 81 of 11432 | From 	 2017-03-19 17:00:10 	 to 	 2017-03-19 17:59:50 | column eMeter | NaN streak length: 359
#
# Enumeration 56987 of 58291 | From 	 2017-08-11 02:00:00 	 to 	 2017-08-11 02:09:50 | column Q | NaN streak length: 60Enumeration 52188 of 53370 | From 	 2017-08-09 02:00:00 	 to 	 2017-08-09 02:09:50 | column Q | NaN streak length: 60
#
# Enumeration 82 of 11432 | From 	 2017-03-19 18:00:10 	 to 	 2017-03-19 18:59:50 | column eMeter | NaN streak length: 359
# Enumeration 56988 of 58291 | From 	 2017-08-12 02:00:00 	 to 	 2017-08-12 02:09:50 | column Q | NaN streak length: 60Enumeration 52189 of 53370 | From 	 2017-08-10 02:00:00 	 to 	 2017-08-10 02:09:50 | column Q | NaN streak length: 60Enumeration 83 of 11432 | From 	 2017-03-19 19:00:10 	 to 	 2017-03-19 19:59:50 | column eMeter | NaN streak length: 359
#
#
# Enumeration 52190 of 53370 | From 	 2017-08-11 02:00:00 	 to 	 2017-08-11 02:09:50 | column Q | NaN streak length: 60Enumeration 56989 of 58291 | From 	 2017-08-13 02:00:00 	 to 	 2017-08-13 02:09:50 | column Q | NaN streak length: 60Enumeration 84 of 11432 | From 	 2017-03-19 20:00:10 	 to 	 2017-03-19 20:59:50 | column eMeter | NaN streak length: 359
#
# Enumeration 56990 of 58291 | From 	 2017-08-14 02:00:00 	 to 	 2017-08-14 02:09:50 | column Q | NaN streak length: 60Enumeration 52191 of 53370 | From 	 2017-08-12 02:00:00 	 to 	 2017-08-12 02:09:50 | column Q | NaN streak length: 60
# Enumeration 85 of 11432 | From 	 2017-03-19 21:00:10 	 to 	 2017-03-19 21:59:50 | column eMeter | NaN streak length: 359
#
#
# Enumeration 56991 of 58291 | From 	 2017-08-15 02:00:00 	 to 	 2017-08-15 02:09:50 | column Q | NaN streak length: 60Enumeration 52192 of 53370 | From 	 2017-08-13 02:00:00 	 to 	 2017-08-13 02:09:50 | column Q | NaN streak length: 60
#
# Enumeration 86 of 11432 | From 	 2017-03-19 22:00:10 	 to 	 2017-03-19 22:59:50 | column eMeter | NaN streak length: 359Enumeration 52193 of 53370 | From 	 2017-08-14 02:00:00 	 to 	 2017-08-14 02:09:50 | column Q | NaN streak length: 60
# Enumeration 56992 of 58291 | From 	 2017-08-16 02:00:00 	 to 	 2017-08-16 02:09:50 | column Q | NaN streak length: 60
#
# Enumeration 87 of 11432 | From 	 2017-03-19 23:00:10 	 to 	 2017-03-19 23:59:50 | column eMeter | NaN streak length: 359Enumeration 56993 of 58291 | From 	 2017-08-17 02:00:00 	 to 	 2017-08-17 02:09:50 | column Q | NaN streak length: 60
# Enumeration 52194 of 53370 | From 	 2017-08-15 02:00:00 	 to 	 2017-08-15 02:09:50 | column Q | NaN streak length: 60
#
# Enumeration 88 of 11432 | From 	 2017-03-20 00:00:10 	 to 	 2017-03-20 00:59:50 | column eMeter | NaN streak length: 359Enumeration 56994 of 58291 | From 	 2017-08-18 02:00:00 	 to 	 2017-08-18 02:09:50 | column Q | NaN streak length: 60
#
# Enumeration 56995 of 58291 | From 	 2017-08-19 02:00:00 	 to 	 2017-08-19 02:09:50 | column Q | NaN streak length: 60Enumeration 52195 of 53370 | From 	 2017-08-16 02:00:00 	 to 	 2017-08-16 02:09:50 | column Q | NaN streak length: 60Enumeration 89 of 11432 | From 	 2017-03-20 01:00:10 	 to 	 2017-03-20 01:59:50 | column eMeter | NaN streak length: 359
#
#
# Enumeration 56996 of 58291 | From 	 2017-08-20 02:00:00 	 to 	 2017-08-20 02:09:50 | column Q | NaN streak length: 60Enumeration 52196 of 53370 | From 	 2017-08-17 02:00:00 	 to 	 2017-08-17 02:09:50 | column Q | NaN streak length: 60
#
# Enumeration 90 of 11432 | From 	 2017-03-20 02:00:10 	 to 	 2017-03-20 02:59:50 | column eMeter | NaN streak length: 359Enumeration 56997 of 58291 | From 	 2017-08-21 02:00:00 	 to 	 2017-08-21 02:09:50 | column Q | NaN streak length: 60Enumeration 52197 of 53370 | From 	 2017-08-18 02:00:00 	 to 	 2017-08-18 02:09:50 | column Q | NaN streak length: 60
#
#
# Enumeration 91 of 11432 | From 	 2017-03-20 03:00:10 	 to 	 2017-03-20 03:59:50 | column eMeter | NaN streak length: 359Enumeration 56998 of 58291 | From 	 2017-08-22 02:00:00 	 to 	 2017-08-22 02:09:50 | column Q | NaN streak length: 60
# Enumeration 52198 of 53370 | From 	 2017-08-19 02:00:00 	 to 	 2017-08-19 02:09:50 | column Q | NaN streak length: 60
#
# Enumeration 92 of 11432 | From 	 2017-03-20 04:00:10 	 to 	 2017-03-20 04:59:50 | column eMeter | NaN streak length: 359Enumeration 56999 of 58291 | From 	 2017-08-23 02:00:00 	 to 	 2017-08-23 02:09:50 | column Q | NaN streak length: 60
# Enumeration 52199 of 53370 | From 	 2017-08-20 02:00:00 	 to 	 2017-08-20 02:09:50 | column Q | NaN streak length: 60
# Enumeration 57000 of 58291 | From 	 2017-08-24 02:00:00 	 to 	 2017-08-24 02:09:50 | column Q | NaN streak length: 60
# Enumeration 93 of 11432 | From 	 2017-03-20 05:00:10 	 to 	 2017-03-20 05:59:50 | column eMeter | NaN streak length: 359
#
# Enumeration 52200 of 53370 | From 	 2017-08-21 02:00:00 	 to 	 2017-08-21 02:09:50 | column Q | NaN streak length: 60Enumeration 94 of 11432 | From 	 2017-03-20 06:00:10 	 to 	 2017-03-20 06:59:50 | column eMeter | NaN streak length: 359Enumeration 57001 of 58291 | From 	 2017-08-25 02:00:00 	 to 	 2017-08-25 02:09:50 | column Q | NaN streak length: 60
#
#
# Enumeration 52201 of 53370 | From 	 2017-08-22 02:00:00 	 to 	 2017-08-22 02:09:50 | column Q | NaN streak length: 60Enumeration 95 of 11432 | From 	 2017-03-20 07:00:10 	 to 	 2017-03-20 07:59:50 | column eMeter | NaN streak length: 359Enumeration 57002 of 58291 | From 	 2017-08-26 02:00:00 	 to 	 2017-08-26 02:09:50 | column Q | NaN streak length: 60
#
# Enumeration 52202 of 53370 | From 	 2017-08-23 02:00:00 	 to 	 2017-08-23 02:09:50 | column Q | NaN streak length: 60Enumeration 96 of 11432 | From 	 2017-03-20 08:00:10 	 to 	 2017-03-20 08:59:50 | column eMeter | NaN streak length: 359
#
#
# Enumeration 57003 of 58291 | From 	 2017-08-27 02:00:00 	 to 	 2017-08-27 02:09:50 | column Q | NaN streak length: 60Enumeration 97 of 11432 | From 	 2017-03-20 09:00:10 	 to 	 2017-03-20 09:59:50 | column eMeter | NaN streak length: 359
# Enumeration 52203 of 53370 | From 	 2017-08-24 02:00:00 	 to 	 2017-08-24 02:09:50 | column Q | NaN streak length: 60Enumeration 57004 of 58291 | From 	 2017-08-28 02:00:00 	 to 	 2017-08-28 02:09:50 | column Q | NaN streak length: 60
#
#
# Enumeration 52204 of 53370 | From 	 2017-08-25 02:00:00 	 to 	 2017-08-25 02:09:50 | column Q | NaN streak length: 60Enumeration 98 of 11432 | From 	 2017-03-20 10:00:10 	 to 	 2017-03-20 10:59:50 | column eMeter | NaN streak length: 359Enumeration 57005 of 58291 | From 	 2017-08-29 02:00:00 	 to 	 2017-08-29 02:09:50 | column Q | NaN streak length: 60
#
#
# Enumeration 52205 of 53370 | From 	 2017-08-26 02:00:00 	 to 	 2017-08-26 02:09:50 | column Q | NaN streak length: 60Enumeration 99 of 11432 | From 	 2017-03-20 11:00:10 	 to 	 2017-03-20 11:59:50 | column eMeter | NaN streak length: 359
# Enumeration 57006 of 58291 | From 	 2017-08-29 11:30:00 	 to 	 2017-08-29 11:39:50 | column Q | NaN streak length: 60Enumeration 52206 of 53370 | From 	 2017-08-27 02:00:00 	 to 	 2017-08-27 02:09:50 | column Q | NaN streak length: 60
#
# Enumeration 100 of 11432 | From 	 2017-03-20 12:00:10 	 to 	 2017-03-20 12:59:50 | column eMeter | NaN streak length: 359
# Enumeration 57007 of 58291 | From 	 2017-08-30 02:00:00 	 to 	 2017-08-30 02:09:50 | column Q | NaN streak length: 60
#
# Enumeration 52207 of 53370 | From 	 2017-08-28 02:00:00 	 to 	 2017-08-28 02:09:50 | column Q | NaN streak length: 60Enumeration 101 of 11432 | From 	 2017-03-20 13:00:10 	 to 	 2017-03-20 13:59:50 | column eMeter | NaN streak length: 359Enumeration 57008 of 58291 | From 	 2017-08-31 02:00:00 	 to 	 2017-08-31 02:09:50 | column Q | NaN streak length: 60
#
# Enumeration 57009 of 58291 | From 	 2017-09-01 02:00:00 	 to 	 2017-09-01 02:09:50 | column Q | NaN streak length: 60
# Enumeration 102 of 11432 | From 	 2017-03-20 14:00:10 	 to 	 2017-03-20 14:59:50 | column eMeter | NaN streak length: 359
# Enumeration 52208 of 53370 | From 	 2017-08-29 02:00:00 	 to 	 2017-08-29 02:09:50 | column Q | NaN streak length: 60
# Enumeration 57010 of 58291 | From 	 2017-09-02 02:00:00 	 to 	 2017-09-02 02:09:50 | column Q | NaN streak length: 60
# Enumeration 103 of 11432 | From 	 2017-03-20 15:00:10 	 to 	 2017-03-20 15:59:50 | column eMeter | NaN streak length: 359
#
# Enumeration 57011 of 58291 | From 	 2017-09-03 02:00:00 	 to 	 2017-09-03 02:09:50 | column Q | NaN streak length: 60Enumeration 52209 of 53370 | From 	 2017-08-29 11:30:00 	 to 	 2017-08-29 11:39:50 | column Q | NaN streak length: 60Enumeration 104 of 11432 | From 	 2017-03-20 16:00:10 	 to 	 2017-03-20 16:59:50 | column eMeter | NaN streak length: 359
#
#
# Enumeration 57012 of 58291 | From 	 2017-09-04 02:00:00 	 to 	 2017-09-04 02:09:50 | column Q | NaN streak length: 60Enumeration 105 of 11432 | From 	 2017-03-20 17:00:10 	 to 	 2017-03-20 17:59:50 | column eMeter | NaN streak length: 359Enumeration 52210 of 53370 | From 	 2017-08-30 02:00:00 	 to 	 2017-08-30 02:09:50 | column Q | NaN streak length: 60
#
#
# Enumeration 57013 of 58291 | From 	 2017-09-05 02:00:00 	 to 	 2017-09-05 02:09:50 | column Q | NaN streak length: 60Enumeration 106 of 11432 | From 	 2017-03-20 18:00:10 	 to 	 2017-03-20 18:59:50 | column eMeter | NaN streak length: 359Enumeration 52211 of 53370 | From 	 2017-08-31 02:00:00 	 to 	 2017-08-31 02:09:50 | column Q | NaN streak length: 60
#
#
# Enumeration 107 of 11432 | From 	 2017-03-20 19:00:10 	 to 	 2017-03-20 19:59:50 | column eMeter | NaN streak length: 359Enumeration 52212 of 53370 | From 	 2017-09-01 02:00:00 	 to 	 2017-09-01 02:09:50 | column Q | NaN streak length: 60Enumeration 57014 of 58291 | From 	 2017-09-06 02:00:00 	 to 	 2017-09-06 02:09:50 | column Q | NaN streak length: 60
#
#
# Enumeration 52213 of 53370 | From 	 2017-09-02 02:00:00 	 to 	 2017-09-02 02:09:50 | column Q | NaN streak length: 60Enumeration 108 of 11432 | From 	 2017-03-20 20:00:10 	 to 	 2017-03-20 20:59:50 | column eMeter | NaN streak length: 359Enumeration 57015 of 58291 | From 	 2017-09-07 02:00:00 	 to 	 2017-09-07 02:09:50 | column Q | NaN streak length: 60
#
#
# Enumeration 57016 of 58291 | From 	 2017-09-08 02:00:00 	 to 	 2017-09-08 02:09:50 | column Q | NaN streak length: 60Enumeration 109 of 11432 | From 	 2017-03-20 21:00:10 	 to 	 2017-03-20 21:59:50 | column eMeter | NaN streak length: 359
# Enumeration 52214 of 53370 | From 	 2017-09-03 02:00:00 	 to 	 2017-09-03 02:09:50 | column Q | NaN streak length: 60
# Enumeration 57017 of 58291 | From 	 2017-09-09 02:00:00 	 to 	 2017-09-09 02:09:50 | column Q | NaN streak length: 60Enumeration 110 of 11432 | From 	 2017-03-20 22:00:10 	 to 	 2017-03-20 22:59:50 | column eMeter | NaN streak length: 359
#
#
# Enumeration 57018 of 58291 | From 	 2017-09-10 02:00:00 	 to 	 2017-09-10 02:09:50 | column Q | NaN streak length: 60Enumeration 111 of 11432 | From 	 2017-03-20 23:00:10 	 to 	 2017-03-20 23:59:50 | column eMeter | NaN streak length: 359Enumeration 52215 of 53370 | From 	 2017-09-04 02:00:00 	 to 	 2017-09-04 02:09:50 | column Q | NaN streak length: 60
#
#
# Enumeration 112 of 11432 | From 	 2017-03-21 00:00:10 	 to 	 2017-03-21 00:59:50 | column eMeter | NaN streak length: 359Enumeration 57019 of 58291 | From 	 2017-09-11 02:00:00 	 to 	 2017-09-11 02:09:50 | column Q | NaN streak length: 60
#
# Enumeration 52216 of 53370 | From 	 2017-09-05 02:00:00 	 to 	 2017-09-05 02:09:50 | column Q | NaN streak length: 60
# Enumeration 57020 of 58291 | From 	 2017-09-12 02:00:00 	 to 	 2017-09-12 02:09:50 | column Q | NaN streak length: 60Enumeration 113 of 11432 | From 	 2017-03-21 01:00:10 	 to 	 2017-03-21 01:59:50 | column eMeter | NaN streak length: 359
#
# Enumeration 52217 of 53370 | From 	 2017-09-06 02:00:00 	 to 	 2017-09-06 02:09:50 | column Q | NaN streak length: 60
# Enumeration 114 of 11432 | From 	 2017-03-21 02:00:10 	 to 	 2017-03-21 02:59:50 | column eMeter | NaN streak length: 359Enumeration 57021 of 58291 | From 	 2017-09-13 02:00:00 	 to 	 2017-09-13 02:09:50 | column Q | NaN streak length: 60Enumeration 52218 of 53370 | From 	 2017-09-07 02:00:00 	 to 	 2017-09-07 02:09:50 | column Q | NaN streak length: 60
#
#
# Enumeration 115 of 11432 | From 	 2017-03-21 03:00:10 	 to 	 2017-03-21 03:59:50 | column eMeter | NaN streak length: 359Enumeration 57022 of 58291 | From 	 2017-09-14 02:00:00 	 to 	 2017-09-14 02:09:50 | column Q | NaN streak length: 60Enumeration 52219 of 53370 | From 	 2017-09-08 02:00:00 	 to 	 2017-09-08 02:09:50 | column Q | NaN streak length: 60
#
#
# Enumeration 116 of 11432 | From 	 2017-03-21 04:00:10 	 to 	 2017-03-21 04:59:50 | column eMeter | NaN streak length: 359Enumeration 52220 of 53370 | From 	 2017-09-09 02:00:00 	 to 	 2017-09-09 02:09:50 | column Q | NaN streak length: 60
# Enumeration 57023 of 58291 | From 	 2017-09-15 02:00:00 	 to 	 2017-09-15 02:09:50 | column Q | NaN streak length: 60
# Enumeration 117 of 11432 | From 	 2017-03-21 05:00:10 	 to 	 2017-03-21 05:59:50 | column eMeter | NaN streak length: 359
#
# Enumeration 57024 of 58291 | From 	 2017-09-16 02:00:00 	 to 	 2017-09-16 02:09:50 | column Q | NaN streak length: 60Enumeration 52221 of 53370 | From 	 2017-09-10 02:00:00 	 to 	 2017-09-10 02:09:50 | column Q | NaN streak length: 60
# Enumeration 118 of 11432 | From 	 2017-03-21 06:00:10 	 to 	 2017-03-21 06:59:50 | column eMeter | NaN streak length: 359
#
# Enumeration 57025 of 58291 | From 	 2017-09-17 02:00:00 	 to 	 2017-09-17 02:09:50 | column Q | NaN streak length: 60Enumeration 52222 of 53370 | From 	 2017-09-11 02:00:00 	 to 	 2017-09-11 02:09:50 | column Q | NaN streak length: 60Enumeration 119 of 11432 | From 	 2017-03-21 07:00:10 	 to 	 2017-03-21 07:59:50 | column eMeter | NaN streak length: 359
#
#
# Enumeration 57026 of 58291 | From 	 2017-09-18 02:00:00 	 to 	 2017-09-18 02:09:50 | column Q | NaN streak length: 60Enumeration 52223 of 53370 | From 	 2017-09-12 02:00:00 	 to 	 2017-09-12 02:09:50 | column Q | NaN streak length: 60Enumeration 120 of 11432 | From 	 2017-03-21 08:00:10 	 to 	 2017-03-21 08:59:50 | column eMeter | NaN streak length: 359
#
#
# Enumeration 52224 of 53370 | From 	 2017-09-13 02:00:00 	 to 	 2017-09-13 02:09:50 | column Q | NaN streak length: 60Enumeration 57027 of 58291 | From 	 2017-09-19 02:00:00 	 to 	 2017-09-19 02:09:50 | column Q | NaN streak length: 60Enumeration 121 of 11432 | From 	 2017-03-21 09:00:10 	 to 	 2017-03-21 09:59:50 | column eMeter | NaN streak length: 359
#
#
# Enumeration 57028 of 58291 | From 	 2017-09-20 02:00:00 	 to 	 2017-09-20 02:09:50 | column Q | NaN streak length: 60Enumeration 52225 of 53370 | From 	 2017-09-14 02:00:00 	 to 	 2017-09-14 02:09:50 | column Q | NaN streak length: 60Enumeration 122 of 11432 | From 	 2017-03-21 10:00:10 	 to 	 2017-03-21 10:59:50 | column eMeter | NaN streak length: 359
#
#
# Enumeration 52226 of 53370 | From 	 2017-09-15 02:00:00 	 to 	 2017-09-15 02:09:50 | column Q | NaN streak length: 60Enumeration 123 of 11432 | From 	 2017-03-21 11:00:10 	 to 	 2017-03-21 11:59:50 | column eMeter | NaN streak length: 359Enumeration 57029 of 58291 | From 	 2017-09-21 02:00:00 	 to 	 2017-09-21 02:09:50 | column Q | NaN streak length: 60
#
#
# Enumeration 52227 of 53370 | From 	 2017-09-16 02:00:00 	 to 	 2017-09-16 02:09:50 | column Q | NaN streak length: 60Enumeration 124 of 11432 | From 	 2017-03-21 12:00:10 	 to 	 2017-03-21 12:59:50 | column eMeter | NaN streak length: 359
#
# Enumeration 57030 of 58291 | From 	 2017-09-22 02:00:00 	 to 	 2017-09-22 02:09:50 | column Q | NaN streak length: 60Enumeration 52228 of 53370 | From 	 2017-09-17 02:00:00 	 to 	 2017-09-17 02:09:50 | column Q | NaN streak length: 60
# Enumeration 125 of 11432 | From 	 2017-03-21 13:00:10 	 to 	 2017-03-21 13:59:50 | column eMeter | NaN streak length: 359
# Enumeration 57031 of 58291 | From 	 2017-09-23 02:00:00 	 to 	 2017-09-23 02:09:50 | column Q | NaN streak length: 60
#
# Enumeration 52229 of 53370 | From 	 2017-09-18 02:00:00 	 to 	 2017-09-18 02:09:50 | column Q | NaN streak length: 60Enumeration 126 of 11432 | From 	 2017-03-21 14:00:10 	 to 	 2017-03-21 14:59:50 | column eMeter | NaN streak length: 359Enumeration 57032 of 58291 | From 	 2017-09-24 02:00:00 	 to 	 2017-09-24 02:09:50 | column Q | NaN streak length: 60
#
#
# Enumeration 52230 of 53370 | From 	 2017-09-19 02:00:00 	 to 	 2017-09-19 02:09:50 | column Q | NaN streak length: 60Enumeration 127 of 11432 | From 	 2017-03-21 15:00:10 	 to 	 2017-03-21 15:59:50 | column eMeter | NaN streak length: 359Enumeration 57033 of 58291 | From 	 2017-09-25 02:00:00 	 to 	 2017-09-25 02:09:50 | column Q | NaN streak length: 60
#
#
# Enumeration 52231 of 53370 | From 	 2017-09-20 02:00:00 	 to 	 2017-09-20 02:09:50 | column Q | NaN streak length: 60Enumeration 128 of 11432 | From 	 2017-03-21 16:00:10 	 to 	 2017-03-21 16:59:50 | column eMeter | NaN streak length: 359Enumeration 57034 of 58291 | From 	 2017-09-26 02:00:00 	 to 	 2017-09-26 02:09:50 | column Q | NaN streak length: 60
#
#
# ...
#
#
# Enumeration 57455 of 58291 | From 	 2017-08-31 02:00:00 	 to 	 2017-08-31 02:09:50 | column T | NaN streak length: 60Enumeration 248 of 11432 | From 	 2017-03-26 18:00:10 	 to 	 2017-03-26 18:59:50 | column eMeter | NaN streak length: 359Enumeration 52624 of 53370 | From 	 2017-09-05 02:00:00 	 to 	 2017-09-05 02:09:50 | column T | NaN streak length: 60
#
# Enumeration 57456 of 58291 | From 	 2017-09-01 02:00:00 	 to 	 2017-09-01 02:09:50 | column T | NaN streak length: 60
# Enumeration 52625 of 53370 | From 	 2017-09-06 02:00:00 	 to 	 2017-09-06 02:09:50 | column T | NaN streak length: 60Enumeration 249 of 11432 | From 	 2017-03-26 19:00:10 	 to 	 2017-03-26 19:59:50 | column eMeter | NaN streak length: 359
#
#
# Enumeration 57457 of 58291 | From 	 2017-09-02 02:00:00 	 to 	 2017-09-02 02:09:50 | column T | NaN streak length: 60Enumeration 52626 of 53370 | From 	 2017-09-07 02:00:00 	 to 	 2017-09-07 02:09:50 | column T | NaN streak length: 60Enumeration 250 of 11432 | From 	 2017-03-26 20:00:10 	 to 	 2017-03-26 20:59:50 | column eMeter | NaN streak length: 359
#
#
# Enumeration 57458 of 58291 | From 	 2017-09-03 02:00:00 	 to 	 2017-09-03 02:09:50 | column T | NaN streak length: 60Enumeration 52627 of 53370 | From 	 2017-09-08 02:00:00 	 to 	 2017-09-08 02:09:50 | column T | NaN streak length: 60Enumeration 251 of 11432 | From 	 2017-03-26 21:00:10 	 to 	 2017-03-26 21:59:50 | column eMeter | NaN streak length: 359
#
# Enumeration 57459 of 58291 | From 	 2017-09-04 02:00:00 	 to 	 2017-09-04 02:09:50 | column T | NaN streak length: 60Enumeration 52628 of 53370 | From 	 2017-09-09 02:00:00 	 to 	 2017-09-09 02:09:50 | column T | NaN streak length: 60
#
#
# Enumeration 252 of 11432 | From 	 2017-03-26 22:00:10 	 to 	 2017-03-26 22:59:50 | column eMeter | NaN streak length: 359Enumeration 57460 of 58291 | From 	 2017-09-05 02:00:00 	 to 	 2017-09-05 02:09:50 | column T | NaN streak length: 60
# Enumeration 52629 of 53370 | From 	 2017-09-10 02:00:00 	 to 	 2017-09-10 02:09:50 | column T | NaN streak length: 60
#
# Enumeration 253 of 11432 | From 	 2017-03-26 23:00:10 	 to 	 2017-03-26 23:59:50 | column eMeter | NaN streak length: 359Enumeration 57461 of 58291 | From 	 2017-09-06 02:00:00 	 to 	 2017-09-06 02:09:50 | column T | NaN streak length: 60Enumeration 52630 of 53370 | From 	 2017-09-11 02:00:00 	 to 	 2017-09-11 02:09:50 | column T | NaN streak length: 60
#
#
# Enumeration 254 of 11432 | From 	 2017-03-27 00:00:10 	 to 	 2017-03-27 00:59:50 | column eMeter | NaN streak length: 359Enumeration 57462 of 58291 | From 	 2017-09-07 02:00:00 	 to 	 2017-09-07 02:09:50 | column T | NaN streak length: 60
# Enumeration 52631 of 53370 | From 	 2017-09-12 02:00:00 	 to 	 2017-09-12 02:09:50 | column T | NaN streak length: 60
#
# Enumeration 255 of 11432 | From 	 2017-03-27 01:00:10 	 to 	 2017-03-27 01:59:50 | column eMeter | NaN streak length: 359Enumeration 57463 of 58291 | From 	 2017-09-08 02:00:00 	 to 	 2017-09-08 02:09:50 | column T | NaN streak length: 60
# Enumeration 52632 of 53370 | From 	 2017-09-13 02:00:00 	 to 	 2017-09-13 02:09:50 | column T | NaN streak length: 60
# Enumeration 256 of 11432 | From 	 2017-03-27 02:00:10 	 to 	 2017-03-27 02:59:50 | column eMeter | NaN streak length: 359
# Enumeration 57464 of 58291 | From 	 2017-09-09 02:00:00 	 to 	 2017-09-09 02:09:50 | column T | NaN streak length: 60
# Enumeration 52633 of 53370 | From 	 2017-09-14 02:00:00 	 to 	 2017-09-14 02:09:50 | column T | NaN streak length: 60
# Enumeration 257 of 11432 | From 	 2017-03-27 03:00:10 	 to 	 2017-03-27 03:59:50 | column eMeter | NaN streak length: 359
# Enumeration 57465 of 58291 | From 	 2017-09-10 02:00:00 	 to 	 2017-09-10 02:09:50 | column T | NaN streak length: 60
# Enumeration 52634 of 53370 | From 	 2017-09-15 02:00:00 	 to 	 2017-09-15 02:09:50 | column T | NaN streak length: 60
#
# Enumeration 258 of 11432 | From 	 2017-03-27 04:00:10 	 to 	 2017-03-27 04:59:50 | column eMeter | NaN streak length: 359Enumeration 57466 of 58291 | From 	 2017-09-11 02:00:00 	 to 	 2017-09-11 02:09:50 | column T | NaN streak length: 60Enumeration 52635 of 53370 | From 	 2017-09-16 02:00:00 	 to 	 2017-09-16 02:09:50 | column T | NaN streak length: 60
#
#
# Enumeration 57467 of 58291 | From 	 2017-09-12 02:00:00 	 to 	 2017-09-12 02:09:50 | column T | NaN streak length: 60Enumeration 259 of 11432 | From 	 2017-03-27 05:00:10 	 to 	 2017-03-27 05:59:50 | column eMeter | NaN streak length: 359Enumeration 52636 of 53370 | From 	 2017-09-17 02:00:00 	 to 	 2017-09-17 02:09:50 | column T | NaN streak length: 60
#
#
# Enumeration 57468 of 58291 | From 	 2017-09-13 02:00:00 	 to 	 2017-09-13 02:09:50 | column T | NaN streak length: 60Enumeration 260 of 11432 | From 	 2017-03-27 06:00:10 	 to 	 2017-03-27 06:59:50 | column eMeter | NaN streak length: 359Enumeration 52637 of 53370 | From 	 2017-09-18 02:00:00 	 to 	 2017-09-18 02:09:50 | column T | NaN streak length: 60
#
#
# Enumeration 57469 of 58291 | From 	 2017-09-14 02:00:00 	 to 	 2017-09-14 02:09:50 | column T | NaN streak length: 60Enumeration 261 of 11432 | From 	 2017-03-27 07:00:10 	 to 	 2017-03-27 07:59:50 | column eMeter | NaN streak length: 359Enumeration 52638 of 53370 | From 	 2017-09-19 02:00:00 	 to 	 2017-09-19 02:09:50 | column T | NaN streak length: 60
#
#
# Enumeration 57470 of 58291 | From 	 2017-09-15 02:00:00 	 to 	 2017-09-15 02:09:50 | column T | NaN streak length: 60Enumeration 262 of 11432 | From 	 2017-03-27 08:00:10 	 to 	 2017-03-27 08:59:50 | column eMeter | NaN streak length: 359
#
# Enumeration 52639 of 53370 | From 	 2017-09-20 02:00:00 	 to 	 2017-09-20 02:09:50 | column T | NaN streak length: 60Enumeration 57471 of 58291 | From 	 2017-09-16 02:00:00 	 to 	 2017-09-16 02:09:50 | column T | NaN streak length: 60Enumeration 263 of 11432 | From 	 2017-03-27 09:00:10 	 to 	 2017-03-27 09:59:50 | column eMeter | NaN streak length: 359
#
#
# Enumeration 52640 of 53370 | From 	 2017-09-21 02:00:00 	 to 	 2017-09-21 02:09:50 | column T | NaN streak length: 60Enumeration 57472 of 58291 | From 	 2017-09-17 02:00:00 	 to 	 2017-09-17 02:09:50 | column T | NaN streak length: 60Enumeration 264 of 11432 | From 	 2017-03-27 10:00:10 	 to 	 2017-03-27 10:59:50 | column eMeter | NaN streak length: 359
#
# Enumeration 52641 of 53370 | From 	 2017-09-22 02:00:00 	 to 	 2017-09-22 02:09:50 | column T | NaN streak length: 60
#
# Enumeration 265 of 11432 | From 	 2017-03-27 11:00:10 	 to 	 2017-03-27 11:59:50 | column eMeter | NaN streak length: 359Enumeration 57473 of 58291 | From 	 2017-09-18 02:00:00 	 to 	 2017-09-18 02:09:50 | column T | NaN streak length: 60Enumeration 52642 of 53370 | From 	 2017-09-23 02:00:00 	 to 	 2017-09-23 02:09:50 | column T | NaN streak length: 60
#
#
# Enumeration 266 of 11432 | From 	 2017-03-27 12:00:10 	 to 	 2017-03-27 12:59:50 | column eMeter | NaN streak length: 359Enumeration 57474 of 58291 | From 	 2017-09-19 02:00:00 	 to 	 2017-09-19 02:09:50 | column T | NaN streak length: 60
#
# Enumeration 52643 of 53370 | From 	 2017-09-24 02:00:00 	 to 	 2017-09-24 02:09:50 | column T | NaN streak length: 60Enumeration 57475 of 58291 | From 	 2017-09-20 02:00:00 	 to 	 2017-09-20 02:09:50 | column T | NaN streak length: 60
# Enumeration 267 of 11432 | From 	 2017-03-27 13:00:10 	 to 	 2017-03-27 13:59:50 | column eMeter | NaN streak length: 359
#
# Enumeration 268 of 11432 | From 	 2017-03-27 14:00:10 	 to 	 2017-03-27 14:59:50 | column eMeter | NaN streak length: 359Enumeration 52644 of 53370 | From 	 2017-09-25 02:00:00 	 to 	 2017-09-25 02:09:50 | column T | NaN streak length: 60Enumeration 57476 of 58291 | From 	 2017-09-21 02:00:00 	 to 	 2017-09-21 02:09:50 | column T | NaN streak length: 60
#
#
# Enumeration 52645 of 53370 | From 	 2017-09-26 02:00:00 	 to 	 2017-09-26 02:09:50 | column T | NaN streak length: 60Enumeration 269 of 11432 | From 	 2017-03-27 15:00:10 	 to 	 2017-03-27 15:59:50 | column eMeter | NaN streak length: 359Enumeration 57477 of 58291 | From 	 2017-09-22 02:00:00 	 to 	 2017-09-22 02:09:50 | column T | NaN streak length: 60
#
#
# Enumeration 57478 of 58291 | From 	 2017-09-23 02:00:00 	 to 	 2017-09-23 02:09:50 | column T | NaN streak length: 60Enumeration 270 of 11432 | From 	 2017-03-27 16:00:10 	 to 	 2017-03-27 16:59:50 | column eMeter | NaN streak length: 359Enumeration 52646 of 53370 | From 	 2017-09-27 02:00:00 	 to 	 2017-09-27 02:09:50 | column T | NaN streak length: 60
#
#
# Enumeration 271 of 11432 | From 	 2017-03-27 17:00:10 	 to 	 2017-03-27 17:59:50 | column eMeter | NaN streak length: 359Enumeration 57479 of 58291 | From 	 2017-09-24 02:00:00 	 to 	 2017-09-24 02:09:50 | column T | NaN streak length: 60Enumeration 52647 of 53370 | From 	 2017-09-28 02:00:00 	 to 	 2017-09-28 02:09:50 | column T | NaN streak length: 60
#
#
# Enumeration 272 of 11432 | From 	 2017-03-27 18:00:10 	 to 	 2017-03-27 18:59:50 | column eMeter | NaN streak length: 359Enumeration 52648 of 53370 | From 	 2017-09-29 02:00:00 	 to 	 2017-09-29 02:09:50 | column T | NaN streak length: 60Enumeration 57480 of 58291 | From 	 2017-09-25 02:00:00 	 to 	 2017-09-25 02:09:50 | column T | NaN streak length: 60
#
#
# Enumeration 57481 of 58291 | From 	 2017-09-26 02:00:00 	 to 	 2017-09-26 02:09:50 | column T | NaN streak length: 60Enumeration 52649 of 53370 | From 	 2017-09-30 02:00:00 	 to 	 2017-09-30 02:09:50 | column T | NaN streak length: 60Enumeration 273 of 11432 | From 	 2017-03-27 19:00:10 	 to 	 2017-03-27 19:59:50 | column eMeter | NaN streak length: 359
#
#
# Enumeration 57482 of 58291 | From 	 2017-09-27 02:00:00 	 to 	 2017-09-27 02:09:50 | column T | NaN streak length: 60Enumeration 52650 of 53370 | From 	 2017-10-01 02:00:00 	 to 	 2017-10-01 02:09:50 | column T | NaN streak length: 60Enumeration 274 of 11432 | From 	 2017-03-27 20:00:10 	 to 	 2017-03-27 20:59:50 | column eMeter | NaN streak length: 359
#
#
# Enumeration 57483 of 58291 | From 	 2017-09-28 02:00:00 	 to 	 2017-09-28 02:09:50 | column T | NaN streak length: 60Enumeration 52651 of 53370 | From 	 2017-10-02 02:00:00 	 to 	 2017-10-02 02:09:50 | column T | NaN streak length: 60Enumeration 275 of 11432 | From 	 2017-03-27 21:00:10 	 to 	 2017-03-27 21:59:50 | column eMeter | NaN streak length: 359
#
# Enumeration 57484 of 58291 | From 	 2017-09-29 02:00:00 	 to 	 2017-09-29 02:09:50 | column T | NaN streak length: 60Enumeration 52652 of 53370 | From 	 2017-10-03 02:00:00 	 to 	 2017-10-03 02:09:50 | column T | NaN streak length: 60
#
#
# Enumeration 276 of 11432 | From 	 2017-03-27 22:00:10 	 to 	 2017-03-27 22:59:50 | column eMeter | NaN streak length: 359Enumeration 57485 of 58291 | From 	 2017-09-30 02:00:00 	 to 	 2017-09-30 02:09:50 | column T | NaN streak length: 60Enumeration 52653 of 53370 | From 	 2017-10-04 02:00:00 	 to 	 2017-10-04 02:09:50 | column T | NaN streak length: 60
#
#
# Enumeration 57486 of 58291 | From 	 2017-10-01 02:00:00 	 to 	 2017-10-01 02:09:50 | column T | NaN streak length: 60Enumeration 277 of 11432 | From 	 2017-03-27 23:00:10 	 to 	 2017-03-27 23:59:50 | column eMeter | NaN streak length: 359Enumeration 52654 of 53370 | From 	 2017-10-05 02:00:00 	 to 	 2017-10-05 02:09:50 | column T | NaN streak length: 60
#
# Enumeration 278 of 11432 | From 	 2017-03-28 00:00:10 	 to 	 2017-03-28 00:59:50 | column eMeter | NaN streak length: 359
# Enumeration 57487 of 58291 | From 	 2017-10-02 02:00:00 	 to 	 2017-10-02 02:09:50 | column T | NaN streak length: 60
# Enumeration 52655 of 53370 | From 	 2017-10-06 02:00:00 	 to 	 2017-10-06 02:09:50 | column T | NaN streak length: 60
# Enumeration 279 of 11432 | From 	 2017-03-28 01:00:10 	 to 	 2017-03-28 01:59:50 | column eMeter | NaN streak length: 359
#
# Enumeration 57488 of 58291 | From 	 2017-10-03 02:00:00 	 to 	 2017-10-03 02:09:50 | column T | NaN streak length: 60Enumeration 280 of 11432 | From 	 2017-03-28 02:00:10 	 to 	 2017-03-28 02:59:50 | column eMeter | NaN streak length: 359
# Enumeration 52656 of 53370 | From 	 2017-10-07 02:00:00 	 to 	 2017-10-07 02:09:50 | column T | NaN streak length: 60Enumeration 57489 of 58291 | From 	 2017-10-04 02:00:00 	 to 	 2017-10-04 02:09:50 | column T | NaN streak length: 60
# Enumeration 52657 of 53370 | From 	 2017-10-08 02:00:00 	 to 	 2017-10-08 02:09:50 | column T | NaN streak length: 60
# Enumeration 57490 of 58291 | From 	 2017-10-05 02:00:00 	 to 	 2017-10-05 02:09:50 | column T | NaN streak length: 60
#
# Enumeration 52658 of 53370 | From 	 2017-10-09 02:00:00 	 to 	 2017-10-09 02:09:50 | column T | NaN streak length: 60Enumeration 57491 of 58291 | From 	 2017-10-06 02:00:00 	 to 	 2017-10-06 02:09:50 | column T | NaN streak length: 60
#
# Enumeration 52659 of 53370 | From 	 2017-10-10 02:00:00 	 to 	 2017-10-10 02:09:50 | column T | NaN streak length: 60Enumeration 57492 of 58291 | From 	 2017-10-07 02:00:00 	 to 	 2017-10-07 02:09:50 | column T | NaN streak length: 60
# Enumeration 57493 of 58291 | From 	 2017-10-08 02:00:00 	 to 	 2017-10-08 02:09:50 | column T | NaN streak length: 60
# Enumeration 52660 of 53370 | From 	 2017-10-11 02:00:00 	 to 	 2017-10-11 02:09:50 | column T | NaN streak length: 60
#
# Enumeration 57494 of 58291 | From 	 2017-10-09 02:00:00 	 to 	 2017-10-09 02:09:50 | column T | NaN streak length: 60Enumeration 52661 of 53370 | From 	 2017-10-12 02:00:00 	 to 	 2017-10-12 02:09:50 | column T | NaN streak length: 60
#
# Enumeration 57495 of 58291 | From 	 2017-10-10 02:00:00 	 to 	 2017-10-10 02:09:50 | column T | NaN streak length: 60
# Enumeration 52662 of 53370 | From 	 2017-10-13 02:00:00 	 to 	 2017-10-13 02:09:50 | column T | NaN streak length: 60
# Enumeration 57496 of 58291 | From 	 2017-10-11 02:00:00 	 to 	 2017-10-11 02:09:50 | column T | NaN streak length: 60Enumeration 52663 of 53370 | From 	 2017-10-14 02:00:00 	 to 	 2017-10-14 02:09:50 | column T | NaN streak length: 60
# Enumeration 57497 of 58291 | From 	 2017-10-12 02:00:00 	 to 	 2017-10-12 02:09:50 | column T | NaN streak length: 60
#
# Enumeration 52664 of 53370 | From 	 2017-10-15 02:00:00 	 to 	 2017-10-15 02:09:50 | column T | NaN streak length: 60Enumeration 57498 of 58291 | From 	 2017-10-13 02:00:00 	 to 	 2017-10-13 02:09:50 | column T | NaN streak length: 60
#
# Enumeration 52665 of 53370 | From 	 2017-10-16 02:00:00 	 to 	 2017-10-16 02:09:50 | column T | NaN streak length: 60Enumeration 57499 of 58291 | From 	 2017-10-14 02:00:00 	 to 	 2017-10-14 02:09:50 | column T | NaN streak length: 60
# Enumeration 52666 of 53370 | From 	 2017-10-17 02:00:00 	 to 	 2017-10-17 02:09:50 | column T | NaN streak length: 60
#
# Enumeration 57500 of 58291 | From 	 2017-10-15 02:00:00 	 to 	 2017-10-15 02:09:50 | column T | NaN streak length: 60
# Enumeration 52667 of 53370 | From 	 2017-10-18 02:00:00 	 to 	 2017-10-18 02:09:50 | column T | NaN streak length: 60Enumeration 57501 of 58291 | From 	 2017-10-16 02:00:00 	 to 	 2017-10-16 02:09:50 | column T | NaN streak length: 60
#
# Enumeration 57502 of 58291 | From 	 2017-10-17 02:00:00 	 to 	 2017-10-17 02:09:50 | column T | NaN streak length: 60Enumeration 52668 of 53370 | From 	 2017-10-19 02:00:00 	 to 	 2017-10-19 02:09:50 | column T | NaN streak length: 60
# Enumeration 52669 of 53370 | From 	 2017-10-20 02:00:00 	 to 	 2017-10-20 02:09:50 | column T | NaN streak length: 60
# Enumeration 52670 of 53370 | From 	 2017-10-21 02:00:00 	 to 	 2017-10-21 02:09:50 | column T | NaN streak length: 60
# Enumeration 52671 of 53370 | From 	 2017-10-22 02:00:00 	 to 	 2017-10-22 02:09:50 | column T | NaN streak length: 60
# Enumeration 52672 of 53370 | From 	 2017-10-23 02:00:00 	 to 	 2017-10-23 02:09:50 | column T | NaN streak length: 60
# Enumeration 52673 of 53370 | From 	 2017-10-24 02:00:00 	 to 	 2017-10-24 02:09:50 | column T | NaN streak length: 60
# Enumeration 52674 of 53370 | From 	 2017-10-25 02:00:00 	 to 	 2017-10-25 02:09:50 | column T | NaN streak length: 60

# %% [markdown]
# # Compute stuff

# %%
dfs_10s_results = []
dfs_hour_results = []

dfs_nan_table_10s_results = []
dfs_nan_table_hour_results = []

dfs_10s_partly_processed_results = []
dfs_hour_partly_processed_results = []

for i in range(len(dfs_nan_table_10s)):
    dfs_10s_results.append(client.compute(dfs_10s[i].compute()))
    dfs_hour_results.append(client.compute(dfs_hour[i].compute()))
    
    #dfs_nan_table_10s_results.append(client.compute(dfs_nan_table_10s[i].compute()))
    #dfs_nan_table_hour_results.append(client.compute(dfs_nan_table_hour[i].compute()))
    
    dfs_10s_partly_processed_results.append(client.compute(dfs_10s_partly_processed[i].compute()))
    dfs_hour_partly_processed_results.append(client.compute(dfs_hour_partly_processed[i].compute()))

# %% [markdown]
# # Save stuff

# %%
# Save unprocessed data (NaN threshold applied)
zz = []
for i in range(len(dfs_10s_partly_processed)):
    dwelling_id = dwelling_ids[i]
    df = dfs_10s[i].compute()
    z = client.submit(save_df_unprocessed, df, dwelling_id+'_10s')
    zz.append(z) # This makes it run in parallel?
    #print('Finished saving %s' % i)
    
    zz = []
for i in range(len(dfs_hour_partly_processed)):
    dwelling_id = dwelling_ids[i]
    df = dfs_hour[i].compute()
    z = client.submit(save_df_unprocessed, df, dwelling_id+'_hour')
    zz.append(z) # This makes it run in parallel?
    print('Finished saving %s' % i)
# Out:
# Saved unprocessed df: P01S01W0001_10s
# Saved unprocessed df: P01S01W0000_10s
# Finished saving 0
# Saved unprocessed df: P01S01W0000_hour
# Finished saving 1
# Saved unprocessed df: P01S01W0001_hour
# Finished saving 2
# Finished saving 3Saved unprocessed df: P01S01W0373_hour
#
# Finished saving 4
# Saved unprocessed df: P01S01W0378_hour
# Saved unprocessed df: P01S01W0998_hour
# Saved unprocessed df: P01S01W0373_10s
# Saved unprocessed df: P01S01W0998_10s
# Saved unprocessed df: P01S01W0378_10s

# %%
# Save partly processed data (NaN threshold applied)
zz = []
for i in range(len(dfs_10s_partly_processed)):
    dwelling_id = dwelling_ids[i]
    df = dfs_10s_partly_processed[i].compute()
    z = client.submit(save_df_processed, df, dwelling_id+'_10s')
    zz.append(z) # This makes it run in parallel?
    #print('Finished saving %s' % i)
    
    zz = []
for i in range(len(dfs_hour_partly_processed)):
    dwelling_id = dwelling_ids[i]
    df = dfs_hour_partly_processed[i].compute()
    z = client.submit(save_df_processed, df, dwelling_id+'_hour')
    zz.append(z) # This makes it run in parallel?
    print('Finished saving %s' % i)
# Out:
# Saved processed df: P01S01W0000_10s
# Saved processed df: P01S01W0001_10s
# Saved processed df: P01S01W0373_10s
# Saved processed df: P01S01W0378_10s
# Saved processed df: P01S01W0998_10s
