# %%
import sys
sys.path.append('/home/16080696/notebooks/KB-74-OPSCHALER/')
import Opschaler as op
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
op.corr_df('6h','P01S01W0373')

# %%
op.dwel_path_id('10s','processed','yes')
print(file_paths)
# Out:
# complete_path: //datc//opschaler//combined_gas_smart_weather_dfs//processed//all_dwellings_combined_10s.csv
# Detected 0 smartmeter_data files.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-0693a1df5db9> in <module>()
#       1 op.dwel_path_id('10s','processed','yes')
# ----> 2 print(file_paths)
#
# NameError: name 'file_paths' is not defined
