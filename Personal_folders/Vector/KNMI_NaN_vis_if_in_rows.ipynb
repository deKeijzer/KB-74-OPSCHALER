# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('//datc//opschaler//weather_data//knmi_10_min_raw_data//output//df_combined_uncleaned.csv', delimiter='\t', parse_dates=['datetime'])

# %%
df = df.reset_index()
df = df.isnull()
fig = sns.heatmap(smart_nan_test, cmap='gray_r', yticklabels = 10000, cbar=False)
fig.invert_yaxis()
fig.set(xlabel='Column [-]', ylabel='Index [-]')
plt.title('KNMI')
plt.savefig('test_nans_vis_weather_whole.png')
plt.show()
