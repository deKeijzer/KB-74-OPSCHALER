# %%
#Studentnummer: 16023161
#Studentnaam: Lucas de Lange
#Importeer alle blibliotheken die ik nodig ga hebben.
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
get_ipython().run_line_magic('matplotlib', 'inline')

# %%
df = pd.read_excel('/home/14109999/notebooks/KB-74-OPSCHALER/Personal_folders/Megan/table1.xlsx')
df.head()
# Out:
#                                              Table 1               \
# 0                         Crime in the United States          NaN
# 1  by Volume and Rate per 100,000 Inhabitants, 19...          NaN
# 2                                               Year  Population1
# 3                                               1997    267783607
# 4                                               1998    270248003
#
#         Unnamed: 2               Unnamed: 3  \
# 0              NaN                      NaN
# 1              NaN                      NaN
# 2  Violent\ncrime2  Violent \ncrime \nrate
# 3          1636096                      611
# 4          1533887                    567.6
#
#                                 Unnamed: 4  \
# 0                                      NaN
# 1                                      NaN
# 2  Murder and\nnonnegligent \nmanslaughter
# 3                                    18208
# 4                                    16974
#
#                                          Unnamed: 5  \
# 0                                               NaN
# 1                                               NaN
# 2  Murder and \nnonnegligent \nmanslaughter \nrate
# 3                                               6.8
# 4                                               6.3
#
#                       Unnamed: 6                            Unnamed: 7  \
# 0                            NaN                                   NaN
# 1                            NaN                                   NaN
# 2  Rape\n(revised \ndefinition3)  Rape\n(revised \ndefinition) \nrate3
# 3                            NaN                                   NaN
# 4                            NaN                                   NaN
#
#                      Unnamed: 8                           Unnamed: 9  \
# 0                           NaN                                  NaN
# 1                           NaN                                  NaN
# 2  Rape\n(legacy \ndefinition4)  Rape\n(legacy \ndefinition) \nrate4
# 3                         96153                                 35.9
# 4                         93144                                 34.5
#
#                 ...                          Unnamed: 12  \
# 0               ...                                  NaN
# 1               ...                                  NaN
# 2               ...                 Aggravated \nassault
# 3               ...                              1023201
# 4               ...                               976583
#
#                   Unnamed: 13       Unnamed: 14               Unnamed: 15  \
# 0                         NaN               NaN                       NaN
# 1                         NaN               NaN                       NaN
# 2  Aggravated \nassault rate   Property \ncrime  Property \ncrime \nrate
# 3                       382.1          11558475                    4316.3
# 4                       361.4          10951827                    4052.5
#
#   Unnamed: 16       Unnamed: 17      Unnamed: 18            Unnamed: 19  \
# 0         NaN               NaN              NaN                    NaN
# 1         NaN               NaN              NaN                    NaN
# 2    Burglary  Burglary \nrate   Larceny-\ntheft  Larceny-\ntheft rate
# 3     2460526             918.8          7743760                 2891.8
# 4     2332735             863.2          7376311                 2729.5
#
#                Unnamed: 20                      Unnamed: 21
# 0                      NaN                              NaN
# 1                      NaN                              NaN
# 2  Motor \nvehicle \ntheft  Motor \nvehicle \ntheft \nrate
# 3                  1354189                            505.7
# 4                  1242781                            459.9
#
# [5 rows x 22 columns]

# %%
df.isnull().sum()
# Out:
# Table 1        15
#                24
# Unnamed: 2     24
# Unnamed: 3     22
# Unnamed: 4     24
# Unnamed: 5     24
# Unnamed: 6     39
# Unnamed: 7     40
# Unnamed: 8     24
# Unnamed: 9     24
# Unnamed: 10    24
# Unnamed: 11    24
# Unnamed: 12    24
# Unnamed: 13    23
# Unnamed: 14    24
# Unnamed: 15    22
# Unnamed: 16    23
# Unnamed: 17    24
# Unnamed: 18    24
# Unnamed: 19    23
# Unnamed: 20    24
# Unnamed: 21    24
# dtype: int64

# %%
df.dtypes
# Out:
# Table 1        object
#                object
# Unnamed: 2     object
# Unnamed: 3     object
# Unnamed: 4     object
# Unnamed: 5     object
# Unnamed: 6     object
# Unnamed: 7     object
# Unnamed: 8     object
# Unnamed: 9     object
# Unnamed: 10    object
# Unnamed: 11    object
# Unnamed: 12    object
# Unnamed: 13    object
# Unnamed: 14    object
# Unnamed: 15    object
# Unnamed: 16    object
# Unnamed: 17    object
# Unnamed: 18    object
# Unnamed: 19    object
# Unnamed: 20    object
# Unnamed: 21    object
# dtype: object

# %%
df.columns
# Out:
# Index(['Table 1', ' ', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21'],
#       dtype='object')
