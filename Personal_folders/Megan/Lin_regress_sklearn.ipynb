# %%
#I created this notebook based on my portfolio feedback, in which I should create a simple linear regression 
#It might be similar to other MVR notebooks in my jupyiter
#Because it all has the same source which is datacamp 

#Firstly there are different methods in doing a linear regression or Lin_regress
#A linear regression always has the basic function of Y = ax + b whereas Y is the dependent variable,x = the independent variable
#A lin_regress can always show errors otherwise known as MSE or residual errors
#The most common library to use for this method is scikit-learn

# %%
#step 1 import packages/libraries
import sklearn as sk 
from sklearn import linear_model   #I am performing a linear regression, if it was multi_lin I would use different packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import style
from sklearn import svm
import numpy as np
# %matplotlib inline

#step 2 import csv, I use dwelling 8655 which is the most complete dwelling
dir = '//datc//opschaler//combined_gas_smart_weather_dfs//processed//'
dwelling_id = 'P01S01W5855_hour'
df = pd.read_csv(dir+dwelling_id+'.csv', delimiter='\t', parse_dates=['datetime'])
df = df.set_index(['datetime'])
df.head()
# Out:
#                        eMeter  eMeterReturn  eMeterLow  eMeterLowReturn  \
# datetime
# 2017-03-07 07:00:00       NaN           NaN        NaN              NaN
# 2017-03-07 08:00:00  2458.056           0.0   2370.064              0.0
# 2017-03-07 09:00:00  2458.288           0.0   2370.064              0.0
# 2017-03-07 10:00:00  2459.166           0.0   2370.064              0.0
# 2017-03-07 11:00:00  2459.424           0.0   2370.064              0.0
#
#                         ePower  ePowerReturn  gasMeter         DD     DR  \
# datetime
# 2017-03-07 07:00:00        NaN           NaN  2073.335  283.46667    0.0
# 2017-03-07 08:00:00  477.85837           0.0  2073.933  273.10000    0.0
# 2017-03-07 09:00:00  232.49167           0.0  2074.427  281.45000    0.0
# 2017-03-07 10:00:00  880.23050           0.0  2074.991  282.10000  100.0
# 2017-03-07 11:00:00  251.95273           0.0  2075.398  286.85000    2.0
#
# ...

# %%
df.isnull().sum()
# Out:
# eMeter             3
# eMeterReturn       3
# eMeterLow          3
# eMeterLowReturn    3
# ePower             3
# ePowerReturn       3
# gasMeter           2
# DD                 0
# DR                 0
# FF                 0
# FX                 0
# N                  0
# P                  1
# Q                  0
# RG                 0
# SQ                 0
# T                  0
# T10                0
# TD                 0
# U                  0
# VV                 0
# WW                 0
# dwelling           0
# gasPower           6
# dtype: int64

# %%
df2 = df.dropna()

# %%
df2.head()
# Out:
#                        eMeter  eMeterReturn  eMeterLow  eMeterLowReturn  \
# datetime
# 2017-03-07 08:00:00  2458.056           0.0   2370.064              0.0
# 2017-03-07 09:00:00  2458.288           0.0   2370.064              0.0
# 2017-03-07 10:00:00  2459.166           0.0   2370.064              0.0
# 2017-03-07 11:00:00  2459.424           0.0   2370.064              0.0
# 2017-03-07 12:00:00  2459.545           0.0   2370.064              0.0
#
#                          ePower  ePowerReturn  gasMeter         DD     DR  \
# datetime
# 2017-03-07 08:00:00  477.858370           0.0  2073.933  273.10000    0.0
# 2017-03-07 09:00:00  232.491670           0.0  2074.427  281.45000    0.0
# 2017-03-07 10:00:00  880.230500           0.0  2074.991  282.10000  100.0
# 2017-03-07 11:00:00  251.952730           0.0  2075.398  286.85000    2.0
# 2017-03-07 12:00:00  119.513885           0.0  2075.810  288.80002    0.0
#
# ...

# %%
df2['gasPower']
# Out:
# datetime
# 2017-03-07 08:00:00    0.598145
# 2017-03-07 09:00:00    0.493896
# 2017-03-07 10:00:00    0.563965
# 2017-03-07 11:00:00    0.406982
# 2017-03-07 12:00:00    0.412109
# 2017-03-07 13:00:00    0.173828
# 2017-03-07 14:00:00    0.000000
# 2017-03-07 15:00:00    0.000000
# 2017-03-07 16:00:00    0.000000
# 2017-03-07 17:00:00    0.000000
# 2017-03-07 18:00:00    0.125000
# 2017-03-07 19:00:00    0.671143
# 2017-03-07 20:00:00    0.302979
# 2017-03-07 21:00:00    0.302979
# 2017-03-07 22:00:00    0.303955
# 2017-03-07 23:00:00    0.297119
# 2017-03-08 00:00:00    0.000000
# 2017-03-08 01:00:00    0.000000
# 2017-03-08 02:00:00    0.000000
# 2017-03-08 03:00:00    0.000000
# 2017-03-08 04:00:00    0.000000
# 2017-03-08 05:00:00    0.000000
# 2017-03-08 06:00:00    0.000000
# 2017-03-08 07:00:00    0.625977
# 2017-03-08 08:00:00    0.630859
# 2017-03-08 09:00:00    0.528076
# 2017-03-08 10:00:00    0.812988
# 2017-03-08 11:00:00    0.626953
# 2017-03-08 12:00:00    0.527100
# ...

# %%
#filling up the gasPower with the mean of the gasPower columns
df_mean = df2.gasPower.fillna(df['gasPower'].mean())

# %%
df2.head()
df2.dropna()
# Out:
#                        eMeter  eMeterReturn  eMeterLow  eMeterLowReturn  \
# datetime
# 2017-03-07 08:00:00  2458.056         0.000   2370.064            0.000
# 2017-03-07 09:00:00  2458.288         0.000   2370.064            0.000
# 2017-03-07 10:00:00  2459.166         0.000   2370.064            0.000
# 2017-03-07 11:00:00  2459.424         0.000   2370.064            0.000
# 2017-03-07 12:00:00  2459.545         0.000   2370.064            0.000
# 2017-03-07 13:00:00  2459.642         0.000   2370.064            0.000
# 2017-03-07 14:00:00  2459.822         0.000   2370.064            0.000
# 2017-03-07 15:00:00  2459.915         0.000   2370.064            0.000
# 2017-03-07 16:00:00  2460.014         0.000   2370.064            0.000
# 2017-03-07 17:00:00  2461.023         0.000   2370.064            0.000
# 2017-03-07 18:00:00  2461.522         0.000   2370.064            0.000
# 2017-03-07 19:00:00  2462.374         0.000   2370.064            0.000
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-0724b3ffcc71> in <module>
#       1 #this linear regress will focus on the correlation between gas column gasPower and temperature column T
#       2 #Tt is Train temperature
# ----> 3 Tt = Tt[:]
#       4 Tt = Tt[Tt['T'] < 16.5] #Only uses data with T < 16.5 for training MVLR due to homes not heating when T>16.5.
#       5
#
# NameError: name 'Tt' is not defined

# %%
X = ['gasPower']
Y = ['Temperature']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.4, random_state=101)

# %%
from sklearn.linear_model import LinearRegression
linear_model = LinearRegression()
linear_model.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-9faac709b3da> in <module>
#       1 from sklearn.linear_model import LinearRegression
#       2 linear_model = LinearRegression()
# ----> 3 linear_model.fit(X_train,y_train)
#
# /opt/jupyterhub/anaconda/lib/python3.6/site-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     456         n_jobs_ = self.n_jobs
#     457         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 458                          y_numeric=True, multi_output=True)
#     459
#     460         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ...
