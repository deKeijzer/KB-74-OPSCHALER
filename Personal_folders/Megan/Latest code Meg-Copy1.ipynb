# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
#so basically I wanted to know if there was a difference between a ordened excel ,
# file and a messy one and if this would require more coding

df = pd.read_excel('/home/14109999/notebooks/KB-74-OPSCHALER/Personal_folders/Megan/w378.xlsx')

# %%
df.head()
# Out:
#          eMeter  eMeterReturn  eMeterLow  eMeterLowReturn  ePower  \
# 0  3.717472e+06           0.0  3883382.0              0.0  3760.0
# 1  3.717473e+06           0.0  3883382.0              0.0  3810.0
# 2  3.717474e+06           0.0  3883382.0              0.0  3780.0
# 3  3.717475e+06           0.0  3883382.0              0.0  3760.0
# 4  3.717476e+16           0.0  3883382.0              0.0  3800.0
#
#    ePowerReturn                 DD   FH                 FF   FX      ...       \
# 0           0.0  25522222222222224  300  32388888888888888  600      ...
# 1           0.0  25516666666666664  300  32416666666666664  600      ...
# 2           0.0  25511111111111112  300   3244444444444444  600      ...
# 3           0.0  25505555555555552  300   3247222222222222  600      ...
# 4           0.0               2550  300                325  600      ...
#
#                   U   WW  IX  M  R  S  O  Y           gasMeter      gasPower
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 


df = pd.read_csv('/datc/opschaler/output/P01S01W0378_gas_electricity_weather.csv',header = 0, delimiter="\t")

# %%
df.head()
# Out:
#      eMeter  eMeterReturn  eMeterLow  eMeterLowReturn  ePower  ePowerReturn  \
# 0  3717.472           0.0   3883.382              0.0   376.0           0.0
# 1  3717.473           0.0   3883.382              0.0   381.0           0.0
# 2  3717.474           0.0   3883.382              0.0   378.0           0.0
# 3  3717.475           0.0   3883.382              0.0   376.0           0.0
# 4  3717.476           0.0   3883.382              0.0   380.0           0.0
#
#            DD    FH         FF    FX    ...             U   WW   IX    M    R  \
# 0  255.222222  30.0  32.388889  60.0    ...     81.761111  NaN  5.0  0.0  0.0
# 1  255.166667  30.0  32.416667  60.0    ...     81.758333  NaN  5.0  0.0  0.0
# 2  255.111111  30.0  32.444444  60.0    ...     81.755556  NaN  5.0  0.0  0.0
# 3  255.055556  30.0  32.472222  60.0    ...     81.752778  NaN  5.0  0.0  0.0
# 4  255.000000  30.0  32.500000  60.0    ...     81.750000  NaN  5.0  0.0  0.0
#
#      S    O    Y     gasMeter  gasPower
# ...

# %%
plt.plot(df['gasPower'], df['ePower'], '.', color="#ff0000", ms=2)

# %%
plt.show()

# %%
df.plot(x='ePower', y='gasPower', kind ='scatter')
plt.xlabel('ePower')
plt.ylabel('gasPower')
plt.grid()
plt.tight_layout()
plt.show()
#don´t pay too much attention to this mess XD

# %%
df.loc['eMeter':'ePowerReturn','gasPower']
#just trying out stuff
# Out:
# Series([], Name: gasPower, dtype: float64)

# %%
df.describe(include = 'all')
# Out:
#                eMeter  eMeterReturn      eMeterLow  eMeterLowReturn  \
# count   180212.000000      180212.0  180212.000000         180212.0
# unique            NaN           NaN            NaN              NaN
# top               NaN           NaN            NaN              NaN
# freq              NaN           NaN            NaN              NaN
# mean      3772.072393           0.0    3943.560832              0.0
# std         32.097010           0.0      36.042886              0.0
# min       3717.472000           0.0    3883.382000              0.0
# 25%       3737.922000           0.0    3918.327750              0.0
# 50%       3775.712000           0.0    3939.233500              0.0
# 75%       3801.514250           0.0    3973.161000              0.0
# max       3830.551000           0.0    4003.787000              0.0
#
#                ePower  ePowerReturn             DD             FH  \
# count   180212.000000      180212.0  183155.000000  183155.000000
# ...

# %%
plt.show()

# %%
df.corr()
# Out:
#                    eMeter  eMeterReturn  eMeterLow  eMeterLowReturn    ePower  \
# eMeter           1.000000           NaN   0.982250              NaN  0.020867
# eMeterReturn          NaN           NaN        NaN              NaN       NaN
# eMeterLow        0.982250           NaN   1.000000              NaN  0.033549
# eMeterLowReturn       NaN           NaN        NaN              NaN       NaN
# ePower           0.020867           NaN   0.033549              NaN  1.000000
# ePowerReturn          NaN           NaN        NaN              NaN       NaN
# DD              -0.443447           NaN  -0.414969              NaN  0.024333
# FH               0.194500           NaN   0.193379              NaN  0.077698
# FF               0.201166           NaN   0.201796              NaN  0.071123
# FX               0.179363           NaN   0.171326              NaN  0.081037
# T                0.214925           NaN   0.206302              NaN  0.182408
# ...

# %%
sns.heatmap(df.corr(),annot=True, annot_kws={"size": 4},linewidths=0.1, linecolor='black')
plt.style.use('default')

# %%
plt.plot(df['gasPower'], df['ePower'], '.', color="#ff0000", ms=2)

# %%
df.loc[:,:6]
df.corr()
# Out:
#            eMeter  eMeterReturn  eMeterLow  eMeterLowReturn  ePower  \
# 0       3717.4720           0.0   3883.382              0.0   376.0
# 1       3717.4730           0.0   3883.382              0.0   381.0
# 2       3717.4740           0.0   3883.382              0.0   378.0
# 3       3717.4750           0.0   3883.382              0.0   376.0
# 4       3717.4760           0.0   3883.382              0.0   380.0
# 5       3717.4770           0.0   3883.382              0.0   379.0
# 6       3717.4780           0.0   3883.382              0.0   382.0
# 7       3717.4790           0.0   3883.382              0.0   380.0
# 8       3717.4800           0.0   3883.382              0.0   376.0
# 9       3717.4810           0.0   3883.382              0.0   380.0
# 10      3717.4820           0.0   3883.382              0.0   380.0
# 11            NaN           NaN        NaN              NaN     NaN
# 12      3717.4840           0.0   3883.382              0.0   379.0
# ...
