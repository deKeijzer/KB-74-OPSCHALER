# %%
# EDA packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#read in excel file
df = pd.read_excel('/home/14109999/notebooks/KB-74-OPSCHALER/Personal_folders/Megan/portfoliolinks/uncleandat.xlsx')

# %%
#to gain insight in what the first columns look like
df.head()
# Out:
#                                          movie_title  num_critic_for_reviews  \
# 0                                           Avatar?ÿ                   723.0
# 1         Pirates of the Caribbean: At World's End?ÿ                   302.0
# 2                                          Spectre?ÿ                   602.0
# 3                            The Dark Knight Rises?ÿ                   813.0
# 4  John Carter?ÿ,462,132,"""475""",530,640,730586...                     NaN
#
#    duration  DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                     10.0                   855.0
# 1       NaN                    563.0                  1000.0
# 2     148.0                     20.0                   161.0
# 3       NaN                  22000.0                 23000.0
# 4       NaN                      NaN                     NaN
#
#    ACTOR_1_facebook_likes        gross  num_voted_users  \
# 0                  1000.0  760505847.0         886204.0
# ...

# %%
#clean inconistent column names
#change and rename
df.columns
# Out:
# Index(['movie_title', 'num_critic_for_reviews', 'duration',
#        'DIRECTOR_facebook_likes', 'actor_3_facebook_likes',
#        'ACTOR_1_facebook_likes', 'gross', 'num_voted_users',
#        'Cast_Total_facebook_likes', 'facenumber_in_poster',
#        'num_user_for_reviews', 'budget', 'title_year',
#        'ACTOR_2_facebook_likes', 'imdb_score', 'title_year_1'],
#       dtype='object')

# %%
df.columns.str.upper()
# Out:
# Index(['MOVIE_TITLE', 'NUM_CRITIC_FOR_REVIEWS', 'DURATION',
#        'DIRECTOR_FACEBOOK_LIKES', 'ACTOR_3_FACEBOOK_LIKES',
#        'ACTOR_1_FACEBOOK_LIKES', 'GROSS', 'NUM_VOTED_USERS',
#        'CAST_TOTAL_FACEBOOK_LIKES', 'FACENUMBER_IN_POSTER',
#        'NUM_USER_FOR_REVIEWS', 'BUDGET', 'TITLE_YEAR',
#        'ACTOR_2_FACEBOOK_LIKES', 'IMDB_SCORE', 'TITLE_YEAR_1'],
#       dtype='object')

# %%
df.columns = df.columns.str.upper()

# %%
plt.plot(df['DURATION'],'*')

# %%
df.rename(columns = {'DURATION':'TIME'})
# Out:
#                                           MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS  \
# 0                                            Avatar?ÿ                   723.0
# 1          Pirates of the Caribbean: At World's End?ÿ                   302.0
# 2                                           Spectre?ÿ                   602.0
# 3                             The Dark Knight Rises?ÿ                   813.0
# 4   John Carter?ÿ,462,132,"""475""",530,640,730586...                     NaN
# 5                                      Spider-Man 3?ÿ                   392.0
# 6                                           Tangled?ÿ                   324.0
# 7                           Avengers: Age of Ultron?ÿ                   635.0
# 8                           Avengers: Age of Ultron?ÿ                   635.0
# 9            Harry Potter and the Half-Blood Prince?ÿ                   375.0
# 10               Batman v Superman: Dawn of Justice?ÿ                   673.0
# ...

# %%
df.isnull().any()
# Out:
# MOVIE_TITLE                  False
# NUM_CRITIC_FOR_REVIEWS        True
# DURATION                      True
# DIRECTOR_FACEBOOK_LIKES       True
# ACTOR_3_FACEBOOK_LIKES        True
# ACTOR_1_FACEBOOK_LIKES        True
# GROSS                         True
# NUM_VOTED_USERS               True
# CAST_TOTAL_FACEBOOK_LIKES     True
# FACENUMBER_IN_POSTER          True
# NUM_USER_FOR_REVIEWS          True
# BUDGET                        True
# TITLE_YEAR                    True
# ACTOR_2_FACEBOOK_LIKES        True
# IMDB_SCORE                    True
# TITLE_YEAR_1                  True
# dtype: bool

# %%
#missing data 
#delete rows with NaN's 
#replace
#add default values if neccesary
df.isnull()
# Out:
#     MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS  DURATION  DIRECTOR_FACEBOOK_LIKES  \
# 0         False                   False     False                    False
# 1         False                   False      True                    False
# 2         False                   False     False                    False
# 3         False                   False      True                    False
# 4         False                    True      True                     True
# 5         False                   False     False                    False
# 6         False                   False      True                    False
# 7         False                   False     False                    False
# 8         False                   False     False                    False
# 9         False                   False     False                    False
# 10        False                   False     False                     True
# ...

# %%
# Columns with NAN using the true/false method
# False means it doesn't have a NAN
df.isnull().any()
# Out:
# MOVIE_TITLE                  False
# NUM_CRITIC_FOR_REVIEWS        True
# DURATION                      True
# DIRECTOR_FACEBOOK_LIKES       True
# ACTOR_3_FACEBOOK_LIKES        True
# ACTOR_1_FACEBOOK_LIKES        True
# GROSS                         True
# NUM_VOTED_USERS               True
# CAST_TOTAL_FACEBOOK_LIKES     True
# FACENUMBER_IN_POSTER          True
# NUM_USER_FOR_REVIEWS          True
# BUDGET                        True
# TITLE_YEAR                    True
# ACTOR_2_FACEBOOK_LIKES        True
# IMDB_SCORE                    True
# TITLE_YEAR_1                  True
# dtype: bool

# %%
# For the whole df
df.isnull().any().any()
# Out:
# True

# %%
# showcases columns with NAN using int
df.isnull().sum()
# Out:
# MOVIE_TITLE                  0
# NUM_CRITIC_FOR_REVIEWS       1
# DURATION                     4
# DIRECTOR_FACEBOOK_LIKES      3
# ACTOR_3_FACEBOOK_LIKES       1
# ACTOR_1_FACEBOOK_LIKES       1
# GROSS                        1
# NUM_VOTED_USERS              2
# CAST_TOTAL_FACEBOOK_LIKES    3
# FACENUMBER_IN_POSTER         6
# NUM_USER_FOR_REVIEWS         1
# BUDGET                       1
# TITLE_YEAR                   1
# ACTOR_2_FACEBOOK_LIKES       2
# IMDB_SCORE                   1
# TITLE_YEAR_1                 7
# dtype: int64

# %%
df.isnull().sum().sum()
#result is total number of missing values
# Out:
# 35

# %%
#Going to fill the missing data
df.head()
df_0 = df.fillna(0)

# %%
df_0.head()
# Out:
#                                          MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS  \
# 0                                           Avatar?ÿ                   723.0
# 1         Pirates of the Caribbean: At World's End?ÿ                   302.0
# 2                                          Spectre?ÿ                   602.0
# 3                            The Dark Knight Rises?ÿ                   813.0
# 4  John Carter?ÿ,462,132,"""475""",530,640,730586...                     0.0
#
#    DURATION  DIRECTOR_FACEBOOK_LIKES  ACTOR_3_FACEBOOK_LIKES  \
# 0     178.0                     10.0                   855.0
# 1       0.0                    563.0                  1000.0
# 2     148.0                     20.0                   161.0
# 3       0.0                  22000.0                 23000.0
# 4       0.0                      0.0                     0.0
#
#    ACTOR_1_FACEBOOK_LIKES        GROSS  NUM_VOTED_USERS  \
# 0                  1000.0  760505847.0         886204.0
# ...

# %%
#after filling it with 0, I will fill it wil the mean of the DURATION
df['DURATION'].mean()
# Out:
# 152.6

# %%
df_mean = df.DURATION.fillna(df['DURATION'].mean())

# %%
df_mean
# Out:
# 0     178.0
# 1     152.6
# 2     148.0
# 3     152.6
# 4     152.6
# 5     156.0
# 6     152.6
# 7     141.0
# 8     141.0
# 9     153.0
# 10    183.0
# 11    169.0
# 12    106.0
# 13    151.0
# Name: DURATION, dtype: float64

# %%
#Now I am gonna drop the NAN's
df.isnull().sum().sum()
# Out:
# 35

# %%
df.shape
# Out:
# (14, 16)

# %%
df_drop = df.dropna()

# %%
df_drop.shape
# Out:
# (4, 16)

# %%
df_drop.head()
# Out:
#                                      MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS  \
# 2                                      Spectre?ÿ                   602.0
# 8                      Avengers: Age of Ultron?ÿ                   635.0
# 12                           Quantum of Solace?ÿ                   403.0
# 13  Pirates of the Caribbean: Dead Man's Chest?ÿ                   313.0
#
#     DURATION  DIRECTOR_FACEBOOK_LIKES  ACTOR_3_FACEBOOK_LIKES  \
# 2      148.0                     20.0                   161.0
# 8      141.0                     10.0                 19000.0
# 12     106.0                    395.0                   393.0
# 13     151.0                    563.0                  1000.0
#
#     ACTOR_1_FACEBOOK_LIKES        GROSS  NUM_VOTED_USERS  \
# 2                  11000.0  200074175.0         275868.0
# 8                  26000.0  458991599.0         462669.0
# 12                   451.0  168368427.0         330784.0
# ...

# %%
df_con = df.dropna(thresh=2)

# %%
df_condition.shape
# Out:
# (13, 16)

# %%
df_dropcolumn = df.dropna(axis=1)

# %%
df_dropcolumn.shape
# Out:
# (14, 1)

# %%
df_dropcolumn.head()
# Out:
#                                          MOVIE_TITLE
# 0                                           Avatar?ÿ
# 1         Pirates of the Caribbean: At World's End?ÿ
# 2                                          Spectre?ÿ
# 3                            The Dark Knight Rises?ÿ
# 4  John Carter?ÿ,462,132,"""475""",530,640,730586...

# %%
df.dtypes
# Out:
# MOVIE_TITLE                   object
# NUM_CRITIC_FOR_REVIEWS       float64
# DURATION                     float64
# DIRECTOR_FACEBOOK_LIKES      float64
# ACTOR_3_FACEBOOK_LIKES       float64
# ACTOR_1_FACEBOOK_LIKES       float64
# GROSS                        float64
# NUM_VOTED_USERS              float64
# CAST_TOTAL_FACEBOOK_LIKES    float64
# FACENUMBER_IN_POSTER         float64
# NUM_USER_FOR_REVIEWS         float64
# BUDGET                       float64
# TITLE_YEAR                   float64
# ACTOR_2_FACEBOOK_LIKES       float64
# IMDB_SCORE                   float64
# TITLE_YEAR_1                 float64
# dtype: object

# %%
#for further information on the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 16 columns):
# MOVIE_TITLE                  14 non-null object
# NUM_CRITIC_FOR_REVIEWS       13 non-null float64
# DURATION                     10 non-null float64
# DIRECTOR_FACEBOOK_LIKES      11 non-null float64
# ACTOR_3_FACEBOOK_LIKES       13 non-null float64
# ACTOR_1_FACEBOOK_LIKES       13 non-null float64
# GROSS                        13 non-null float64
# NUM_VOTED_USERS              12 non-null float64
# CAST_TOTAL_FACEBOOK_LIKES    11 non-null float64
# FACENUMBER_IN_POSTER         8 non-null float64
# NUM_USER_FOR_REVIEWS         13 non-null float64
# BUDGET                       13 non-null float64
# TITLE_YEAR                   13 non-null float64
# ACTOR_2_FACEBOOK_LIKES       12 non-null float64
# IMDB_SCORE                   13 non-null float64
# TITLE_YEAR_1                 7 non-null float64
# dtypes: float64(15), object(1)
# memory usage: 1.8+ KB
