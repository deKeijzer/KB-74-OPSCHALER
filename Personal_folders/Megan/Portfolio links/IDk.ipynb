# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('/datc/opschaler/combined_gas_smart_weather_dfs/processed/all_dwellings_combined_hour.csv', delimiter='\t', parse_dates=['datetime'], engine = 'python')
df = df.set_index(['datetime'])

# %%
df.describe()
# Out:
#               eMeter   eMeterReturn      eMeterLow  eMeterLowReturn  \
# count  106765.000000  106765.000000  106765.000000    106765.000000
# mean     2189.215206     709.855795    2485.990042       332.242885
# std      1361.673502    1527.941524    1556.899637       712.183033
# min        23.603001       0.000000      32.388000         0.000000
# 25%      1152.979980       0.000000    1259.534058         0.000000
# 50%      1738.719971       0.000000    2004.744995         0.000000
# 75%      2801.851074     783.710999    3734.760010       306.691986
# max      5932.604004    7923.578125    7707.495117      3508.043945
#
#               ePower   ePowerReturn       gasMeter             DD  \
# count  106765.000000  106765.000000  106685.000000  115843.000000
# mean      305.550675      88.666733    1885.520542     200.302983
# std       308.312428     370.928368     948.668185      86.826243
# min         0.000000       0.000000     195.725006       1.850000
# ...

# %%
y_val= df["gasPower"]
x_data=df.drop("gasPower",axis=1)

# %%
X_train, X_eval,y_train,y_eval=train_test_split(x_data,y_val,test_size=0.3,random_state=101)

# %%
scaler_model = MinMaxScaler()
scaler_model.fit(X_train)

X_train=pd.df(scaler_model.transform(X_train),columns=X_train.columns,index=X_train.index)

scaler_model.fit(X_eval)

X_eval=pd.df(scaler_model.transform(X_eval),columns=X_eval.columns,index=X_eval.index)

#Creating Feature Columns
feat_cols=[]
for cols in df.columns[:-1]:
    column=tf.feature_column.numeric_column(cols)
    feat_cols.append(column)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-e5f51ff31e2b> in <module>
#       1 scaler_model = MinMaxScaler()
# ----> 2 scaler_model.fit(X_train)
#       3
#       4 X_train=pd.df(scaler_model.transform(X_train),columns=X_train.columns,index=X_train.index)
#       5
#
# /opt/jupyterhub/anaconda/lib/python3.6/site-packages/sklearn/preprocessing/data.py in fit(self, X, y)
#     321         # Reset internal state before fitting
#     322         self._reset()
# --> 323         return self.partial_fit(X, y)
#     324
#     325     def partial_fit(self, X, y=None):
#
# /opt/jupyterhub/anaconda/lib/python3.6/site-packages/sklearn/preprocessing/data.py in partial_fit(self, X, y)
#     349         X = check_array(X, copy=self.copy, warn_on_dtype=True,
#     350                         estimator=self, dtype=FLOAT_DTYPES,
# ...
