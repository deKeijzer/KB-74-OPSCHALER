# %%
import pandas as pd
import numpy as np
from bokeh.charts import Scatter, output_file, show
import matplotlib.pyplot as plt

df = pd.read_csv("/datc/opschaler/combined_dfs_gas_smart_weather/P01S02W4827_merged_gas_smart_weather.csv",header=0,delimiter="\t",parse_dates = ['datetime'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-93-d2eb12a817d6> in <module>()
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 from bokeh.charts import Scatter, output_file, show
#       4 import matplotlib.pyplot as plt
#       5
#
# ModuleNotFoundError: No module named 'bokeh.charts'

# %%
df.head()
# Out:
#              datetime   eMeter  eMeterReturn  eMeterLow  eMeterLowReturn  \
# 0 2017-06-27 14:58:00  551.034      1442.395     777.73          619.046
# 1 2017-06-27 14:58:10  551.034      1442.398     777.73          619.046
# 2 2017-06-27 14:58:20  551.034      1442.400     777.73          619.046
# 3 2017-06-27 14:58:30  551.034      1442.402     777.73          619.046
# 4 2017-06-27 14:58:40  551.034      1442.405     777.73          619.046
#
#    ePower  ePowerReturn     gasMeter  gasPower          DD ...             P  \
# 0     0.0         762.0  1338.309500  0.000042  102.320000 ...   1006.520000
# 1     0.0         783.0  1338.309542  0.000042  102.376667 ...   1006.518333
# 2     0.0         821.0  1338.309583  0.000042  102.433333 ...   1006.516667
# 3     0.0         824.0  1338.309625  0.000042  102.490000 ...   1006.515000
# 4     0.0         839.0  1338.309667  0.000042  102.546667 ...   1006.513333
#
# ...

# %%
plt.title('House ID: P01S01W0373')

plt.plot(df['datetime'][:], df['eMeter'][:], '-', color='r', linewidth=1)
plt.xlabel('Date [-]')
plt.ylabel('eMeter [kWh]')
plt.xticks(rotation=45)
plt.grid()
plt.tight_layout()
plt.savefig('sample2.png', dpi=1000)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.title('House ID: P01S01W0373')

plt.plot(df['datetime'][:], df['gasMeter'][:], '-', color='r', linewidth=1)
plt.xlabel('Date [-]')
plt.ylabel('gasMeter [m3]')
plt.xticks(rotation=45)
plt.grid()
plt.tight_layout()
#plt.savefig('sample2.png', dpi=1000)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
