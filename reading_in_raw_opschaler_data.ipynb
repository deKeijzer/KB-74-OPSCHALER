# %%
"""
TODO: 
clean xlsx data?
concatenate xlsx data
concatenate csv data

seperate xlsx, csv or combined in one df?

ATTENTION!
'Batch 2-without pictures' is not yet included because the 'opnameformulier' is a pdf.

More info: https://campus.datacamp.com/courses/cleaning-data-in-python/combining-data-for-analysis?ex=4 whole chapter
"""

# Import necessary modules
import glob
import pandas as pd

# Write the pattern: pattern, ** means ''all sub dirs''
pattern_csv = 'data/**/**/*.csv'
pattern_xls = 'data/**/**/*.xls*'

# Save all file matches: csv_files
csv_files = glob.glob(pattern_csv)
xls_files = glob.glob(pattern_xls)

# Print the file names
print("Amount of csv files detected: %s" % len(csv_files))
print("Amount of xlsx files detected: %s" % len(xls_files))
# Out:
# Amount of csv files detected: 23094
# Amount of xlsx files detected: 52

# %%
# Load the second file into a DataFrame: csv2
csv1 = pd.read_csv(csv_files[0])
xls1 = pd.read_excel(xls_files[0])

# Print the head of csv2
csv1.head()
# Out:
#                                  Timestamp;Device;Co2Value;RoomTemp;Humidity;HumidityBathRoom;VentilationLevel;Presence
# 11-3-2017 23:49:00;1DC063;533;19                                    54;38;255;255;1
# 11-3-2017 23:54:00;1DC063;534;19                                    54;38;255;255;0
# 11-3-2017 23:59:00;1DC063;544;19                                    57;38;255;255;0
# 12-3-2017 0:04:00;1DC063;566;19                                     63;38;255;255;1
# 12-3-2017 0:09:00;1DC063;569;19                                     58;37;255;255;0

# %%
"""
Will probably need multi indexing:

https://campus.datacamp.com/courses/merging-dataframes-with-pandas/concatenating-data?ex=9
"""
# Out:
# '\nWill probably need multi indexing:\n\nhttps://campus.datacamp.com/courses/merging-dataframes-with-pandas/concatenating-data?ex=9\n'

# %%
xls_files[0:5]
# Out:
# ['data/Batch 2-without pictures/P01S02W4042/Opnameformulier P01S02W4042.xlsx',
#  'data/Batch 1-without pictures/P01S01W6271/Opnameformulier P01S01W6271.xls',
#  'data/Batch 1-without pictures/P01S01W7579/Opname formulier P01S01W7579.xls',
#  'data/Batch 1-without pictures/P01S01W6959/opname formulier P01S01W6959.xlsm',
#  'data/Batch 1-without pictures/P01S01W4313/opnameformulier P01S01W4313.xlsm']

# %% [markdown]
# """
# Concat files (=merge them in one df)
# """
# frames=[]
#
# for csv in csv_files:
#     print(csv)
#     df = pd.read_csv(csv)
#     frames.append(df)
#
# #csv_concat = pd.concat(frames)
# #csv_concat.info(memory_usage='deep')

# %%
"""
Selecting the tables out of the excel file.
Saving it in format table_{table number}.
"""
# Out:
# '\nSelecting the tables out of the excel file.\nSaving it in format table_{table number}.\n'

# %%
# Need iloc for index based selection of rows and columns
table_1 = xls1.iloc[23:34,2:4]
table_1
# Out:
#                                            Unnamed: 2  \
# 23                                        projectnaam
# 24                                            kenmerk
# 25                                              adres
# 26                              postcode + plaatsnaam
# 27                                     contactpersoon
# 28                                           eigendom
# 29                                         inspecteur
# 30                                datum woning bezoek
# 31                             datum afronding opname
# 32                                bron gebouwgegevens
# 33  gebruik gelijkwaardigheids-/ kwaliteitsverklar...
#
#                              Unnamed: 3
# 23                            opschaler
# 24                          P01S02W4042
# 25                                  NaN
# 26                                  NaN
# 27                                  NaN
# 28  professionele verhuur (particulier)
# 29                    Catherine Bahhady
# 30                                  NaN
# 31                                  NaN
# 32                           waarneming
# 33                                   ja

# %%
# TODO: Drop unselected 'soort woning' rows
table_2_1 = xls1.iloc[38:47,1:12]
table_2_1
# Out:
#    Unnamed: 1                   Unnamed: 2                  Unnamed: 3  \
# 38        NaN                   woningtype                         NaN
# 39          2                 soort woning                  woningtype
# 40        NaN                          NaN           eengezinswoningen
# 41        NaN                          NaN  positie_meergezinswoningen
# 42        NaN                          NaN                         NaN
# 43          O              eengezinswoning                  vrijstaand
# 44          X       appartement 1 woonlaag                tussen vloer
# 45          O  appartement meer  woonlagen                 hoek midden
# 46        NaN                          NaN                         NaN
#
#    Unnamed: 4     Unnamed: 5          Unnamed: 6 Unnamed: 7    Unnamed: 8  \
# 38        NaN            NaN                 NaN        NaN           NaN
# 39   bouwjaar  renovatiejaar            bouwtype   type dak  voorzetgevel
# 40        NaN            NaN            bouwtype   type_dak        ja_nee
# 41        NaN            NaN                 NaN        NaN           NaN
# 42        NaN            NaN                 NaN        NaN           NaN
# 43          0              0  traditioneel zwaar    hellend           nee
# 44       2007              0  traditioneel zwaar       plat           nee
# 45          0              0  traditioneel zwaar       geen           nee
# 46        NaN            NaN                 NaN        NaN           NaN
#
#               Unnamed: 9         Unnamed: 10         Unnamed: 11
# 38                   NaN                 NaN                 NaN
# 39  breedte\ngebouw [m2]  lengte\ngebouw [m]  hoogte\ngebouw [m]
# 40                   NaN                 NaN                 NaN
# 41                   NaN                 NaN                 NaN
# 42                   NaN                 NaN                 NaN
# 43                   nvt                 nvt                 nvt
# 44                     0                   0                   0
# 45                     0                   0                   0
# 46                   NaN                 NaN                 NaN

# %%
table_2_2 = xls1.iloc[48:54,1:9]
table_2_2
# Out:
#    Unnamed: 1                        Unnamed: 2        Unnamed: 3  \
# 48        NaN  gebruiksoppervlakte per bouwlaag               NaN
# 49        NaN               gebruiksoppervlakte  1e bouwlaag [m2]
# 50        NaN                               NaN               NaN
# 51        NaN                               NaN               NaN
# 52        NaN                      per bouwlaag           109.085
# 53        NaN                               NaN               NaN
#
#           Unnamed: 4        Unnamed: 5        Unnamed: 6  \
# 48               NaN               NaN               NaN
# 49  2e bouwlaag [m2]  3e bouwlaag [m2]  4e bouwlaag [m2]
# 50               NaN               NaN               NaN
# 51               NaN               NaN               NaN
# 52                 0                 0                 0
# 53               NaN               NaN               NaN
#
#                 Unnamed: 7     Unnamed: 8
# 48                     NaN            NaN
# 49  overige bouwlagen [m2]  totaal\n [m2]
# 50                     NaN            NaN
# 51                     NaN            NaN
# 52                       0        109.085
# 53                     NaN            NaN

# %%
table_3_1 = xls1.iloc[57:68,1:10]
table_3_1
# Out:
#    Unnamed: 1                    Unnamed: 2       Unnamed: 3      Unnamed: 4  \
# 57        NaN                         vloer              NaN             NaN
# 58        NaN                naam\nbouwdeel  oppervlak\n[m2]  perimeter\n[m]
# 59        NaN                           NaN              NaN             NaN
# 60        NaN                           NaN              NaN             NaN
# 61        NaN                        <naam>                0               0
# 62        NaN                        <naam>              NaN             NaN
# 63        NaN                        <naam>              NaN             NaN
# 64        NaN                        <naam>              NaN             NaN
# 65        NaN                        <naam>              NaN             NaN
# 66        NaN                           NaN              NaN             NaN
# 67        NaN  kruipruime (indien aanwezig)              NaN             NaN
#
#          Unnamed: 5                                         Unnamed: 6  \
# 57              NaN                                                NaN
# 58  dikte\nisolatie                                       lucht\nspouw
# 59   isolatie_vloer                                              spouw
# 60              NaN  alleen bij:\n- geen isolatie\n- iso dikte onbe...
# 61         onbekend                                                 ja
# 62         onbekend                                                 ja
# 63         onbekend                                                 ja
# 64         onbekend                                                 ja
# 65         onbekend                                                 ja
# 66              NaN                                                NaN
# 67              NaN                                                NaN
#
#       Unnamed: 7      Unnamed: 8          Unnamed: 9
# 57           NaN             NaN                 NaN
# 58  begrenzing\n  thermo\nkussen  Rc waarde\n[m2K/W]
# 59   grens_vloer          ja_nee                 NaN
# 60           NaN             NaN       indien bekend
# 61   kruipruimte             nee                   0
# 62   kruipruimte             nee                 NaN
# 63   kruipruimte             nee                 NaN
# 64   kruipruimte             nee                 NaN
# 65   kruipruimte             nee                 NaN
# 66           NaN             NaN                 NaN
# 67           NaN             NaN                 NaN

# %%
table_3_2 = xls1.iloc[67:75,1:10]
table_3_2
# Out:
#    Unnamed: 1                    Unnamed: 2        Unnamed: 3  \
# 67        NaN  kruipruime (indien aanwezig)               NaN
# 68        NaN                nr kruipruimte  bodem geïsoleerd
# 69        NaN                           NaN            ja_nee
# 70        NaN                           NaN               NaN
# 71        NaN                            xx               nee
# 72        NaN                            xx               nee
# 73        NaN                            xx               nee
# 74        NaN                            xx               nee
#
#                              Unnamed: 4                           Unnamed: 5  \
# 67                                  NaN                                  NaN
# 68                    Rm bodem\n[m2K/W]             nr kwaliteits verklaring
# 69                                  NaN                                  NaN
# 70  als bodem kruipruimte geïsoleerd is  als bodem kruipruimte geïsoleerd is
# 71                                    0                                    -
# 72                                  NaN                                  NaN
# 73                                  NaN                                  NaN
# 74                                  NaN                                  NaN
#
#            Unnamed: 6                              Unnamed: 7  \
# 67                NaN                                     NaN
# 68  wanden geïsoleerd                      Rm wanden\n[m2K/W]
# 69             ja_nee                                     NaN
# 70                NaN  als wanden kruipruimte geïsoleerd zijn
# 71                nee                                       0
# 72                nee                                     NaN
# 73                nee                                     NaN
# 74                nee                                     NaN
#
#                                 Unnamed: 8              Unnamed: 9
# 67                                     NaN                     NaN
# 68                nr kwaliteits verklaring  ventilatie kruipruimte
# 69                                     NaN  ventilatie_kruipruimte
# 70  als wanden kruipruimte geïsoleerd zijn                     NaN
# 71                                       -                 normaal
# 72                                       -                 normaal
# 73                                       -                 normaal
# 74                                       -                 normaal

# %%
table_3_3 = xls1.iloc[77:86,1:14]
table_3_3
# Out:
#    Unnamed: 1                                         Unnamed: 2   Unnamed: 3  \
# 77        NaN  vloeren en delen van buitenwanden die grenzen ...          NaN
# 78        NaN                naam bouwdeel\n& hoort bij vloer xx  lengte\n[m]
# 79        NaN                                                NaN          NaN
# 80        NaN                                                NaN          NaN
# 81        NaN                                             <naam>            0
# 82        NaN                                             <naam>          NaN
# 83        NaN                                             <naam>          NaN
# 84        NaN                                             <naam>          NaN
# 85        NaN                                             <naam>          NaN
#
#       Unnamed: 4   Unnamed: 5    Unnamed: 6         Unnamed: 7  \
# 77           NaN          NaN           NaN                NaN
# 78  breedte\n[m]  aantal\n[-]  aftrek\n[m2]  oppervlakte\n[m2]
# 79           NaN          NaN           NaN                NaN
# 80           NaN          NaN           NaN                NaN
# 81             0            1             0                  0
# 82           NaN          NaN             0                  0
# 83           NaN          NaN             0                  0
# 84           NaN          NaN             0                  0
# 85           NaN          NaN             0                  0
#
#                   Unnamed: 8       Unnamed: 9  \
# 77                       NaN              NaN
# 78  vloer boven maaiveld [m]  dikte\nisolatie
# 79                       NaN   isolatie_vloer
# 80                       NaN              NaN
# 81                         0         onbekend
# 82                       NaN              NaN
# 83                       NaN              NaN
# 84                       NaN              NaN
# 85                       NaN              NaN
#
#                                           Unnamed: 10        Unnamed: 11  \
# 77                                                NaN                NaN
# 78                                       lucht\nspouw       begrenzing\n
# 79                                              spouw  grens_vloer_grond
# 80  alleen bij:\n- geen isolatie\n- iso dikte onbe...                NaN
# 81                                                 ja              grond
# 82                                                NaN              grond
# 83                                                NaN              grond
# 84                                                NaN              grond
# 85                                                NaN              grond
#
#            Unnamed: 12               Unnamed: 13
# 77                 NaN                       NaN
# 78  Rc waarde\n[m2K/W]  nr kwaliteits verklaring
# 79                 NaN                       NaN
# 80       indien bekend           indien aanwezig
# 81                   2                         -
# 82                 NaN                         -
# 83                 NaN                         -
# 84                 NaN                         -
# 85                 NaN                         -

# %%
table_3_4 = xls1.iloc[87:101,1:15]
table_3_4
# Out:
#     Unnamed: 1      Unnamed: 2   Unnamed: 3    Unnamed: 4   Unnamed: 5  \
# 87         NaN     hellend dak          NaN           NaN          NaN
# 88         NaN  naam\nbouwdeel  lengte\n[m]  breedte\n[m]  aantal\n[-]
# 89         NaN             NaN          NaN           NaN          NaN
# 90         NaN             NaN          NaN           NaN          NaN
# 91         NaN          <naam>            0             0            1
# 92         NaN          <naam>          NaN           NaN          NaN
# 93         NaN          <naam>          NaN           NaN          NaN
# 94         NaN          <naam>          NaN           NaN          NaN
# 95         NaN          <naam>          NaN           NaN          NaN
# 96         NaN          <naam>          NaN           NaN          NaN
# 97         NaN          <naam>          NaN           NaN          NaN
# 98         NaN          <naam>          NaN           NaN          NaN
# 99         NaN          <naam>          NaN           NaN          NaN
# 100        NaN          <naam>          NaN           NaN          NaN
#
#        Unnamed: 6         Unnamed: 7                       Unnamed: 8  \
# 87            NaN                NaN                              NaN
# 88   aftrek\n[m2]  oppervlakte\n[m2]                     orientatie\n
# 89            NaN                NaN                       orientatie
# 90            NaN                NaN  helling per definitie 45 graden
# 91              0                  0                            noord
# 92              0                  0                              NaN
# 93              0                  0                              NaN
# 94              0                  0                              NaN
# 95              0                  0                              NaN
# 96              0                  0                              NaN
# 97              0                  0                              NaN
# 98              0                  0                              NaN
# 99              0                  0                              NaN
# 100             0                  0                              NaN
#
#           Unnamed: 9                                        Unnamed: 10  \
# 87               NaN                                                NaN
# 88   dikte\nisolatie                                       lucht\nspouw
# 89   isolatie_overig                                              spouw
# 90               NaN  alleen bij:\n- geen isolatie\n- iso dikte onbe...
# 91          onbekend                                                nee
# 92               NaN                                                NaN
# 93               NaN                                                NaN
# 94               NaN                                                NaN
# 95               NaN                                                NaN
# 96               NaN                                                NaN
# 97               NaN                                                NaN
# 98               NaN                                                NaN
# 99               NaN                                                NaN
# 100              NaN                                                NaN
#
#       Unnamed: 11         Unnamed: 12               Unnamed: 13  \
# 87            NaN                 NaN                       NaN
# 88   begrenzing\n  Rc waarde\n[m2K/W]  nr kwaliteits verklaring
# 89      grens_dak                 NaN                       NaN
# 90            NaN       indien bekend           indien aanwezig
# 91    buitenlucht                   2                         1
# 92    buitenlucht                 NaN                       NaN
# 93    buitenlucht                 NaN                       NaN
# 94    buitenlucht                 NaN                       NaN
# 95    buitenlucht                 NaN                       NaN
# 96    buitenlucht                 NaN                       NaN
# 97    buitenlucht                 NaN                       NaN
# 98    buitenlucht                 NaN                       NaN
# 99    buitenlucht                 NaN                       NaN
# 100   buitenlucht                 NaN                       NaN
#
#               Unnamed: 14
# 87                    NaN
# 88   dikte rieten dak [m]
# 89                    NaN
# 90        indien aanwezig
# 91                      0
# 92                    NaN
# 93                    NaN
# 94                    NaN
# 95                    NaN
# 96                    NaN
# 97                    NaN
# 98                    NaN
# 99                    NaN
# 100                   NaN

# %%
table_3_5 = xls1.iloc[102:111,1:14]
table_3_5
# Out:
#     Unnamed: 1      Unnamed: 2   Unnamed: 3    Unnamed: 4   Unnamed: 5  \
# 102        NaN        plat dak          NaN           NaN          NaN
# 103        NaN  naam\nbouwdeel  lengte\n[m]  breedte\n[m]  aantal\n[-]
# 104        NaN             NaN          NaN           NaN          NaN
# 105        NaN             NaN          NaN           NaN          NaN
# 106        NaN          <naam>            0             0            1
# 107        NaN          <naam>          NaN           NaN          NaN
# 108        NaN          <naam>          NaN           NaN          NaN
# 109        NaN          <naam>          NaN           NaN          NaN
# 110        NaN          <naam>          NaN           NaN          NaN
#
#        Unnamed: 6       Unnamed: 7   Unnamed: 8       Unnamed: 9  \
# 102           NaN              NaN          NaN              NaN
# 103  aftrek\n[m2]  oppervlak\n[m2]   orientatie  dikte\nisolatie
# 104           NaN              NaN          NaN  isolatie_overig
# 105           NaN              NaN          NaN              NaN
# 106             0                0  horizontaal         onbekend
# 107             0                0  horizontaal              NaN
# 108             0                0  horizontaal              NaN
# 109             0                0  horizontaal              NaN
# 110             0                0  horizontaal              NaN
#
#                                            Unnamed: 10   Unnamed: 11  \
# 102                                                NaN           NaN
# 103                                       lucht\nspouw  begrenzing\n
# 104                                              spouw     grens_dak
# 105  alleen bij:\n- geen isolatie\n- iso dikte onbe...           NaN
# 106                                                 ja   buitenlucht
# 107                                                NaN   buitenlucht
# 108                                                NaN   buitenlucht
# 109                                                NaN   buitenlucht
# 110                                                NaN   buitenlucht
#
#             Unnamed: 12               Unnamed: 13
# 102                 NaN                       NaN
# 103  Rc waarde\n[m2K/W]  nr kwaliteits verklaring
# 104                 NaN                       NaN
# 105       indien bekend           indien aanwezig
# 106                   0                         -
# 107                 NaN                         -
# 108                 NaN                         -
# 109                 NaN                         -
# 110                 NaN                         -

# %%
table_3_6 = xls1.iloc[112:131,1:14]
table_3_6
# Out:
#     Unnamed: 1      Unnamed: 2   Unnamed: 3    Unnamed: 4   Unnamed: 5  \
# 112        NaN    dichte gevel          NaN           NaN          NaN
# 113        NaN  naam\nbouwdeel  lengte\n[m]  breedte\n[m]  aantal\n[-]
# 114        NaN             NaN          NaN           NaN          NaN
# 115        NaN             NaN          NaN           NaN          NaN
# 116        NaN          <naam>         5.15          2.56            1
# 117        NaN             NaN         21.5          2.56            1
# 118        NaN             NaN         5.15          2.56            1
# 119        NaN             NaN         5.15          2.56            1
# 120        NaN          <naam>          NaN           NaN          NaN
# 121        NaN          <naam>          NaN           NaN          NaN
# 122        NaN          <naam>          NaN           NaN          NaN
# 123        NaN          <naam>          NaN           NaN          NaN
# 124        NaN          <naam>          NaN           NaN          NaN
# 125        NaN          <naam>          NaN           NaN          NaN
# 126        NaN          <naam>          NaN           NaN          NaN
# 127        NaN          <naam>          NaN           NaN          NaN
# 128        NaN          <naam>          NaN           NaN          NaN
# 129        NaN          <naam>          NaN           NaN          NaN
# 130        NaN          <naam>          NaN           NaN          NaN
#
#        Unnamed: 6       Unnamed: 7                       Unnamed: 8  \
# 112           NaN              NaN                              NaN
# 113  aftrek\n[m2]  oppervlak\n[m2]                     orientatie\n
# 114           NaN              NaN                       orientatie
# 115           NaN              NaN  helling per definitie 90 graden
# 116             0           13.184                        noordoost
# 117             0            55.04                        noordwest
# 118             0           13.184                         zuidwest
# 119             0           13.184                         zuidoost
# 120             0                0                              NaN
# 121             0                0                              NaN
# 122             0                0                              NaN
# 123             0                0                              NaN
# 124             0                0                              NaN
# 125             0                0                              NaN
# 126             0                0                              NaN
# 127             0                0                              NaN
# 128             0                0                              NaN
# 129             0                0                              NaN
# 130             0                0                              NaN
#
#           Unnamed: 9                                        Unnamed: 10  \
# 112              NaN                                                NaN
# 113  dikte\nisolatie                                       lucht\nspouw
# 114  isolatie_overig                                              spouw
# 115              NaN  alleen bij:\n- geen isolatie\n- iso dikte onbe...
# 116         onbekend                                           onbekend
# 117         onbekend                                           onbekend
# 118         onbekend                                           onbekend
# 119         onbekend                                           onbekend
# 120              NaN                                                NaN
# 121              NaN                                                NaN
# 122              NaN                                                NaN
# 123              NaN                                                NaN
# 124              NaN                                                NaN
# 125              NaN                                                NaN
# 126              NaN                                                NaN
# 127              NaN                                                NaN
# 128              NaN                                                NaN
# 129              NaN                                                NaN
# 130              NaN                                                NaN
#
#       Unnamed: 11         Unnamed: 12               Unnamed: 13
# 112           NaN                 NaN                       NaN
# 113  begrenzing\n  Rc waarde\n[m2K/W]  nr kwaliteits verklaring
# 114   grens_gevel                 NaN                       NaN
# 115           NaN       indien bekend           indien aanwezig
# 116   buitenlucht                   0                         -
# 117   buitenlucht                 NaN                         -
# 118   buitenlucht                 NaN                         -
# 119   buitenlucht                 NaN                         -
# 120   buitenlucht                 NaN                         -
# 121   buitenlucht                 NaN                         -
# 122   buitenlucht                 NaN                         -
# 123   buitenlucht                 NaN                         -
# 124   buitenlucht                 NaN                         -
# 125   buitenlucht                 NaN                         -
# 126   buitenlucht                 NaN                         -
# 127   buitenlucht                 NaN                         -
# 128   buitenlucht                 NaN                         -
# 129   buitenlucht                 NaN                         -
# 130   buitenlucht                 NaN                         -

# %%
table_3_7 = xls1.iloc[132:140,1:15]
table_3_7
# Out:
#     Unnamed: 1      Unnamed: 2   Unnamed: 3    Unnamed: 4   Unnamed: 5  \
# 132        NaN          paneel          NaN           NaN          NaN
# 133        NaN  naam\nbouwdeel  lengte\n[m]  breedte\n[m]  aantal\n[-]
# 134        NaN             NaN          NaN           NaN          NaN
# 135        NaN             NaN          NaN           NaN          NaN
# 136        NaN          <naam>            0             0            1
# 137        NaN          <naam>          NaN           NaN          NaN
# 138        NaN          <naam>          NaN           NaN          NaN
# 139        NaN          <naam>          NaN           NaN          NaN
#
#        Unnamed: 6       Unnamed: 7                       Unnamed: 8  \
# 132           NaN              NaN                              NaN
# 133  aftrek\n[m2]  oppervlak\n[m2]                     orientatie\n
# 134           NaN              NaN                       orientatie
# 135           NaN              NaN  helling per definitie 90 graden
# 136             0                0                            noord
# 137             0                0                              NaN
# 138             0                0                              NaN
# 139             0                0                              NaN
#
#           Unnamed: 9                                        Unnamed: 10  \
# 132              NaN                                                NaN
# 133  dikte\nisolatie                                       lucht\nspouw
# 134  isolatie_overig                                              spouw
# 135              NaN  alleen bij:\n- geen isolatie\n- iso dikte onbe...
# 136         onbekend                                                nee
# 137              NaN                                                NaN
# 138              NaN                                                NaN
# 139              NaN                                                NaN
#
#          Unnamed: 11   Unnamed: 12         Unnamed: 13  \
# 132              NaN           NaN                 NaN
# 133      type kozijn  begrenzing\n  Rc waarde\n[m2K/W]
# 134           kozijn   grens_gevel                 NaN
# 135              NaN           NaN       indien bekend
# 136  hout, kunststof   buitenlucht                   2
# 137              NaN           NaN                 NaN
# 138              NaN           NaN                 NaN
# 139              NaN           NaN                 NaN
#
#                   Unnamed: 14
# 132                       NaN
# 133  nr kwaliteits verklaring
# 134                       NaN
# 135           indien aanwezig
# 136                         -
# 137                       NaN
# 138                       NaN
# 139                       NaN

# %%
table_3_8 = xls1.iloc[141:160,1:25]
table_3_8
# Out:
#     Unnamed: 1       Unnamed: 2   Unnamed: 3    Unnamed: 4   Unnamed: 5  \
# 141        NaN        beglazing          NaN           NaN          NaN
# 142        NaN   naam\nbouwdeel  lengte\n[m]  breedte\n[m]  aantal\n[-]
# 143        NaN              NaN          NaN           NaN          NaN
# 144        NaN              NaN          NaN           NaN          NaN
# 145        NaN  Noordoost groot         1.55          2.65            3
# 146        NaN  Noordoost klein         1.55          2.45            1
# 147        NaN           <naam>          NaN           NaN          NaN
# 148        NaN           <naam>          NaN           NaN          NaN
# 149        NaN           <naam>          NaN           NaN          NaN
# 150        NaN           <naam>          NaN           NaN          NaN
# 151        NaN           <naam>          NaN           NaN          NaN
# 152        NaN           <naam>          NaN           NaN          NaN
# 153        NaN           <naam>          NaN           NaN          NaN
# 154        NaN           <naam>          NaN           NaN          NaN
# 155        NaN           <naam>          NaN           NaN          NaN
# 156        NaN           <naam>          NaN           NaN          NaN
# 157        NaN           <naam>          NaN           NaN          NaN
# 158        NaN           <naam>          NaN           NaN          NaN
# 159        NaN           <naam>          NaN           NaN          NaN
#
#        Unnamed: 6       Unnamed: 7                       Unnamed: 8  \
# 141           NaN              NaN                              NaN
# 142  aftrek\n[m2]  oppervlak\n[m2]                     orientatie\n
# 143           NaN              NaN                       orientatie
# 144           NaN              NaN  helling per definitie 90 graden
# 145             0          12.3225                        noordoost
# 146             0           3.7975                        noordoost
# 147             0                0                              NaN
# 148             0                0                              NaN
# 149             0                0                              NaN
# 150             0                0                              NaN
# 151             0                0                              NaN
# 152             0                0                              NaN
# 153             0                0                              NaN
# 154             0                0                              NaN
# 155             0                0                              NaN
# 156             0                0                              NaN
# 157             0                0                              NaN
# 158             0                0                              NaN
# 159             0                0                              NaN
#
#        Unnamed: 9  Unnamed: 10   Unnamed: 11      Unnamed: 12 Unnamed: 13  \
# 141           NaN          NaN           NaN              NaN         NaN
# 142  helling\n[°]  type ruimte  begrenzing\n      type kozijn   type glas
# 143       helling  type_ruimte   grens_gevel           kozijn        glas
# 144           NaN          NaN           NaN              NaN         NaN
# 145   90° (vert.)   leefruimte   buitenlucht  hout, kunststof        HR++
# 146   90° (vert.)  slaapruimte   buitenlucht  hout, kunststof        HR++
# 147           NaN          NaN   buitenlucht              NaN         NaN
# 148           NaN          NaN   buitenlucht              NaN         NaN
# 149           NaN          NaN   buitenlucht              NaN         NaN
# 150           NaN          NaN   buitenlucht              NaN         NaN
# 151           NaN          NaN   buitenlucht              NaN         NaN
# 152           NaN          NaN   buitenlucht              NaN         NaN
# 153           NaN          NaN   buitenlucht              NaN         NaN
# 154           NaN          NaN   buitenlucht              NaN         NaN
# 155           NaN          NaN   buitenlucht              NaN         NaN
# 156           NaN          NaN   buitenlucht              NaN         NaN
# 157           NaN          NaN   buitenlucht              NaN         NaN
# 158           NaN          NaN   buitenlucht              NaN         NaN
# 159           NaN          NaN   buitenlucht              NaN         NaN
#
#     Unnamed: 14 Unnamed: 15        Unnamed: 16    Unnamed: 17  \
# 141         NaN         NaN                NaN            NaN
# 142   zonwering    overstek  U waarde\n[W/m2K]  g waarde\n[-]
# 143      ja_nee      ja_nee                NaN            NaN
# 144         NaN         NaN      indien bekend  indien bekend
# 145         nee         nee                1.2            0.5
# 146         nee         nee                1.2            NaN
# 147         NaN         NaN                NaN            NaN
# 148         NaN         NaN                NaN            NaN
# 149         NaN         NaN                NaN            NaN
# 150         NaN         NaN                NaN            NaN
# 151         NaN         NaN                NaN            NaN
# 152         NaN         NaN                NaN            NaN
# 153         NaN         NaN                NaN            NaN
# 154         NaN         NaN                NaN            NaN
# 155         NaN         NaN                NaN            NaN
# 156         NaN         NaN                NaN            NaN
# 157         NaN         NaN                NaN            NaN
# 158         NaN         NaN                NaN            NaN
# 159         NaN         NaN                NaN            NaN
#
#               Unnamed: 18               Unnamed: 19
# 141                   NaN                       NaN
# 142      dikte glas\n[mm]  nr kwaliteits verklaring
# 143                   NaN                       NaN
# 144                   NaN           indien aanwezig
# 145  12 (tussenruimte 18)                         -
# 146  13 (tussenruimte 18)                         -
# 147                   NaN                         -
# 148                   NaN                         -
# 149                   NaN                         -
# 150                   NaN                         -
# 151                   NaN                         -
# 152                   NaN                         -
# 153                   NaN                         -
# 154                   NaN                         -
# 155                   NaN                         -
# 156                   NaN                         -
# 157                   NaN                         -
# 158                   NaN                         -
# 159                   NaN                         -

# %%
table_3_9 = xls1.iloc[161:169,1:13]
table_3_9
# Out:
#     Unnamed: 1      Unnamed: 2   Unnamed: 3    Unnamed: 4   Unnamed: 5  \
# 161        NaN            deur          NaN           NaN          NaN
# 162        NaN  naam\nbouwdeel  lengte\n[m]  breedte\n[m]  aantal\n[-]
# 163        NaN             NaN          NaN           NaN          NaN
# 164        NaN             NaN          NaN           NaN          NaN
# 165        NaN          <naam>            0             0            1
# 166        NaN          <naam>          NaN           NaN          NaN
# 167        NaN          <naam>          NaN           NaN          NaN
# 168        NaN          <naam>          NaN           NaN          NaN
#
#        Unnamed: 6       Unnamed: 7                       Unnamed: 8  \
# 161           NaN              NaN                              NaN
# 162  aftrek\n[m2]  oppervlak\n[m2]                     orientatie\n
# 163           NaN              NaN                       orientatie
# 164           NaN              NaN  helling per definitie 90 graden
# 165             0                0                            noord
# 166             0                0                              NaN
# 167             0                0                              NaN
# 168             0                0                              NaN
#
#      Unnamed: 9   Unnamed: 10        Unnamed: 11               Unnamed: 12
# 161         NaN           NaN                NaN                       NaN
# 162   type deur  begrenzing\n  U waarde\n[W/m2K]  nr kwaliteits verklaring
# 163        deur   grens_gevel                NaN                       NaN
# 164         NaN           NaN      indien bekend           indien aanwezig
# 165  geïsoleerd   buitenlucht                  0                         -
# 166         NaN   buitenlucht                NaN                       NaN
# 167         NaN   buitenlucht                NaN                       NaN
# 168         NaN   buitenlucht                NaN                       NaN

# %%
table_4_1 = xls1.iloc[172:183,1:14]
table_4_1
# Out:
#     Unnamed: 1                   Unnamed: 2     Unnamed: 3  \
# 172        NaN        individuele opwekking            NaN
# 173          3                 type toestel        toestel
# 174        NaN                          NaN       gasketel
# 175        NaN                          NaN      HRE_ketel
# 176        NaN                          NaN         lokaal
# 177        NaN                          NaN            NaN
# 178          O  geen individuele verwarming            nvt
# 179          O            lokale verwarming         lokaal
# 180          X                     gasketel   HR 107 ketel
# 181          O                    micro wkk  met HRE-label
# 182          O                   warmtepomp     warmtepomp
#
#                Unnamed: 4       Unnamed: 5 Unnamed: 6  \
# 172                   NaN              NaN        NaN
# 173        energie drager          bron WP    WP keur
# 174  energiedrager_lokaal  bron_warmtepomp     ja_nee
# 175         energiedrager              NaN        NaN
# 176                   NaN              NaN        NaN
# 177                   NaN              NaN        NaN
# 178                   nvt              nvt        nvt
# 179                   gas              nvt        nvt
# 180                   gas              nvt        nvt
# 181                   gas              nvt        nvt
# 182         elektriciteit            bodem         ja
#
#                         Unnamed: 7            Unnamed: 8           Unnamed: 9  \
# 172                            NaN                   NaN                  NaN
# 173            aanvoer temperatuur  vermogen therm. [kW]  vermogen elek. [kW]
# 174          warmtetransport_ketel                   NaN                  NaN
# 175     warmtetransport_warmtepomp                   NaN                  NaN
# 176                            NaN                   NaN                  NaN
# 177                            NaN                   NaN                  NaN
# 178                            nvt                   nvt                  nvt
# 179                            nvt                   nvt                  nvt
# 180         water LT\nθ,gem ≤ 50°C                   nvt                  nvt
# 181                            nvt                     2                    2
# 182  LT: 45°C < θ aanvoer  ≤ 55°C                      2                  nvt
#
#                   Unnamed: 10        Unnamed: 11        Unnamed: 12  \
# 172               niet bekend                NaN                NaN
# 173  tst. binnen therm. schil           bijstook  nummer verklaring
# 174                    ja_nee  gasketel_bijstook                NaN
# 175                       NaN                NaN                NaN
# 176                       NaN                NaN                NaN
# 177                       NaN                NaN                NaN
# 178                       nvt                nvt                nvt
# 179                       nvt                nvt                  -
# 180                        ja                nvt                  -
# 181                        ja                nvt                  -
# 182                        ja                nvt                  -
#
#      Unnamed: 13
# 172          NaN
# 173  merk & type
# 174          NaN
# 175          NaN
# 176          NaN
# 177          NaN
# 178          nvt
# 179            -
# 180            -
# 181            -
# 182            -

# %%
table_4_2 = xls1.iloc[185:195,1:15]
table_4_2
# Out:
#     Unnamed: 1                                 Unnamed: 2      Unnamed: 3  \
# 185        NaN  collectieve opwekking - preferent toestel             NaN
# 186          1                               type toestel         toestel
# 187        NaN                                        NaN        gasketel
# 188        NaN                                        NaN             NaN
# 189        NaN                                        NaN             NaN
# 190          X                geen collectieve verwarming             nvt
# 191          O                                   gasketel    HR 100 ketel
# 192          O                                 warmtepomp      warmtepomp
# 193          O                         gebouwgebonden WKK             WKK
# 194          O                      warmtelevering derden  warmtelevering
#
#          Unnamed: 4       Unnamed: 5 Unnamed: 6  \
# 185             NaN              NaN        NaN
# 186  energie drager          bron WP    WP keur
# 187   energiedrager  bron_warmtepomp     ja_nee
# 188             NaN              NaN        NaN
# 189             NaN              NaN        NaN
# 190             nvt              nvt        nvt
# 191             gas              nvt        nvt
# 192   elektriciteit            bodem         ja
# 193             gas              nvt        nvt
# 194          warmte              nvt        nvt
#
#                         Unnamed: 7            Unnamed: 8           Unnamed: 9  \
# 185                            NaN                   NaN                  NaN
# 186            aanvoer temperatuur  vermogen therm. [kW]  vermogen elek. [kW]
# 187          warmtetransport_ketel                   NaN                  NaN
# 188     warmtetransport_warmtepomp                   NaN                  NaN
# 189                            NaN                   NaN                  NaN
# 190                            nvt                   nvt                  nvt
# 191         water LT\nθ,gem ≤ 50°C                     2                  nvt
# 192  LT: 45°C < θ aanvoer  ≤ 55°C                      2                  nvt
# 193                            nvt                     2                    2
# 194                            nvt                   nvt                  nvt
#
#                   Unnamed: 10             Unnamed: 11             Unnamed: 12  \
# 185                       NaN                     NaN                     NaN
# 186  tst. binnen therm. schil  individuele bemetering  individuele afleverset
# 187                    ja_nee                  ja_nee                  ja_nee
# 188                       NaN                     NaN                     NaN
# 189                       NaN                     NaN                     NaN
# 190                       nvt                     nvt                     nvt
# 191                        ja                      ja                     nee
# 192                        ja                      ja                     nee
# 193                        ja                      ja                     nee
# 194                       nee                      ja                      ja
#
#            Unnamed: 13  Unnamed: 14
# 185                NaN          NaN
# 186  nummer verklaring  merk & type
# 187                NaN          NaN
# 188                NaN          NaN
# 189                NaN          NaN
# 190                nvt          nvt
# 191                  -            -
# 192                  -            -
# 193                  -            -
# 194                  -            -

# %%
table_4_3 = xls1.iloc[197:207,1:7]
table_4_3
# Out:
#     Unnamed: 1                                      Unnamed: 2    Unnamed: 3  \
# 197        NaN  collectieve opwekking - NIET preferent toestel           NaN
# 198          1                                    type toestel       toestel
# 199        NaN                                             NaN      gasketel
# 200        NaN                                             NaN           NaN
# 201        NaN                                             NaN           NaN
# 202          O                     geen NIET preferent toestel           nvt
# 203          O                          elektrische verwarming    elektrisch
# 204          O                                        gasketel  HR 100 ketel
# 205          O                                      warmtepomp    warmtepomp
# 206          O                                             WKK           WKK
#
#         Unnamed: 4       Unnamed: 5 Unnamed: 6
# 197            NaN              NaN        NaN
# 198  energiedrager  bron warmtepomp    WP keur
# 199  energiedrager  bron_warmtepomp     ja_nee
# 200            NaN              NaN        NaN
# 201            NaN              NaN        NaN
# 202            nvt              nvt        nvt
# 203  elektriciteit              nvt        nvt
# 204            gas              nvt        nvt
# 205  elektriciteit       grondwater        nee
# 206            gas              nvt        mvt

# %%
table_4_4 = xls1.iloc[209:215,1:14]
table_4_4
# Out:
#     Unnamed: 1                        Unnamed: 2  \
# 209        NaN  distributie, afgifte en regeling
# 210        NaN                      type toestel
# 211        NaN                               NaN
# 212        NaN                               NaN
# 213        NaN                       distributie
# 214        NaN        afgiftesysteem en regeling
#
#                                    Unnamed: 3  \
# 209                                       NaN
# 210                    verdeler / verzamelaar
# 211  verdelers_verzamelaars_warmtedistributie
# 212                                       NaN
# 213                       ja, niet geïsoleerd
# 214                                       nvt
#
#                                    Unnamed: 4           Unnamed: 5  \
# 209                                       NaN                  NaN
# 210                    leid/kanaal onv.ruimte  leid. buiten gebouw
# 211  leidingen_kanalen_in_onverwarmde_ruimten               ja_nee
# 212                                       NaN                  NaN
# 213                       ja, niet geïsoleerd                   ja
# 214                                       nvt                  nvt
#
#                           Unnamed: 6                Unnamed: 7  \
# 209                              NaN                       NaN
# 210                 inblaas richting             pomp vermogen
# 211  inblaasrichting_luchtverwarming  berekening_pomp_vermogen
# 212                              NaN                       NaN
# 213                       kernzijdig                forfaitair
# 214                              nvt                       nvt
#
#                    Unnamed: 8         Unnamed: 9 Unnamed: 10  \
# 209                       NaN                NaN         NaN
# 210  eigen pomp vermogen  [W]  nummer verklaring  extra pomp
# 211                       NaN                NaN  extra_pomp
# 212                       NaN                NaN         NaN
# 213                         2                  2         nee
# 214                       nvt                nvt         nvt
#
#                 Unnamed: 11             Unnamed: 12        Unnamed: 13
# 209                     NaN                     NaN                NaN
# 210          afgiftesysteem  regeling warmteafgifte  nummer verklaring
# 211          afgiftesysteem  regeling_warmteafgifte                NaN
# 212                     NaN                     NaN                NaN
# 213                     nvt                     nvt                nvt
# 214  vloer-/wand-verwarming                geregeld                  -

# %%
table_4_5 = xls1.iloc[217:224,1:7]
table_4_5
# Out:
#     Unnamed: 1        Unnamed: 2                                Unnamed: 3  \
# 217        NaN       thermostaat                                       NaN
# 218          2  type thermostaat                     instelling bij bezoek
# 219        NaN               NaN  verdelers_verzamelaars_warmtedistributie
# 220        NaN               NaN                                       NaN
# 221          O              geen                                       nvt
# 222          X           manueel                                        21
# 223          O       automatisch                                       nvt
#
#                                    Unnamed: 4              Unnamed: 5  \
# 217                                       NaN                     NaN
# 218                        instelling weekdag  instelling weekend dag
# 219  leidingen_kanalen_in_onverwarmde_ruimten                  ja_nee
# 220                                       NaN                     NaN
# 221                                       nvt                     nvt
# 222                                       nvt                     nvt
# 223                                         -                       -
#
#                           Unnamed: 6
# 217                              NaN
# 218                     merk en type
# 219  inblaasrichting_luchtverwarming
# 220                              NaN
# 221                              nvt
# 222                        honeywell
# 223                                -

# %%
table_5_1 = xls1.iloc[228:232,1:8]
table_5_1
# Out:
#     Unnamed: 1    Unnamed: 2               Unnamed: 3  \
# 228      False  type toestel          koude\nopwekker
# 229        NaN           NaN            koudeopwekker
# 230        NaN           NaN                      NaN
# 231          O       koeling  compressie (elektrisch)
#
#                   Unnamed: 4     Unnamed: 5              Unnamed: 6  \
# 228  koelmachine ook voor RV  energiedrager  rendem. met verklaring
# 229                   ja_nee  energiedrager                     NaN
# 230                      NaN            NaN                     NaN
# 231                      nee  elektriciteit                       -
#
#             Unnamed: 7
# 228  nummer verklaring
# 229                NaN
# 230                NaN
# 231                  -

# %%
table_6_1a = xls1.iloc[235:248,1:16]
table_6_1a
# Out:
#     Unnamed: 1                            Unnamed: 2  \
# 235        NaN  toestel opwekking en distributie - 1
# 236          1                 type toestel tapwater
# 237        NaN                                   NaN
# 238        NaN                                   NaN
# 239        NaN                                   NaN
# 240        NaN                                   NaN
# 241        NaN                                   NaN
# 242          X                       individueel gas
# 243          O                individueel elektrisch
# 244          O            individueel elektrische wp
# 245          O            collectief direct gestookt
# 246          O          collectief indirect gestookt
# 247          O                 warmtelevering derden
#
#                    Unnamed: 3                                Unnamed: 4  \
# 235                       NaN                                  zie foto
# 236      opstelplaats toestel                                   toestel
# 237  opstelplaats_toestel_tap               tap_toestel_individueel_gas
# 238                       NaN     tap_toestel_individueel_elektriciteit
# 239                       NaN    tap_toestel_collectief_direct_gestookt
# 240                       NaN  tap_toestel_collectief_indirect_gestookt
# 241                       NaN              afhankelijk van type toestel
# 242             binnen woning                 combitoestel Gaskeur HRww
# 243             binnen woning                            elektr. boiler
# 244             binnen woning                WP vent.lucht geen WP-keur
# 245             binnen woning                      direct gestookt, gas
# 246             binnen woning                                  VR ketel
# 247             buiten woning                            warmtelevering
#
#                  Unnamed: 5          Unnamed: 6  \
# 235             niet bekend                 NaN
# 236    CW klasse gastoestel  isolatie boilervat
# 237               CW_klasse  isolatie_boilervat
# 238                     NaN                 NaN
# 239                     NaN                 NaN
# 240                     NaN                 NaN
# 241  alleen individueel gas                 NaN
# 242                     CW3                 nvt
# 243                     nvt                 nvt
# 244                     nvt                 nvt
# 245                     nvt                 nvt
# 246                     nvt                geen
# 247                     nvt                 nvt
#
#                              Unnamed: 7           Unnamed: 8  \
# 235                                 NaN                  NaN
# 236         isol. leiding. w. wisselaar   circulatie leiding
# 237  isolatie_leidingen_warmtewisselaar    circulatieleiding
# 238                                 NaN                  NaN
# 239                                 NaN                  NaN
# 240                                 NaN                  NaN
# 241                                 NaN                  NaN
# 242                                 nvt                  nvt
# 243                                 nvt                  nvt
# 244                                 nvt                  nvt
# 245                                 nvt                  nee
# 246                               10 mm  ja, niet geïsoleerd
# 247                                 nvt                  nvt
#
#                  Unnamed: 9             Unnamed: 10           Unnamed: 11  \
# 235                     NaN                     NaN                   NaN
# 236  vermogen circ.pomp [W]  individuele bemetering  gastoestel\nbijstook
# 237                     NaN                  ja_nee   bijstook_wp_tap_gas
# 238                     NaN                     NaN                   NaN
# 239                     NaN                     NaN                   NaN
# 240                     NaN                     NaN                   NaN
# 241                     NaN                     NaN                   NaN
# 242                     nvt                      ja                   nvt
# 243                     nvt                      ja                   nvt
# 244                     nvt                      ja         geen bijstook
# 245                       0                     nee                   nvt
# 246                       2                     nee                   nvt
# 247                     nvt                     nee                   nvt
#
#            Unnamed: 12                Unnamed: 13                Unnamed: 14  \
# 235                NaN                        NaN                        NaN
# 236  fractie\nbijstook  opwekk. rend.\nverklaring  nr. kwaliteits verklaring
# 237                NaN                        NaN                        NaN
# 238                NaN                        NaN                        NaN
# 239                NaN                        NaN                        NaN
# 240                NaN                        NaN                        NaN
# 241                NaN                        NaN                        NaN
# 242                nvt                          0                          1
# 243                nvt                          0                          1
# 244                  0                          0                          1
# 245                nvt                          0                          1
# 246                nvt                          0                          1
# 247                nvt                          0                          1
#
#       Unnamed: 15
# 235           NaN
# 236  merk en type
# 237           NaN
# 238           NaN
# 239           NaN
# 240           NaN
# 241           NaN
# 242             -
# 243             -
# 244             -
# 245             -
# 246             -
# 247             -

# %%
table_6_1b = xls1.iloc[249:258,1:16]
table_6_1b
# Out:
#     Unnamed: 1                            Unnamed: 2            Unnamed: 3  \
# 249        NaN  toestel opwekking en distributie - 2                   NaN
# 250          1                 type toestel tapwater  opstelplaats toestel
# 251          X              geen 2e toestel tapwater                   nvt
# 252          O                       individueel gas         binnen woning
# 253          O                individueel elektrisch         binnen woning
# 254          O            individueel elektrische wp         binnen woning
# 255          O            collectief direct gestookt         binnen woning
# 256          O          collectief indirect gestookt         binnen woning
# 257          O                 warmtelevering derden         buiten woning
#
#                      Unnamed: 4            Unnamed: 5          Unnamed: 6  \
# 249                         NaN                   NaN                 NaN
# 250                     toestel  CW klasse gastoestel  isolatie boilervat
# 251                         nvt                   nvt                 nvt
# 252         keuken- / badgeiser                   CW3                 nvt
# 253              elektr. boiler                   nvt                 nvt
# 254  WP vent.lucht geen WP-keur                   nvt                 nvt
# 255        direct gestookt, gas                   nvt                 nvt
# 256                    VR ketel                   nvt                geen
# 257              warmtelevering                   nvt                 nvt
#
#                       Unnamed: 7           Unnamed: 8              Unnamed: 9  \
# 249                          NaN                  NaN                     NaN
# 250  isol. leiding. w. wisselaar   circulatie leiding  vermogen circ.pomp [W]
# 251                          nvt                  nvt                     nvt
# 252                          nvt                  nvt                     nvt
# 253                          nvt                  nvt                     nvt
# 254                          nvt                  nvt                     nvt
# 255                          nvt                  nee                       0
# 256                        10 mm  ja, niet geïsoleerd                       2
# 257                          nvt                  nvt                     nvt
#
#                 Unnamed: 10           Unnamed: 11        Unnamed: 12  \
# 249                     NaN                   NaN                NaN
# 250  individuele bemetering  gastoestel\nbijstook  fractie\nbijstook
# 251                     nvt                   nvt                nvt
# 252                      ja                   nvt                nvt
# 253                      ja                   nvt                nvt
# 254                      ja         geen bijstook                  0
# 255                     nee                   nvt                nvt
# 256                     nee                   nvt                nvt
# 257                     nee                   nvt                nvt
#
#                    Unnamed: 13                Unnamed: 14   Unnamed: 15
# 249                        NaN                        NaN           NaN
# 250  opwekk. rend.\nverklaring  nr. kwaliteits verklaring  merk en type
# 251                        nvt                        nvt           nvt
# 252                          0                          1             -
# 253                          0                          1             -
# 254                          0                          1             -
# 255                          0                          1             -
# 256                          0                          1             -
# 257                          0                          1             -

# %%
table_6_2 = xls1.iloc[259:266,1:8]
table_6_2
# Out:
#     Unnamed: 1                                         Unnamed: 2  \
# 259        NaN  leidingen naar tappunten en douchewater warmte...
# 260        NaN               collectioroppervlak zonneboierl [m2]
# 261        NaN                                                NaN
# 262        NaN                                                NaN
# 263        NaN                           leidinglengtes toestel 1
# 264        NaN                           leidinglengtes toestel 2
# 265        NaN                                               DWTW
#
#                Unnamed: 3              Unnamed: 4       Unnamed: 5  \
# 259                   NaN                     NaN              NaN
# 260  leidinglengte keuken  leidinglengte badkamer             DWTW
# 261     leidinglengte_tap       leidinglengte_tap             DWTW
# 262                   NaN                     NaN              NaN
# 263             0-2 meter               2-6 meter              nvt
# 264                   nvt                     nvt              nvt
# 265                   nvt                     nvt  ja, kwal.verkl.
#
#                  Unnamed: 6                Unnamed: 7
# 259                     NaN                       NaN
# 260  rend.  DWTW verklaring  nr kwaliteits verklaring
# 261                     NaN                       NaN
# 262                     NaN                       NaN
# 263                     nvt                       nvt
# 264                     nvt                       nvt
# 265                       0                         -

# %%
table_6_3 = xls1.iloc[267:272,1:14]
table_6_3
# Out:
#     Unnamed: 1           Unnamed: 2           Unnamed: 3    Unnamed: 4  \
# 267        NaN          zonneboiler                  NaN           NaN
# 268        NaN          zonneboiler  collector-opp. [m2]  PVT\nsysteem
# 269        NaN  zonneboiler_is_voor                  NaN        ja_nee
# 270        NaN                  NaN                  NaN           NaN
# 271        NaN        niet aanwezig                    0           nee
#
#                      Unnamed: 5        Unnamed: 6          Unnamed: 7  \
# 267                         NaN               NaN                 NaN
# 268  #  woningen op zonneboiler  zonnekeur\nlabel  helling\ncollector
# 269                         NaN            ja_nee             helling
# 270                         NaN               NaN                 NaN
# 271                           1               nee                 45°
#
#                 Unnamed: 8            Unnamed: 9                  Unnamed: 10  \
# 267                    NaN                   NaN                          NaN
# 268  orientatie\ncollector  volume opslagvat {l]  zonbijdrage -verkl. [MJ/jr]
# 269             orientatie                   NaN                          NaN
# 270                    NaN                   NaN                          NaN
# 271                   zuid                     0                            0
#
#                       Unnamed: 11            Unnamed: 12  \
# 267                           NaN                    NaN
# 268  hulpenergie - verkl. [MJ/jr]  PVT Wp/m2\nverklaring
# 269                           NaN                    NaN
# 270                           NaN                    NaN
# 271                             0                      0
#
#                    Unnamed: 13
# 267                        NaN
# 268  nr. kwaliteits verklaring
# 269                        NaN
# 270                        NaN
# 271                          -

# %%
table_7_1 = xls1.iloc[275:285,1:12]
table_7_1
# Out:
#     Unnamed: 1                 Unnamed: 2  \
# 275          3          ventilatiesysteem
# 276        NaN                        NaN
# 277        NaN                        NaN
# 278        NaN                        NaN
# 279        NaN                        NaN
# 280        NaN                        NaN
# 281          O  A. natuurlijke ventilatie
# 282          O   C. mechanische afzuiging
# 283          X        D. balansventilatie
# 284          O           E. combisystemen
#
#                                         Unnamed: 3  \
# 275                                   omschrijving
# 276                            ventilatiesysteem_A
# 277                            ventilatiesysteem_C
# 278                            ventilatiesysteem_D
# 279                            ventilatiesysteem_E
# 280                                            NaN
# 281                                      A1. basis
# 282                              C.1 handbediening
# 283  D2. WTW zonder zonering, sturing en handmatig
# 284                      C + decentr. bal.+wtw+CO2
#
#                             Unnamed: 4    Unnamed: 5            Unnamed: 6  \
# 275                    installatiejaar  ventilatoren  klapramen / roosters
# 276  installatiejaar_ventilatiesysteem  ventilatoren                ja_nee
# 277                                NaN           NaN                   NaN
# 278                                NaN           NaN                   NaN
# 279                                NaN           NaN                   NaN
# 280                                NaN           NaN                   NaN
# 281                                nvt           nvt                    ja
# 282                             ≤ 1980  gelijkstroom                    ja
# 283                             > 1998  wisselstroom                   nee
# 284                             ≤ 1980  gelijkstroom                   nee
#
#               Unnamed: 7            Unnamed: 8               Unnamed: 9  \
# 275  afzuigkap in keuken                   WTW  rendem. WTW\nverklaring
# 276               ja_nee                   WTW                      NaN
# 277                  NaN                   NaN                      NaN
# 278                  NaN                   NaN                      NaN
# 279                  NaN                   NaN                      NaN
# 280                  NaN                   NaN                      NaN
# 281                   ja                   nvt                      nvt
# 282                   ja                   nvt                      nvt
# 283                   ja                  geen                        0
# 284                   ja  tegenstroom (HR wtw)                        0
#
#                    Unnamed: 10   Unnamed: 11
# 275  nr. kwaliteits verklaring  merk en type
# 276                        NaN           NaN
# 277                        NaN           NaN
# 278                        NaN           NaN
# 279                        NaN           NaN
# 280                        NaN           NaN
# 281                        nvt           nvt
# 282                        nvt             -
# 283                          -             -
# 284                          -             -

# %%
table_8_1 = xls1.iloc[286:292,1:9]
table_8_1
# Out:
#     Unnamed: 1                                 Unnamed: 2        Unnamed: 3  \
# 286        NaN  installaties - fotovoltaïsche cellen (PV)               NaN
# 287        NaN                                        NaN               NaN
# 288        NaN                                   type cel  oppervlakte [m2]
# 289        NaN                                    type_PV               NaN
# 290        NaN                                        NaN               NaN
# 291        NaN                    mono-/multi kristallijn                 0
#
#              Unnamed: 4             Unnamed: 5         Unnamed: 6  \
# 286                 NaN                    NaN                NaN
# 287                 NaN                    NaN                NaN
# 288  helling\ncollector  orientatie\ncollector  Wp/m2\nverklaring
# 289             helling             orientatie                NaN
# 290                 NaN                    NaN                NaN
# 291                 45°                   zuid                  0
#
#                     Unnamed: 7    Unnamed: 8
# 286                        NaN           NaN
# 287                        NaN           NaN
# 288  nr. kwaliteits verklaring  merk en type
# 289                        NaN           NaN
# 290                        NaN           NaN
# 291                          -             -
